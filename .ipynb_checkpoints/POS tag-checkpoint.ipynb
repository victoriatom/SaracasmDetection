# %%
import nltk, matplotlib, re

# %%
# Read in entire file of tweets

# Create List to keep adding lines to
list = []

# Open file of tweets, appending each line to List
with open("sarcastictweets.txt") as f:
    for line in f:
        list.append(line)

# %%
# Tokenize and assign POS tags to each word one tweet at a time

tagged_list = []

for i in list:
    tweet = nltk.word_tokenize(i)
    tweet = nltk.pos_tag(tweet)
    tagged_list.append(tweet)
tagged_list
# Out:
# [[('Very', 'RB'),
#   ('low', 'JJ'),
#   ('entries', 'NNS'),
#   ('in', 'IN'),
#   ('this', 'DT'),
#   ('giveaway', 'NN'),
#   ('!', '.'),
#   ('Hop', 'NNP'),
#   ('over', 'IN'),
#   ('and', 'CC'),
#   ('check', 'VB'),
#   ('it', 'PRP'),
#   ('out', 'RP'),
#   ('!', '.'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/OrUSN9ne', 'NN')],
#  [],
#  [('This', 'DT'),
#   ('totally', 'RB'),
#   ('topped', 'VBD'),
#   ('off', 'RP'),
#   ('my', 'PRP$'),
#   ('week', 'NN'),
#   (':', ':'),
#   ("'", 'POS'),
#   (')', ')'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Summers', 'NNS'),
#   ('over', 'IN'),
#   ('and', 'CC'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('shit', 'VBN'),
#   ('.', '.'),
#   ('Only', 'RB'),
#   ('sunny', 'JJ'),
#   ('day', 'NN'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('bbq', 'NN'),
#   ('in', 'IN'),
#   ('north', 'JJ'),
#   ('west', 'NN'),
#   ('with', 'IN'),
#   ('@', 'NNP'),
#   ('Kade_96', 'NNP'),
#   ('and', 'CC'),
#   ('@', 'NNP'),
#   ('Jess_birch95', 'NNP'),
#   ('hahhahaaa', 'NN'),
#   ('#', '#'),
#   ('amazing', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Did', 'NNP'),
#   ('you', 'PRP'),
#   ('know', 'VBP'),
#   ('that', 'IN'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('Bolshoi', 'NNP'),
#   ('Ballet', 'NNP'),
#   ('members', 'NNS'),
#   ('was', 'VBD'),
#   ('born', 'VBN'),
#   ('in', 'IN'),
#   ('Maranhão', 'NNP'),
#   ('?', '.'),
#   ('Bruna', 'NNP'),
#   ('Gaglianone', 'NNP'),
#   ('is', 'VBZ'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Moscow', 'NNP'),
#   ('group', 'NN'),
#   ('!', '.'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/LG3SME1l', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ('just', 'RB'),
#   ('love', 'VB'),
#   ('missing', 'VBG'),
#   ('the', 'DT'),
#   ('bus', 'NN'),
#   ('!', '.'),
#   ('☺', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('If', 'IN'),
#   ('you', 'PRP'),
#   ("'re", 'VBP'),
#   ('going', 'VBG'),
#   ('into', 'IN'),
#   ('highschool', 'NN'),
#   ('and', 'CC'),
#   ('cant', 'NN'),
#   ('do', 'VBP'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('4', 'CD'),
#   ('pirouettes', 'NNS'),
#   ('you', 'PRP'),
#   ('obviously', 'RB'),
#   ('go', 'VBP'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('fantastic', 'JJ'),
#   ('studio', 'NN'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('babee_kayyy', 'NN'),
#   ('lol', 'NN'),
#   ('itold', 'NN'),
#   ('you', 'PRP'),
#   ('iwasnt', 'VBP'),
#   ('coming', 'VBG'),
#   ('.', '.'),
#   (':', ':'),
#   (')', ')'),
#   ('what', 'WP'),
#   ('we', 'PRP'),
#   ('do', 'VBP'),
#   ('in', 'IN'),
#   ('class', 'NN'),
#   ('?', '.')],
#  [],
#  [('TThis', '$'),
#   ('8:20', 'CD'),
#   ('Friday', 'NNP'),
#   ('class', 'NN'),
#   ('is', 'VBZ'),
#   ('gon', 'VBG'),
#   ('na', 'RB'),
#   ('be', 'VB'),
#   ('grrreat', 'NN'),
#   ('!', '.'),
#   ('!', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Gee', 'NNP'),
#   ('wiz', 'VBD'),
#   ('what', 'WP'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('day', 'NN'),
#   ('so', 'RB'),
#   ('far', 'RB'),
#   ('.', '.'),
#   ('You', 'PRP'),
#   ('can', 'MD'),
#   ('cut', 'VB'),
#   ('the', 'DT'),
#   ('tension', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('knife', 'NN'),
#   ('and', 'CC'),
#   ('they', 'PRP'),
#   ('think', 'VBP'),
#   ('im', 'JJ'),
#   ('faking', 'VBG'),
#   ('#', '#'),
#   ('great', 'JJ'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('This', 'DT'),
#   ('lab', 'NN'),
#   ('class', 'NN'),
#   ('boring', 'NN'),
#   ('af', 'NN')],
#  [],
#  [('Feel', 'NNP'),
#   ('like', 'IN'),
#   ('crap', 'NN'),
#   (',', ','),
#   ('tomorrow', 'NN'),
#   ('should', 'MD'),
#   ('be', 'VB'),
#   ('great', 'JJ'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('throathurts', 'NNS'),
#   ('#', '#'),
#   ('allergies', 'NNS')],
#  [],
#  [('If', 'IN'),
#   ('I', 'PRP'),
#   ('could', 'MD'),
#   ('put', 'VB'),
#   ('into', 'IN'),
#   ('words', 'NNS'),
#   ('how', 'WRB'),
#   ('much', 'JJ'),
#   ('I', 'PRP'),
#   ('love', 'VBP'),
#   ('waking', 'VBG'),
#   ('up', 'RP'),
#   ('at', 'IN'),
#   ('5', 'CD'),
#   ('am', 'VBP'),
#   ('on', 'IN'),
#   ('Tuesday', 'NNP'),
#   ("'s", 'POS'),
#   ('I', 'PRP'),
#   ('would', 'MD'),
#   ('...', ':'),
#   ('.', '.'),
#   ('😒', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'NN'),
#   ('.', '.')],
#  [],
#  [('I', 'PRP'),
#   ('actually', 'RB'),
#   ('did', 'VBD'),
#   ('something', 'NN'),
#   ('with', 'IN'),
#   ('my', 'PRP$'),
#   ('hair', 'NN'),
#   ('today', 'NN'),
#   ('#', '#'),
#   ('firsttimeinmonths', 'JJ'),
#   ('#', '#'),
#   ('weird', 'JJ'),
#   ('d', 'NN')],
#  [],
#  [('Thanks', 'NNS'),
#   ('@', 'VBP'),
#   ('PippaCarlson1', 'NNP'),
#   ('your', 'PRP$'),
#   ('tweets', 'NNS'),
#   ('are', 'VBP'),
#   ('great', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ('really', 'RB'),
#   ('admire', 'VB'),
#   ('your', 'PRP$'),
#   ('maturity', 'NN'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('@', 'NN'),
#   ('lilylovehermore', 'NN'),
#   ('I', 'PRP'),
#   ('knew', 'VBD'),
#   ('I', 'PRP'),
#   ("'d", 'MD'),
#   ('heard', 'VB'),
#   ('that', 'DT'),
#   ('name', 'NN'),
#   ('somewhere', 'RB'),
#   ('!', '.')],
#  [],
#  [('I', 'PRP'),
#   ('just', 'RB'),
#   ('love', 'VB'),
#   ('getting', 'VBG'),
#   ('a', 'DT'),
#   ('random', 'JJ'),
#   ('schedule', 'NN'),
#   ('change', 'NN'),
#   ('and', 'CC'),
#   ('not', 'RB'),
#   ('even', 'RB'),
#   ('knowing', 'VBG'),
#   ('about', 'IN'),
#   ('it', 'PRP'),
#   ('!', '.'),
#   (':', ':'),
#   (')', ')'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('China’s', 'NNP'),
#   ('iOS', 'NN'),
#   (',', ','),
#   ('Android', 'NNP'),
#   ('growth', 'NN'),
#   ('up', 'RB'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('400', 'CD'),
#   ('%', 'NN'),
#   ('in', 'IN'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   ('according', 'VBG'),
#   ('to', 'TO'),
#   ('Flurry', 'NNP'),
#   ('.', '.'),
#   ('Chile', 'NNP'),
#   ('is', 'VBZ'),
#   ('2nd', 'CD'),
#   ('at', 'IN'),
#   ('279', 'CD'),
#   ('%', 'NN'),
#   ('.', '.'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/7nj6qiY9', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ("'ve", 'VBP'),
#   ('got', 'VBN'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('my', 'PRP$'),
#   ('money', 'NN'),
#   ('back', 'RB'),
#   ('this', 'DT'),
#   ('time', 'NN'),
#   ('💰🍁👌', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('Will_Piper', 'NNP'),
#   ('should', 'MD'),
#   ('move', 'VB'),
#   ('back', 'RB'),
#   ('up', 'RP'),
#   ('fella', 'NN'),
#   ('.', '.'),
#   ('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('already', 'RB'),
#   ('here', 'RB'),
#   ('...', ':'),
#   ('On', 'IN'),
#   ('my', 'PRP$'),
#   ('own', 'JJ'),
#   ('...', ':'),
#   ('Having', 'VBG'),
#   ('loads', 'NNS'),
#   ('of', 'IN'),
#   ('fun', 'NN'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('To', 'TO'),
#   ('anyone', 'NN'),
#   ('still', 'RB'),
#   ('making', 'VBG'),
#   ('the', 'DT'),
#   ("'Something", 'VBG'),
#   ('about', 'IN'),
#   ('a', 'DT'),
#   ('picture', 'NN'),
#   ('of', 'IN'),
#   ('Andy', 'NNP'),
#   ('Carroll', 'NNP'),
#   ('...', ':'),
#   ('OH', 'NNP'),
#   ('NO', 'NNP'),
#   ('WAIT', 'NNP'),
#   (',', ','),
#   ('IT', 'NNP'),
#   ("'S", 'VBZ'),
#   ('A', 'NNP'),
#   ('HORSE', 'NNP'),
#   ("'", 'POS'),
#   ('joke', 'NN'),
#   (';', ':'),
#   ('stop', 'NN'),
#   ('.', '.')],
#  [],
#  [('@', 'JJ'),
#   ('FrootNL', 'NNP'),
#   ('yess', 'NN'),
#   (',', ','),
#   ('actie', 'JJ'),
#   ('loopt', 'NN'),
#   ('tot', 'NN'),
#   ('24', 'CD'),
#   ('augustus', 'NN'),
#   ('!', '.'),
#   (':', ':'),
#   ('D', 'NNP'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Its', 'PRP$'),
#   ('my', 'PRP$'),
#   ('birthday', 'NN'),
#   ('bitches', 'NNS'),
#   ('...', ':'),
#   ('who', 'WP'),
#   ("'s", 'VBZ'),
#   ('gon', 'NN'),
#   ('na', 'TO'),
#   ('start', 'VB'),
#   ('sucking', 'VBG'),
#   ('my', 'PRP$'),
#   ('dick', 'NN'),
#   ('and', 'CC'),
#   ('who', 'WP'),
#   ("'s", 'VBZ'),
#   ('gon', 'NN'),
#   ('na', 'TO'),
#   ('start', 'VB'),
#   ('sucking', 'VBG'),
#   ('my', 'PRP$'),
#   ('balls', 'NNS'),
#   ('?', '.')],
#  [],
#  [('Tyga', 'NNP'),
#   ('feat', 'NN'),
#   ('.', '.'),
#   ('Kirko', 'NNP'),
#   ('bangz', 'VBD'),
#   ('Out', 'RP'),
#   ('This', 'DT'),
#   ('Bitch', 'NN')],
#  [],
#  [('We', 'PRP'),
#   ('all', 'DT'),
#   ('have', 'VBP'),
#   ('that', 'DT'),
#   ('one', 'CD'),
#   ('person', 'NN'),
#   ('who', 'WP'),
#   ('we', 'PRP'),
#   ('wished', 'VBD'),
#   ('we', 'PRP'),
#   ('never', 'RB'),
#   ('gave', 'VBD'),
#   ('our', 'PRP$'),
#   ('phone', 'NN'),
#   ('number', 'NN'),
#   ('to', 'TO'),
#   ('...', ':'),
#   ('#', '#'),
#   ('Ted', 'NNP')],
#  [],
#  [('Oh', 'UH'),
#   (',', ','),
#   ('love', 'VB'),
#   ('this', 'DT'),
#   ('!', '.'),
#   ('Shaky', 'JJ'),
#   ('camera', 'NN'),
#   (':', ':'),
#   ('Check', 'NNP'),
#   ('RT', 'NNP'),
#   ('@', 'NNP'),
#   ('Hickesy', 'NNP'),
#   ('Fake', 'NNP'),
#   (',', ','),
#   ('of', 'IN'),
#   ('course', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('I', 'PRP'),
#   ('still', 'RB'),
#   ('love', 'VB'),
#   ('this', 'DT'),
#   ('UFO', 'NNP'),
#   ('vid', 'NN'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/n9ju9uM7', 'NN')],
#  [],
#  [('Monitoring', 'VBG'),
#   ('the', 'DT'),
#   ('hashtag', 'NN'),
#   ('#', '#'),
#   ('PhTrenchQuake', 'NNP'),
#   ('stay', 'NN'),
#   ('safe', 'JJ'),
#   ('follow', 'JJ'),
#   ('orders', 'NNS'),
#   ('please', 'VBP')],
#  [],
#  [('@', 'JJ'),
#   ('Students4Obama', 'NNP'),
#   ('If', 'IN'),
#   ('your', 'PRP$'),
#   ('Dad', 'NNP'),
#   ('will', 'MD'),
#   ('let', 'VB'),
#   ('you', 'PRP'),
#   ('sit', 'VB'),
#   ('there', 'RB'),
#   ('#', '#'),
#   ('fadedposter', 'NN')],
#  [],
#  [('Need', 'NN'),
#   ('to', 'TO'),
#   ('play', 'VB'),
#   ('football', 'NN'),
#   ('...', ':'),
#   ('.', '.')],
#  [],
#  [('#', '#'),
#   ('PROJECTRUNWAY', 'NNP'),
#   ('Ven', 'NNP'),
#   ('ur', 'JJ'),
#   ('dress', 'NN'),
#   ('gave', 'VBD'),
#   ('ur', 'JJ'),
#   ('model', 'NN'),
#   ('a', 'DT'),
#   ('3RD', 'CD'),
#   ('BREAST', 'NN'),
#   ('!', '.'),
#   ('Nice', 'NNP'),
#   (',', ','),
#   ('just', 'RB'),
#   ('what', 'WP'),
#   ('every', 'DT'),
#   ('gal', 'NN'),
#   ('wants', 'VBZ'),
#   ('!', '.'),
#   ('u', 'JJ'),
#   ('sure', 'JJ'),
#   ('know', 'VBP'),
#   ('design', 'NN'),
#   ('better', 'RBR'),
#   ('than', 'IN'),
#   ('women', 'NNS'),
#   ('!', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('RumaisaMohani', 'NNP'),
#   ('@', 'NNP'),
#   ('ShaiziCheema', 'NNP'),
#   ('-', ':'),
#   ('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('sure', 'JJ'),
#   ('mr', 'NN'),
#   ('Raja', 'NNP'),
#   ('rental', 'NN'),
#   ('would', 'MD'),
#   ('have', 'VB'),
#   ('a', 'DT'),
#   ('nice', 'JJ'),
#   ('profitable', 'JJ'),
#   ('scheme', 'NN'),
#   ('in', 'IN'),
#   ('mind', 'NN'),
#   ('#', '#'),
#   ('Sarcasm', 'NNP')],
#  [],
#  [('I', 'PRP'),
#   ('want', 'VBP'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('here', 'RB'),
#   ('...', ':'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/Q9bFkxsE', 'NN')],
#  [],
#  [('Omg', 'NNP'),
#   ('most', 'JJS'),
#   ('insane', 'JJ'),
#   ('matriculants', 'NNS'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('rather', 'RB'),
#   ('play', 'VBD'),
#   ('soccer', 'NN'),
#   ('than', 'IN'),
#   ('study', '$'),
#   ('4', 'CD'),
#   ('prelims=D', 'NN'),
#   ('@', 'NNP'),
#   ('SadieRazak', 'NNP'),
#   (',', ','),
#   ('@', 'NNP'),
#   ('Cocoz_25', 'NNP'),
#   (',', ','),
#   ('@', 'NNP'),
#   ('xFatima_s', 'NNP'),
#   (',', ','),
#   ('@', 'NNP'),
#   ('TasneemKarolia', 'NNP'),
#   (',', ','),
#   ('#', '#'),
#   ('Soccer4lyf♥', 'NNP')],
#  [],
#  [('@', 'JJ'),
#   ('BertLcfc', 'NNP'),
#   ('lookin', 'FW'),
#   ('forward', 'NN'),
#   ('to', 'TO'),
#   ('satday', 'VB'),
#   ('as', 'RB'),
#   ('well', 'RB'),
#   ('nothin', 'IN'),
#   ('quite', 'RB'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('5.20', 'CD'),
#   ('kick', 'NN'),
#   ('off', 'RB'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Yay', 'IN'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('3', 'CD'),
#   ('hour', 'NN'),
#   ('clinical', 'JJ'),
#   ('day', 'NN'),
#   ('.', '.'),
#   ('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('so', 'RB'),
#   ('freaking', 'JJ'),
#   ('excited', 'JJ'),
#   ('I', 'PRP'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('stand', 'VB'),
#   ('it', 'PRP'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ('love', 'VBP'),
#   ('it', 'PRP'),
#   ('whenever', 'WRB'),
#   ('my', 'PRP$'),
#   ('brother', 'NN'),
#   ('gets', 'VBZ'),
#   ('up', 'RP'),
#   ('and', 'CC'),
#   ('turns', 'NNS'),
#   ('on', 'IN'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('lights', 'NNS'),
#   ('...', ':'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('#', '#'),
#   ('10TurnOns', 'CD'),
#   ('Yet', 'RB'),
#   ('again', 'RB'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('list', 'VBP'),
#   ('them', 'PRP'),
#   ('on', 'IN'),
#   ('twitter', 'NN'),
#   ('you', 'PRP'),
#   ("'re", 'VBP'),
#   ('garbage', 'NN'),
#   ('.', '.')],
#  [],
#  [('Just', 'RB'),
#   ('sprained', 'VBN'),
#   ('my', 'PRP$'),
#   ('foot', 'NN'),
#   ('.', '.'),
#   ('happy', 'JJ'),
#   ('days', 'NNS'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('_jackpeters', 'NNS'),
#   ('hahaha', 'VBP'),
#   ('mannn', 'NN'),
#   ('gota', 'NN'),
#   ('have', 'VBP'),
#   ('his', 'PRP$'),
#   ('slices', 'NNS'),
#   ('yooo', 'RB'),
#   ('!', '.')],
#  [],
#  [('Thank', 'NNP'),
#   ('god', 'NN'),
#   ('I', 'PRP'),
#   ('invested', 'VBD'),
#   ('in', 'IN'),
#   ('an', 'DT'),
#   ('umbrella', 'NN'),
#   ('this', 'DT'),
#   ('year', 'NN'),
#   ('.', '.')],
#  [],
#  [('A', 'DT'),
#   ('little', 'JJ'),
#   ('nervous', 'JJ'),
#   ('to', 'TO'),
#   ('start', 'VB'),
#   ('school', 'NN'),
#   ('😝', 'RB'),
#   ('5', 'CD'),
#   ('classes', 'NNS'),
#   ('in', 'IN'),
#   ('one', 'CD'),
#   ('day', 'NN'),
#   ('should', 'MD'),
#   ('be', 'VB'),
#   ('fun', 'NN'),
#   ('...', ':')],
#  [],
#  [('Authentic', 'JJ'),
#   ('Volk', 'NNP'),
#   ('RE30', 'NNP'),
#   ("'s", 'POS'),
#   ('.', '.'),
#   ('18x9.5', 'CD'),
#   ('+25', 'NN'),
#   ('.', '.'),
#   ('Flat', 'JJ'),
#   ('Gunmetal', 'NNP'),
#   ('Finish', 'NNP'),
#   ('.', '.'),
#   ('Comes', 'NNP'),
#   ('with', 'IN'),
#   ('Center', 'NNP'),
#   ('caps', 'VBP'),
#   ('&', 'CC'),
#   ('amp', 'VBP'),
#   (';', ':'),
#   ('Valve', 'NNP'),
#   ('Stems', 'NNP'),
#   ('.', '.'),
#   ('$', '$'),
#   ('2400', 'CD'),
#   ('OBO', 'NNP'),
#   ('...', ':'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/xCr9IQCd', 'NN')],
#  [],
#  [('You', 'PRP'),
#   ('know', 'VBP'),
#   ('what', 'WP'),
#   ('I', 'PRP'),
#   ('love', 'VBP'),
#   ('doing', 'VBG'),
#   ('?', '.'),
#   ('Rehashing', 'VBG'),
#   ('old', 'JJ'),
#   ('arguments', 'NNS'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('``', '``'),
#   ('@', 'JJ'),
#   ('skysports_bryan', 'NN'),
#   (':', ':'),
#   ('We', 'PRP'),
#   ("'re", 'VBP'),
#   ('told', 'JJ'),
#   ('Swansea', 'NNP'),
#   ('and', 'CC'),
#   ('Manchester', 'NNP'),
#   ('City', 'NNP'),
#   ('unable', 'JJ'),
#   ('to', 'TO'),
#   ('reach', 'VB'),
#   ('agreement', 'NN'),
#   ('on', 'IN'),
#   ('Scott', 'NNP'),
#   ('Sinclair', 'NNP'),
#   ('.', '.'),
#   ("''", "''"),
#   ('What.a.shame', 'NNP'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('When', 'WRB'),
#   ('I', 'PRP'),
#   ('really', 'RB'),
#   ('wana', 'VBP'),
#   ('sleep', 'JJ'),
#   ('n', 'NN'),
#   ('ppl', 'NN'),
#   ('wana', 'NN'),
#   ('chat✗', 'NN')],
#  [],
#  [('Cynical', 'JJ'),
#   ('me', 'PRP'),
#   ('sees', 'VBZ'),
#   ('the', 'DT'),
#   ('Trinity-Spadina', 'NNP'),
#   ('riding', 'NN'),
#   ('being', 'VBG'),
#   ('mostly', 'RB'),
#   ('left', 'VBN'),
#   ('alone', 'RB'),
#   ('despite', 'IN'),
#   ('pop', 'NN'),
#   ('.', '.'),
#   ('growth', 'NN'),
#   ('because', 'IN'),
#   ('splitting', 'VBG'),
#   ('it', 'PRP'),
#   ('would', 'MD'),
#   ("n't", 'RB'),
#   ('help', 'VB'),
#   ('the', 'DT'),
#   ('CPC', 'NNP'),
#   ('.', '.'),
#   ('#', '#'),
#   ('CDNPoli', 'NNP')],
#  [],
#  [('@', 'NN'),
#   ('iAM_MissJackson', 'NN'),
#   ('well', 'RB'),
#   ('I', 'PRP'),
#   ('guess', 'VBP'),
#   ('because', 'IN'),
#   ('they', 'PRP'),
#   ('were', 'VBD'),
#   ('missing', 'VBG'),
#   ('pleasure', 'NN'),
#   ('p', 'NN'),
#   ('.', '.')],
#  [],
#  [('I', 'PRP'),
#   ('just', 'RB'),
#   ('love', 'VB'),
#   ('getting', 'VBG'),
#   ('up', 'RP'),
#   ('this', 'DT'),
#   ('early', 'JJ'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('into', 'IN'),
#   ('school', 'NN'),
#   ('#', '#'),
#   ('sarcasm', 'NN'),
#   ('#', '#'),
#   ('sotired', 'VBD'),
#   ('#', '#'),
#   ('killme', 'NN'),
#   (':', ':'),
#   ('/', 'NN')],
#  [],
#  [('Dear', 'NNP'),
#   ('Teva', 'NNP'),
#   (',', ','),
#   ('thank', 'NN'),
#   ('you', 'PRP'),
#   ('for', 'IN'),
#   ('waking', 'VBG'),
#   ('me', 'PRP'),
#   ('up', 'IN'),
#   ('every', 'DT'),
#   ('few', 'JJ'),
#   ('hours', 'NNS'),
#   ('by', 'IN'),
#   ('howling', 'VBG'),
#   ('.', '.'),
#   ('Your', 'PRP$'),
#   ('just', 'RB'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('mother', 'JJ'),
#   ('natures', 'NNS'),
#   ('alarm', 'VBP'),
#   ('clock', 'NN'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('MarkPacker', 'NNP'),
#   ('Yeah', 'NNP'),
#   (',', ','),
#   ('but', 'CC'),
#   ('Beckett', 'NNP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('guy', 'NN'),
#   ('that', 'WDT'),
#   ('just', 'RB'),
#   ('makes', 'VBZ'),
#   ('you', 'PRP'),
#   ('want', 'VBP'),
#   ('to', 'TO'),
#   ('root', 'VB'),
#   ('for', 'IN'),
#   ('him', 'PRP'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('My', 'PRP$'),
#   ('favourite', 'JJ'),
#   ('pre-work', 'JJ'),
#   ('job', 'NN'),
#   (':', ':'),
#   ('fixing', 'VBG'),
#   ('a', 'DT'),
#   ('punctured', 'VBN'),
#   ('bike', 'NN'),
#   ('tyre', 'NN'),
#   ('.', '.'),
#   ('#', '#'),
#   ('Sarcasm', 'NNP')],
#  [],
#  [('@', 'JJ'),
#   ('haileytanley', 'NN'),
#   ('Good', 'JJ'),
#   ('!', '.'),
#   ('I', 'PRP'),
#   ('will', 'MD'),
#   ('give', 'VB'),
#   ('details', 'NNS'),
#   ('later', 'RB')],
#  [],
#  [('@', 'JJ'),
#   ('justkramer', 'NN'),
#   ('good', 'NN'),
#   ('you', 'PRP'),
#   ("'ll", 'MD'),
#   ('save', 'VB'),
#   ('more', 'JJR'),
#   ('money', 'NN'),
#   ('that', 'IN'),
#   ('way', 'NN'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('@', 'NN'),
#   ('xBig_Dawgg', 'NN'),
#   ('made', 'VBD'),
#   ('the', 'DT'),
#   ('semi', 'JJ'),
#   ('pro', 'JJ'),
#   ('team', 'NN'),
#   ('bruh', 'NN'),
#   ('ran', 'VBD'),
#   ('a', 'DT'),
#   ('4.54', 'CD')],
#  [],
#  [('Well', 'RB'),
#   (',', ','),
#   ('today', 'NN'),
#   ('has', 'VBZ'),
#   ('started', 'VBN'),
#   ('of', 'IN'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('WONDERFUL', 'NNP'),
#   ('start', 'NN'),
#   ('.', '.'),
#   ('#', '#'),
#   ('Sarcasm', 'NNP')],
#  [],
#  [('@', 'JJ'),
#   ('ashvichotai', 'NN'),
#   ('Thankyouu', 'NN'),
#   ('!', '.'),
#   ('my', 'PRP$'),
#   ('dad', 'NN'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('understand', 'VB'),
#   ('why', 'WRB'),
#   ('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('so', 'RB'),
#   ('pleased', 'JJ'),
#   ('with', 'IN'),
#   ('that', 'DT'),
#   ('result', 'NN'),
#   ('!', '.'),
#   ('Haha', 'NNP'),
#   ('xx', 'NN')],
#  [],
#  [('#', '#'),
#   ('sarcasm', 'NN'),
#   ('...', ':'),
#   ('.learn', 'VBP'),
#   ('it', 'PRP')],
#  [],
#  [('What', 'WP'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('?', '.'),
#   ('Help', 'VB'),
#   ('please', 'VB'),
#   ('@', 'NNP'),
#   ('BlackBerryHelp', 'NNP'),
#   ('@', 'NNP'),
#   ('BlackBerryPH', 'NNP'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/8uX92LQU', 'NN')],
#  [],
#  [('``', '``'),
#   ('Everything', 'NN'),
#   ('Happens', 'VBZ'),
#   ('For', 'IN'),
#   ('A', 'DT'),
#   ('Reason', 'NNP'),
#   ("''", "''"),
#   ('..', 'NN'),
#   ('Yeah', 'NNP'),
#   ('I', 'PRP'),
#   ('Just', 'VBP'),
#   ('Fall', 'DT'),
#   ('Down', 'RP'),
#   ('The', 'DT'),
#   ('Fucking', 'NNP'),
#   ('Stairs', 'NNP'),
#   ('So', 'NNP'),
#   ('I', 'PRP'),
#   ('Went', 'VBP'),
#   ('To', 'TO'),
#   ('Hospital', 'NNP'),
#   ('On', 'IN'),
#   ('Purpose', 'NNP'),
#   ('.', '.'),
#   ('#', '#'),
#   ('Sarcasm', 'NNP'),
#   ('.', '.')],
#  [],
#  [('everyone', 'NN'),
#   ('please', 'NN'),
#   ('request', 'NN'),
#   ('#', '#'),
#   ('FashionIsMyKryptonite', 'NNP'),
#   ('by', 'IN'),
#   ('@', 'NNP'),
#   ('Zendaya96', 'NNP'),
#   ('&', 'CC'),
#   ('amp', 'NN'),
#   (';', ':'),
#   ('@', 'CC'),
#   ('bellathorne', 'NN'),
#   ('!', '.'),
#   ('!', '.'),
#   ('!', '.'),
#   ('so', 'IN'),
#   ('it', 'PRP'),
#   ('reaches', 'VBZ'),
#   ('the', 'DT'),
#   ('DCT3', 'NNP'),
#   ("'s", 'POS'),
#   ('#', '#'),
#   ('1', 'CD'),
#   ('spot', 'NN'),
#   (':', ':'),
#   (')', ')'),
#   ('&', 'CC'),
#   ('gt', 'NN'),
#   (';', ':'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/SaBwSsLQ', 'NN')],
#  [],
#  [('Watching', 'VBG'),
#   ('the', 'DT'),
#   ('cuddleys', 'NN'),
#   ('@', 'NNP'),
#   ('torycover', 'RB'),
#   ('#', '#'),
#   ('babytv', 'JJ'),
#   ('#', '#'),
#   ('thatshowweroll', 'NN'),
#   ('!', '.')],
#  [],
#  [('Anzhi', 'NNP'),
#   ('join', 'NN'),
#   ('#', '#'),
#   ('LFC', 'NNP'),
#   (',', ','),
#   ('BSC', 'NNP'),
#   ('Young', 'NNP'),
#   ('Boys', 'NNP'),
#   ('&', 'CC'),
#   ('amp', 'NN'),
#   (';', ':'),
#   ('Udinese', 'NNP'),
#   ('in', 'IN'),
#   ('Group', 'NNP'),
#   ('A', 'NNP'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Europa', 'NNP'),
#   ('League', 'NNP'),
#   ('.', '.'),
#   ('Bring', 'NNP'),
#   ('them', 'PRP'),
#   ('on', 'IN'),
#   (',', ','),
#   ('redmen', 'NNS'),
#   ('!', '.'),
#   ('#', '#'),
#   ('ynwa', 'NN')],
#  [],
#  [('@', 'NN'),
#   ('JonnyBones', 'NNS'),
#   ('stay', 'VBP'),
#   ('humble', 'JJ'),
#   (',', ','),
#   ('but', 'CC'),
#   ('u', 'JJ'),
#   ('turning', 'VBG'),
#   ('down', 'RP'),
#   ('that', 'DT'),
#   ('fight', 'NN'),
#   ('is', 'VBZ'),
#   ('your', 'PRP$'),
#   ('choice', 'NN'),
#   ('no', 'DT'),
#   ('one', 'NN'),
#   ('else', 'RB'),
#   ("'s", 'VBZ'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('not', 'RB'),
#   ('like', 'IN'),
#   ('you', 'PRP'),
#   ('have', 'VBP'),
#   ('the', 'DT'),
#   ('title', 'NN'),
#   ('oranything', 'VBG'),
#   ('haha', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ('think', 'VBP'),
#   ('#', '#'),
#   ('ReachForTheStars', 'NNP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('next', 'JJ'),
#   ('single', 'JJ'),
#   ('from', 'IN'),
#   ('@', 'NNP'),
#   ('iamwill', 'NN'),
#   ('featuring', 'VBG'),
#   ('@', 'JJ'),
#   ('britneyspears', 'NNS'),
#   ('...', ':'),
#   ('..just', 'JJ'),
#   ('look', 'VBP'),
#   ('britney', 'NN'),
#   ("'s", 'POS'),
#   ('last', 'JJ'),
#   ('tweet', 'NN')],
#  [],
#  [('CINCINNATI', 'NNP'),
#   ('(', '('),
#   ('AP', 'NNP'),
#   (')', ')'),
#   ('--', ':'),
#   ('Lunar', 'JJ'),
#   ('pioneers', 'NNS'),
#   ('plan', 'VBP'),
#   ('to', 'TO'),
#   ('attend', 'VB'),
#   ('a', 'DT'),
#   ('private', 'JJ'),
#   ('service', 'NN'),
#   ('in', 'IN'),
#   ('Ohio', 'NNP'),
#   ('for', 'IN'),
#   ('astronaut', 'JJ'),
#   ('Neil', 'NNP'),
#   ('Armstrong', 'NNP'),
#   (',', ','),
#   ('fol', 'NN'),
#   ('...', ':'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/UeAPQzvK', 'NN')],
#  [],
#  [('You', 'PRP'),
#   ('jogging', 'VBG'),
#   ('ah', 'VB'),
#   ('?', '.'),
#   ('No', 'DT'),
#   ('la', 'NN'),
#   ('i', 'VBZ'),
#   ('dancing', 'VBG'),
#   ('*started', 'VBN'),
#   ('dancing*', 'JJ'),
#   ('#', '#'),
#   ('Sarcasm', 'NNP')],
#  [],
#  [('Everybody', 'NN'),
#   ('go', 'VBP'),
#   ('follow', 'JJ'),
#   ('my', 'PRP$'),
#   ('nigguh', 'JJ'),
#   ('@', 'JJ'),
#   ('andrepreid', 'NN'),
#   ('!', '.')],
#  [],
#  [('I', 'PRP'),
#   ('liked', 'VBD'),
#   ('a', 'DT'),
#   ('@', 'JJ'),
#   ('YouTube', 'NNP'),
#   ('video', 'NN'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/DpZhl8WC', 'NN'),
#   ('Trey', 'NNP'),
#   ('Songz', 'NNP'),
#   ('-', ':'),
#   ('Heart', 'NNP'),
#   ('Attack', 'NNP'),
#   ('[', 'NNP'),
#   ('Official', 'NNP'),
#   ('Video', 'NNP'),
#   (']', 'NNP')],
#  [],
#  [('but', 'CC'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('cool', 'JJ'),
#   ('never', 'RB'),
#   ('again', 'RB')],
#  [],
#  [('From', 'IN'),
#   ('Hanamasa', 'NNP'),
#   ('with', 'IN'),
#   ('MUM', 'NNP'),
#   ('Family', 'NNP'),
#   ('.', '.'),
#   ('Whadda', 'NNP'),
#   ('great', 'JJ'),
#   ('moment', 'NN'),
#   (':', ':'),
#   (')', ')'),
#   ('Menu', 'NNP'),
#   ('for', 'IN'),
#   ('today', 'NN'),
#   (':', ':'),
#   ('4', 'CD'),
#   ('sehat', 'WP'),
#   ('5', 'CD'),
#   ('semaput', 'NN'),
#   (':', ':'),
#   ('D', 'NNP'),
#   ('#', '#'),
#   ('gagaldiet', 'JJ')],
#  [],
#  [('You', 'PRP'),
#   ("'re", 'VBP'),
#   ('dragged', 'VBN'),
#   ('down', 'RP'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('very', 'RB'),
#   ('people', 'NNS'),
#   ('who', 'WP'),
#   ('claim', 'VBP'),
#   ('they', 'PRP'),
#   ("'re", 'VBP'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('inspire', 'VB'),
#   ('.', '.')],
#  [],
#  [('while', 'IN'),
#   ('I', 'PRP'),
#   ('was', 'VBD'),
#   ('working', 'VBG'),
#   ('for', 'IN'),
#   ('that', 'DT'),
#   ('...', ':'),
#   ('yeah', 'NN'),
#   ('!', '.'),
#   ('“', 'JJ'),
#   ('@', 'JJ'),
#   ('baperebel', 'NN'),
#   (':', ':'),
#   ('@', 'NN'),
#   ('NemoAchida', 'NNP'),
#   ('-', ':'),
#   ('``', '``'),
#   ('My', 'PRP$'),
#   ('hands', 'NNS'),
#   ('almost', 'RB'),
#   ('got', 'VBD'),
#   ('cut', 'VBN'),
#   ('up', 'RP'),
#   ('today..', 'NN'),
#   ("''", "''"),
#   ('”', 'NN')],
#  [],
#  [('Love', 'VB'),
#   ('the', 'DT'),
#   ('political', 'JJ'),
#   ('advice', 'NN'),
#   ('on', 'IN'),
#   ('Twitter', 'NNP'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('getinformed', 'VBD')],
#  [],
#  [('@', 'JJ'),
#   ('KyleLove74', 'NNP'),
#   ('Nope', 'NNP'),
#   (',', ','),
#   ('I', 'PRP'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('stand', 'VB'),
#   ('to', 'TO'),
#   ('lick', 'VB'),
#   ('envelopes', 'NNS'),
#   ('either', 'CC'),
#   ('...', ':'),
#   ('..yuck', 'NN'),
#   ('!', '.')],
#  [],
#  [('Pretty', 'RB'),
#   ('excited', 'VBN'),
#   ('about', 'IN'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('activities', 'NNS'),
#   ('Tom', 'NNP'),
#   ('&', 'CC'),
#   ('amp', 'NN'),
#   (';', ':'),
#   ('I', 'PRP'),
#   ('came', 'VBD'),
#   ('up', 'RP'),
#   ('with', 'IN'),
#   ('for', 'IN'),
#   ('veteran', 'NN'),
#   ('training', 'NN'),
#   ('.', '.'),
#   ('#', '#'),
#   ('surprises', 'NNS'),
#   ('.', '.')],
#  [],
#  [('Hey', 'NNP'),
#   (',', ','),
#   ('hi', 'NN'),
#   ('.', '.'),
#   ('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('here', 'RB'),
#   ('to', 'TO'),
#   ('look', 'VB'),
#   ('pretty', 'RB'),
#   ('and', 'CC'),
#   ('insult', 'VB'),
#   ('your', 'PRP$'),
#   ('intelligence', 'NN'),
#   ('.', '.'),
#   ('[', 'CC'),
#   ('insert', 'JJ'),
#   ('something', 'NN'),
#   ('insulting', 'VBG'),
#   ('to', 'TO'),
#   ('your', 'PRP$'),
#   ('intelligence', 'NN'),
#   ('and', 'CC'),
#   ('hairflip', 'NN'),
#   ('here', 'RB'),
#   (']', 'RB'),
#   ('#', '#'),
#   ('Sarcasm', 'NNP')],
#  [],
#  [('I', 'PRP'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('wait', 'VB'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('oyster', 'NN'),
#   ('fest', 'JJS'),
#   ('^.^', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Those', 'DT'),
#   ('dreams', 'NNS'),
#   ('were', 'VBD'),
#   ('beyond', 'IN'),
#   ('f-ed', 'JJ'),
#   ('up', 'IN'),
#   ('last', 'JJ'),
#   ('night', 'NN'),
#   ('.', '.'),
#   ('#', '#'),
#   ('GreatStartForTheDay', 'NNP'),
#   ('#', '#'),
#   ('Sarcasm', 'NNP'),
#   ('😔', 'NN')],
#  [],
#  [('Dirt', 'NNP'),
#   ('under', 'IN'),
#   ('your', 'PRP$'),
#   ('finger', 'NN'),
#   ('nails', 'NNS'),
#   ('has', 'VBZ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('the', 'DT'),
#   ('most', 'RBS'),
#   ('disgusting', 'JJ'),
#   ('looking', 'VBG'),
#   ('thing', 'NN'),
#   ('ever', 'RB')],
#  [],
#  [('Spending', 'VBG'),
#   ('the', 'DT'),
#   ('night', 'NN'),
#   ('in', 'IN'),
#   ('NA', 'NNP'),
#   ('...', ':'),
#   ('#', '#'),
#   ('wooo', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ('wan', 'VBP'),
#   ('na', 'RB'),
#   ('go', 'VB'),
#   ('to', 'TO'),
#   ('an', 'DT'),
#   ('american', 'JJ'),
#   ('school', 'NN'),
#   ('omg', 'NN'),
#   (':', ':'),
#   ('(', '(')],
#  [],
#  [('@', 'JJ'),
#   ('heynikole', 'NN'),
#   ('twitter', 'NN'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('your', 'PRP$'),
#   ('personal', 'JJ'),
#   ('diary', 'NN'),
#   (',', ','),
#   ('you', 'PRP'),
#   ('should', 'MD'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('more', 'JJR'),
#   ('vague', 'JJ'),
#   ('...', ':'),
#   ('#', '#'),
#   ('sarcasm', 'NN'),
#   ('when', 'WRB'),
#   ('are', 'VBP'),
#   ('you', 'PRP'),
#   ('coming', 'VBG'),
#   ('to', 'TO'),
#   ('meeeee', 'VB')],
#  [],
#  [('Booty', 'NNP'),
#   ('call', 'NN'),
#   ('has', 'VBZ'),
#   ('successfully', 'RB'),
#   ('been', 'VBN'),
#   ('completed', 'VBN'),
#   ('xD', 'JJ'),
#   ('wowwwwwww', 'NN'),
#   ('@', 'NN'),
#   ('purrrtyRinT', 'NN')],
#  [],
#  [('Gon', 'NNP'),
#   ('na', 'TO'),
#   ('have', 'VB'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('another', 'DT'),
#   ('unfollow', 'JJ'),
#   ('spree', 'NN'),
#   ('later', 'RB'),
#   ('today', 'NN'),
#   (',', ','),
#   ('yeah', 'UH'),
#   (',', ','),
#   ('those', 'DT'),
#   ('are', 'VBP'),
#   ('always', 'RB'),
#   ('fun', 'RB'),
#   ('.', '.'),
#   ('#', '#'),
#   ('Sarcasm', 'NNP'),
#   ('#', '#'),
#   ('DamnYouFollowLimit', 'NNP')],
#  [],
#  [('I', 'PRP'),
#   ('love', 'VBP'),
#   ('finding', 'VBG'),
#   ('out', 'RP'),
#   ('who', 'WP'),
#   ('your', 'PRP$'),
#   ('true', 'JJ'),
#   ('friends', 'NNS'),
#   ('are', 'VBP'),
#   ('.', '.'),
#   ('It', 'PRP'),
#   ("'s", 'VBZ'),
#   ('seriously', 'RB'),
#   ('just', 'RB'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('.', '.'),
#   ('(', '('),
#   (':', ':')],
#  [('#', '#'), ('sarcasm', 'NN')],
#  [],
#  [('The', 'DT'),
#   ('school', 'NN'),
#   ('board', 'NN'),
#   ("'s", 'POS'),
#   ('wisest', 'JJS'),
#   ('budget', 'NN'),
#   ('cut', 'NN'),
#   ('has', 'VBZ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('the', 'DT'),
#   ('one', 'NN'),
#   ('that', 'WDT'),
#   ('includes', 'VBZ'),
#   ('new', 'JJ'),
#   ('MacBook', 'NNP'),
#   ("'s", 'POS'),
#   ('for', 'IN'),
#   ('faculty', 'NN'),
#   ('members', 'NNS'),
#   ('...', ':'),
#   ('#', '#'),
#   ('Sarcasm', 'NNP')],
#  [],
#  [('We', 'PRP'),
#   ("'re", 'VBP'),
#   ('hiring', 'VBG'),
#   ('a', 'DT'),
#   ('new', 'JJ'),
#   ('Kiosk', 'NNP'),
#   ('Supervisor', 'NNP'),
#   ('!', '.'),
#   ('Think', 'VBP'),
#   ('you', 'PRP'),
#   ('have', 'VBP'),
#   ('what', 'WP'),
#   ('it', 'PRP'),
#   ('takes', 'VBZ'),
#   ('?', '.'),
#   ('Then', 'RB'),
#   ('apply', 'VB'),
#   ('!', '.')],
#  [],
#  [('http', 'NN'), (':', ':'), ('//t.co/QpSGVw8i', 'NN')],
#  [],
#  [('Deadline', 'NNP'),
#   ('is', 'VBZ'),
#   ('September', 'NNP'),
#   ('7th', 'CD'),
#   (',', ','),
#   ('at', 'IN'),
#   ('Noon', 'NN'),
#   ('!', '.')],
#  [],
#  [('@', 'NN'),
#   ('Vicsterrrrr', 'NNP'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('mint', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('reniueo', 'NN'),
#   ('reply', 'NN'),
#   ('via', 'IN'),
#   ('bbm', 'NN'),
#   ('ya', 'NN'),
#   ('renee', 'NN'),
#   ('hihi', 'NN')],
#  [],
#  [('``', '``'),
#   ('God', 'NNP'),
#   ('will', 'MD'),
#   ('supply', 'VB'),
#   ('us', 'PRP'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('opportunity', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('up', 'RP'),
#   ('to', 'TO'),
#   ('us', 'PRP'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('something', 'NN'),
#   ('with', 'IN'),
#   ('it', 'PRP'),
#   ('.', '.'),
#   ("''", "''")],
#  [],
#  [('People', 'NNS'),
#   ('protesting', 'VBG'),
#   ('in', 'IN'),
#   ('favour', 'NN'),
#   ('of', 'IN'),
#   ('``', '``'),
#   ('men', 'NNS'),
#   ("'s", 'POS'),
#   ('affairs', 'NNS'),
#   ("''", "''"),
#   ('in', 'IN'),
#   ('front', 'NN'),
#   ('of', 'IN'),
#   ('Parliament', 'NNP'),
#   ('-', ':'),
#   ('yes', 'UH'),
#   (',', ','),
#   ('the', 'DT'),
#   ('poor', 'JJ'),
#   ('plight', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('middle', 'JJ'),
#   ('class', 'NN'),
#   ('white', 'JJ'),
#   ('man', 'NN'),
#   ('...', ':'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('If', 'IN'),
#   ('you', 'PRP'),
#   ('appreciate', 'VBP'),
#   ('my', 'PRP$'),
#   ('nerdy', 'JJ'),
#   ('tendencies', 'NNS'),
#   ('#', '#'),
#   ('TheLoveIsReal', 'NNP')],
#  [],
#  [('Traveling', 'VBG'),
#   ('first', 'JJ'),
#   ('class', 'NN'),
#   ('from', 'IN'),
#   ('Paris', 'NNP'),
#   ('.', '.'),
#   ('Is', 'VBZ'),
#   ('it', 'PRP'),
#   ('worth', 'IN'),
#   ('the', 'DT'),
#   ('price', 'NN'),
#   ('?', '.'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/06dnax39', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ('keep', 'VBP'),
#   ('waking', 'VBG'),
#   ('up', 'RP'),
#   ('and', 'CC'),
#   ('falling', 'VBG'),
#   ('back', 'RB'),
#   ('to', 'TO'),
#   ('sleep', 'VB')],
#  [],
#  [('@', 'JJ'),
#   ('flemingsean', 'NN'),
#   ('had', 'VBD'),
#   ('an', 'DT'),
#   ('ex', 'NN'),
#   ('who', 'WP'),
#   ('worked', 'VBD'),
#   ('at', 'IN'),
#   ('VNU', 'NNP'),
#   ('...', ':'),
#   ('#', '#'),
#   ('fantasticfact', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('edstetzer', 'NN'),
#   (':', ':'),
#   ('Only', 'RB'),
#   ('took', 'VBD'),
#   ('you', 'PRP'),
#   ('14', 'CD'),
#   ('mins', 'NNS'),
#   ('to', 'TO'),
#   ('decide', 'VB'),
#   ('?', '.'),
#   ('I', 'PRP'),
#   ('can', 'MD'),
#   ('only', 'RB'),
#   ('hope', 'VB'),
#   ('you', 'PRP'),
#   ('give', 'VB'),
#   ('the', 'DT'),
#   ('DNC', 'NNP'),
#   ('equal', 'JJ'),
#   ('time', 'NN'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Slapen', 'NNP'), ('#', '#'), ('twexit', 'NN')],
#  [],
#  [('In', 'IN'),
#   ('a', 'DT'),
#   ('bit', 'NN'),
#   ('of', 'IN'),
#   ('initially', 'RB'),
#   ('unplanned', 'JJ'),
#   ('synergy', 'NN'),
#   (',', ','),
#   ('@', 'NNP'),
#   ('RotoPat', 'NNP'),
#   ('breaks', 'VBZ'),
#   ('down', 'RP'),
#   ('the', 'DT'),
#   ('@', 'JJ'),
#   ('Rotoworld_BB', 'NNP'),
#   ('crew', 'NN'),
#   ("'s", 'POS'),
#   ('recent', 'JJ'),
#   ('NFL', 'NNP'),
#   ('slow', 'NN'),
#   ('draft', 'NN'),
#   (':', ':'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/Aknvzfnb', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ('love', 'VBP'),
#   ('when', 'WRB'),
#   ('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('doing', 'VBG'),
#   ('dishes', 'NNS'),
#   ('at', 'IN'),
#   ('work', 'NN'),
#   ('&', 'CC'),
#   ('amp', 'NN'),
#   (';', ':'),
#   ('the', 'DT'),
#   ('water', 'NN'),
#   ('spills', 'VBZ'),
#   ('all', 'DT'),
#   ('over', 'IN'),
#   ('me', 'PRP'),
#   (',', ','),
#   ('its', 'PRP$'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Being', 'VBG'),
#   ('awake', 'VB'),
#   ('this', 'DT'),
#   ('early', 'JJ'),
#   ('to', 'TO'),
#   ('pack', 'VB'),
#   ('up', 'RP'),
#   ('my', 'PRP$'),
#   ('stuff', 'NN'),
#   ('and', 'CC'),
#   ('move', 'NN'),
#   ('rooms', 'NNS'),
#   ('sucks', 'NNS'),
#   ('.', '.'),
#   ('But', 'CC'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('plus', 'JJ'),
#   ('side', 'NN'),
#   (',', ','),
#   ('FAIR', 'NNP'),
#   ('TODAY', 'NNP'),
#   ('!', '.'),
#   ('😄', 'NN'),
#   ('#', '#'),
#   ('soexcited', 'VBD'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('😣', 'NNP'),
#   ('#', '#'),
#   ('carnilife', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ('like', 'VBP'),
#   ('the', 'DT'),
#   ('way', 'NN'),
#   ('you', 'PRP'),
#   ('french..', 'VBP'),
#   ('Inhale', 'NNP'),
#   (',', ','),
#   ('do', 'VBP'),
#   ('it', 'PRP'),
#   ('again', 'RB'),
#   ('❤', 'VBD')],
#  [],
#  [('Love', 'VB'),
#   ('you', 'PRP'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('this', 'DT'),
#   ('#', '#'),
#   ('kodeASIKASIK', 'VB'),
#   ('*poke', 'NNP'),
#   ('@', 'NNP'),
#   ('denis_aqsa', 'NN'),
#   (':', ':'),
#   ('p', 'NN'),
#   ('hahah', 'NN')],
#  [],
#  [('At', 'IN'),
#   ('Least', 'JJS'),
#   ('The', 'DT'),
#   ('Line', 'NNP'),
#   ('In', 'IN'),
#   ('The', 'DT'),
#   ('Book', 'NNP'),
#   ('Store', 'NNP'),
#   ('Is', 'VBZ'),
#   ("n't", 'RB'),
#   ('Long', 'NNP'),
#   ('.', '.'),
#   ('-___-', 'NN'),
#   ('#', '#'),
#   ('Sarcasm', 'NNP')],
#  [],
#  [('@', 'NN'),
#   ('amirahhMartin', 'NN'),
#   ('thats', 'NNS'),
#   ('just', 'RB'),
#   ('who', 'WP'),
#   ('i', 'VBP'),
#   ('ammm', 'VBP'),
#   (':', ':'),
#   ('/', 'NN'),
#   ('i', 'NN'),
#   ('help', 'VBP'),
#   ('people', 'NNS'),
#   ('in', 'IN'),
#   ('times', 'NNS'),
#   ('like', 'IN'),
#   ('thesee', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('yousrhammad', 'NN'),
#   ('@', 'NNP'),
#   ('mordy_2012', 'NN'),
#   ('انا', 'NNP'),
#   ('مقتنع', 'NNP'),
#   ('براى', 'NNP'),
#   ('وهقنعك', 'NNP'),
#   ('وممكن', 'NNP'),
#   ('بكره', 'NNP'),
#   ('القيكى', 'NNP'),
#   ('بتتجوزى', 'NN'),
#   (':', ':'),
#   ('D', 'NN')],
#  [],
#  [('Siplah', 'NNP'),
#   (',', ','),
#   ('dtunggu', 'NN'),
#   ('Yªaªaђ', 'NNP'),
#   ('transferan', 'VBD'),
#   ('na', 'RB'),
#   ('Yªaªaђ', 'NNP'),
#   ('wkwkw', 'NN'),
#   ('RT', 'NNP'),
#   ('@', 'NNP'),
#   ('_indriinapasha', 'NN'),
#   (':', ':'),
#   ('Iya', 'NNP'),
#   ('[', 'NNP'),
#   ('ɑ̲̅κ̲̅u̲̅', 'NNP'),
#   (']', 'NNP'),
#   ('(', '('),
#   ('cont', 'NN'),
#   (')', ')'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/ii6WsAvI', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('even', 'RB'),
#   ('describe', 'VB'),
#   ('how', 'WRB'),
#   ('excited', 'JJ'),
#   ('I', 'PRP'),
#   ('am', 'VBP'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('cook', 'NN'),
#   ('noodles', 'NNS'),
#   ('for', 'IN'),
#   ('3', 'CD'),
#   ('hours', 'NNS'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('arrgghh', 'IN'),
#   ('my', 'PRP$'),
#   ('feet', 'NNS'),
#   ('r', 'VBP'),
#   ('killing', 'VBG'),
#   ('me', 'PRP'),
#   ('school', 'NN'),
#   ('uniform', 'RB'),
#   ('done', 'VBN'),
#   ('new', 'JJ'),
#   ('school', 'NN'),
#   ('shoes', 'NNS'),
#   ('check', 'VB'),
#   ('coat', 'NN'),
#   ('bag', 'NN'),
#   ('lunch', 'NN'),
#   ('box', 'NN'),
#   ('bed', 'VBD'),
#   ('early', 'JJ'),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   ('i', 'JJ'),
#   ('think', 'VBP'),
#   ('@', 'CD'),
#   ('aaronoregan1', 'NNS')],
#  [],
#  [('@', 'JJ'),
#   ('kimcherrynice', 'NN'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('loveit', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('PhilTSoares', 'NNP'),
#   ('@', 'NNP'),
#   ('jamessharman', 'NN'),
#   ('yeah', 'NN'),
#   (',', ','),
#   ('trophies', 'NNS'),
#   ('and', 'CC'),
#   ('goals', 'NNS'),
#   ('are', 'VBP'),
#   ("n't", 'RB'),
#   ('everything', 'NN'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('LidiaLowe', 'NNP'),
#   ('oh', 'MD'),
#   ('no', 'DT'),
#   ('way', 'NN'),
#   ('!', '.'),
#   ('I', 'PRP'),
#   ("'ve", 'VBP'),
#   ('just', 'RB'),
#   ('had', 'VBD'),
#   ('a', 'DT'),
#   ('cooked', 'VBN'),
#   ('breakfast', 'NN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('boss', 'NN'),
#   ('.', '.'),
#   ('#', '#'),
#   ('workbenefits', 'NNS'),
#   ('!', '.')],
#  [],
#  [('@', 'NN'),
#   ('allaboutdodie', 'NN'),
#   ('Buwas', 'NNP'),
#   (':', ':'),
#   (')', ')'),
#   (')', ')'),
#   ('Pero', 'NNP'),
#   ('d', 'NN'),
#   ('pak', 'NN'),
#   ('sure', 'JJ'),
#   ('kun', 'VBZ'),
#   ('showing', 'VBG'),
#   ('na', 'JJ'),
#   ('geap', 'JJ'),
#   ('i2', 'NN'),
#   ('ha', 'NN'),
#   ('rob..', 'NN')],
#  [],
#  [('Our', 'PRP$'),
#   ('friends', 'NNS'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('Fowler', 'NNP'),
#   ('House', 'NNP'),
#   ('in', 'IN'),
#   ('Quincy', 'NNP'),
#   ('love', 'VBP'),
#   ('Bawstins', 'NNP'),
#   ('so', 'RB'),
#   ('much', 'RB'),
#   ('they', 'PRP'),
#   ('may', 'MD'),
#   ('be', 'VB'),
#   ('adding', 'VBG'),
#   ('it', 'PRP'),
#   ('to', 'TO'),
#   ('their', 'PRP$'),
#   ('favorite', 'JJ'),
#   ('dish', 'NN'),
#   ('.', '.'),
#   ('Look', 'VB'),
#   ('out', 'RP'),
#   ('its', 'PRP$'),
#   ('gon', 'NN'),
#   ('na', 'TO'),
#   ('be', 'VB'),
#   ('awesome', 'JJ'),
#   ('!', '.')],
#  [],
#  [('New', 'NNP'),
#   ('Jersey', 'NNP'),
#   ('Shopping', 'NNP'),
#   ('Plaza', 'NNP'),
#   ('Shootout', 'NNP'),
#   ('Leaves', 'NNP'),
#   ('Three', 'NNP'),
#   ('Dead', 'NNP'),
#   ('-', ':'),
#   ('Yahoo', 'NN'),
#   ('!', '.'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/ms6MggL1', 'JJ'),
#   ('via', 'IN'),
#   ('@', 'JJ'),
#   ('YahooNews', 'NNS')],
#  [],
#  [('I', 'PRP'),
#   ('really', 'RB'),
#   ('hope', 'VBP'),
#   ('the', 'DT'),
#   ('entire', 'JJ'),
#   ('population', 'NN'),
#   ('of', 'IN'),
#   ('peterborough', 'JJ'),
#   ('county', 'NN'),
#   ('enjoys', 'VBZ'),
#   ('their', 'PRP$'),
#   ('a', 'DT'),
#   ('&', 'CC'),
#   ('amp', 'NN'),
#   (';', ':'),
#   ('w', 'CC'),
#   ('...', ':'),
#   ('#', '#'),
#   ('notbusyatall', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Want', 'NNP'),
#   ('to', 'TO'),
#   ('save', 'VB'),
#   ('money', 'NN'),
#   ('on', 'IN'),
#   ('your', 'PRP$'),
#   ('next', 'JJ'),
#   ('Jerky', 'NNP'),
#   ('run', 'NN'),
#   ('?', '.'),
#   ('Check', 'VB'),
#   ('out', 'IN'),
#   ('the', 'DT'),
#   ('All', 'NNP'),
#   ('Things', 'NNP'),
#   ('Jerky', 'NNP'),
#   ('coupons', 'NNS'),
#   ('at', 'IN'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/kRyKR2XK', 'NN'),
#   ('...', ':'),
#   ('.', '.'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/x0cr5VKs', 'NN')],
#  [],
#  [('The', 'DT'),
#   ('average', 'JJ'),
#   ('man', 'NN'),
#   ('could', 'MD'),
#   ('not', 'RB'),
#   ('handle', 'VB'),
#   ('my', 'PRP$'),
#   ('haircut', 'NN')],
#  [],
#  [('AP', 'JJ'),
#   ('Government', 'NNP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('most', 'RBS'),
#   ('exciting', 'JJ'),
#   ('class', 'NN'),
#   ('I', 'PRP'),
#   ("'ve", 'VBP'),
#   ('ever', 'RB'),
#   ('taken', 'VBN'),
#   ('!', '.'),
#   ('🎉', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('NotesOnNotesOnNotes', 'NNS')],
#  [],
#  [('My', 'PRP$'),
#   ('work', 'NN'),
#   ('ethic', 'JJ'),
#   ('tonight', 'NN'),
#   ('is', 'VBZ'),
#   ('on', 'IN'),
#   ('a', 'DT'),
#   ('different', 'JJ'),
#   ('level', 'NN'),
#   ('#', '#'),
#   ('sarcasm', 'NN'),
#   ('..', 'VBP'),
#   ('It', 'PRP'),
#   ("'ll", 'MD'),
#   ('wait', 'VB'),
#   ('till', 'NN'),
#   ('tomorrow', 'NN')],
#  [],
#  [('All', 'DT'),
#   ('I', 'PRP'),
#   ('want', 'VBP'),
#   ('for', 'IN'),
#   ('mah', 'NN'),
#   ('birthday', 'NN'),
#   ('is', 'VBZ'),
#   ('...', ':'),
#   ('2', 'CD'),
#   ('Chainz', 'NNP'),
#   ('feat', 'NN'),
#   ('.', '.'),
#   ('Kanye', 'NNP'),
#   ('West', 'NNP'),
#   ('-', ':'),
#   ('Birthday', 'NN'),
#   ('Song', 'NN'),
#   (':', ':'),
#   (':', ':'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/SL1MN88g', 'NN')],
#  [],
#  [('Absolutely', 'RB'),
#   ('love', 'VB'),
#   ('being', 'VBG'),
#   ('left', 'VBN'),
#   ('to', 'TO'),
#   ('hang', 'VB'),
#   ('#', '#'),
#   ('SARCASM', 'NNP')],
#  [],
#  [('Woo', 'NNP'),
#   ('best', 'JJS'),
#   ('part', 'NN'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('library', 'JJ'),
#   ('tour', 'NN'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('getting', 'VBG'),
#   ('back', 'RB'),
#   ('to', 'TO'),
#   ('England', 'NNP'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('same', 'JJ'),
#   ('morning', 'NN'),
#   ('that', 'IN'),
#   ('school', 'NN'),
#   ('starts', 'NNS'),
#   ('...', ':'),
#   ('#', '#'),
#   ('Great', 'NNP'),
#   ('.', '.'),
#   ('#', '#'),
#   ('Sarcasm', 'NNP'),
#   ('.', '.')],
#  [],
#  [('@', 'JJ'),
#   ('NurmaFatihah', 'NNP'),
#   ('pew', 'NN'),
#   ('yg', 'NN'),
#   ('rmai', 'NN'),
#   ('?', '.'),
#   ('?', '.')],
#  [],
#  [('The', 'DT'),
#   ('OzMoGa', 'NNP'),
#   ('Times', 'NNP'),
#   ('is', 'VBZ'),
#   ('out', 'RP'),
#   ('!', '.'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/lv1gUDhB', 'JJ'),
#   ('▸', 'NNP'),
#   ('Top', 'NNP'),
#   ('stories', 'NNS'),
#   ('today', 'NN'),
#   ('via', 'IN'),
#   ('@', 'NNP'),
#   ('ezonecom', 'FW'),
#   ('@', 'NNP'),
#   ('SquareEggGames', 'NNP')],
#  [],
#  [('Love', 'VB'),
#   ('being', 'VBG'),
#   ('left', 'VBN'),
#   ('alone', 'RB'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('hall', 'NN'),
#   ('while', 'IN'),
#   ('people', 'NNS'),
#   ('go', 'VBP'),
#   ('and', 'CC'),
#   ('sing', 'VBG'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('loner', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('lukebryanonline', 'NN'),
#   ('puts', 'VBZ'),
#   ('me', 'PRP'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('bestttttt', 'NN'),
#   ('mooooood', 'NN'),
#   ('everrrrrr', 'NN'),
#   ('&', 'CC'),
#   ('lt', 'NN'),
#   (';', ':'),
#   ('3', 'CD')],
#  [],
#  [('And', 'CC'),
#   ('on', 'IN'),
#   ('top', 'NN'),
#   ('of', 'IN'),
#   ('it', 'PRP'),
#   ('all', 'DT'),
#   ('our', 'PRP$'),
#   ('power', 'NN'),
#   ('is', 'VBZ'),
#   ('out', 'RP'),
#   ('#', '#'),
#   ('bestdayever', 'RB'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('so', 'RB'),
#   ('glad', 'JJ'),
#   ('it', 'PRP'),
#   ('never', 'RB'),
#   ('rains', 'VBZ'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('whee', 'NN'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Maryland', 'NNP'),
#   ('absolutely', 'RB'),
#   (',', ','),
#   ('positively', 'RB'),
#   ('did', 'VBD'),
#   ('the', 'DT'),
#   ('right', 'JJ'),
#   ('thing', 'NN'),
#   ('not', 'RB'),
#   ('honoring', 'VBG'),
#   ('James', 'NNP'),
#   ('Franklin', 'NNP'),
#   ("'s", 'POS'),
#   ('``', '``'),
#   ('Head', 'NNP'),
#   ('Coach', 'NNP'),
#   ('In', 'IN'),
#   ('Waiting', 'VBG'),
#   ("''", "''"),
#   ('status', 'NN'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('You', 'PRP'),
#   ('are', 'VBP'),
#   ('attracted', 'VBN'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('wide', 'JJ'),
#   ('variety', 'NN'),
#   ('of', 'IN'),
#   ('new', 'JJ'),
#   ('ideas', 'NNS'),
#   ('during', 'IN'),
#   ('this', 'DT'),
#   ('t', 'NN'),
#   ('...', ':'),
#   ('More', 'JJR'),
#   ('for', 'IN'),
#   ('Capricorn', 'NNP'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/p31ha9AU', 'NN')],
#  [],
#  [('Rrg', 'NNP'),
#   ('my', 'PRP$'),
#   ('teeth', 'NNS'),
#   ('ache', 'VBP'),
#   ('so', 'RB'),
#   ('much', 'JJ'),
#   ('!', '.'),
#   ('!', '.'),
#   ('!', '.'),
#   ('Oh', 'UH'),
#   ('well', 'RB'),
#   ('anything', 'NN'),
#   ('for', 'IN'),
#   ('straight', 'JJ'),
#   ('teeth', 'NNS'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Man', 'NNP'),
#   ('kills', 'VBZ'),
#   ('daughter', 'NN'),
#   ("'s", 'POS'),
#   ('BF', 'NNP'),
#   ('in', 'IN'),
#   ('#', '#'),
#   ('gun', 'NN'),
#   ('control', 'NN'),
#   ('Germany', 'NNP'),
#   ('with', 'IN'),
#   ('an', 'DT'),
#   ('EXPLOSION', 'NNP'),
#   ('.', '.'),
#   ('as', 'RB'),
#   ('long', 'RB'),
#   ('as', 'IN'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('not', 'RB'),
#   ('a', 'DT'),
#   ('gun', 'NN'),
#   ('!', '.'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('NRA', 'NNP'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/uRi7nk9s', 'NN')],
#  [],
#  [('Sometimes', 'RB'),
#   ('I', 'PRP'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('tell', 'VB'),
#   ('if', 'IN'),
#   ('@', 'JJ'),
#   ('katecarneyy', 'NN'),
#   ('is', 'VBZ'),
#   ('serious', 'JJ'),
#   ('or', 'CC'),
#   ('not', 'RB'),
#   ('\ue402', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('UK', 'NNP'),
#   ('Truebies', 'NNP'),
#   ('not', 'RB'),
#   ('long', 'RB'),
#   ('now', 'RB'),
#   ('until', 'IN'),
#   ('those', 'DT'),
#   ('of', 'IN'),
#   ('you', 'PRP'),
#   ('with', 'IN'),
#   ('Sky', 'NNP'),
#   ('and', 'CC'),
#   ('Virgin', 'NNP'),
#   ('get', 'VBP'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('the', 'DT'),
#   ('fabulous', 'JJ'),
#   ('fifth', 'NN'),
#   ('season', 'NN'),
#   ('of', 'IN'),
#   ('True', 'NNP'),
#   ('...', ':'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/qtKFi8ot', 'NN')],
#  [],
#  [('@', 'NN'),
#   ('FlossMoore', 'NNP'),
#   ('Check', 'NNP'),
#   ('out', 'IN'),
#   ('the', 'DT'),
#   ('3rd', 'CD'),
#   ('#', '#'),
#   ('LabLife', 'NNP'),
#   ('installment', 'JJ'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/YSvRL6ez', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('LeeLiLo_90', 'NNP'),
#   ('@', 'NNP'),
#   ('jemlaa90', 'NN'),
#   ('I', 'PRP'),
#   ('wudnt', 'VBP'),
#   ('say', 'VB'),
#   ('funny', 'JJ'),
#   ('lmao', 'NN'),
#   ('!', '.'),
#   ('!', '.'),
#   ('#', '#'),
#   ('Sarcasm', 'NNP')],
#  [],
#  [('Well', 'RB'),
#   ('the', 'DT'),
#   ('lady', 'NN'),
#   ('that', 'WDT'),
#   ('trimmed', 'VBD'),
#   ('my', 'PRP$'),
#   ('hair', 'NN'),
#   ('did', 'VBD'),
#   ('an', 'DT'),
#   ('AWESOME', 'NNP'),
#   ('job', 'NN'),
#   ('.', '.'),
#   ('#', '#'),
#   ('Sarcasm', 'NNP')],
#  [('Callback', 'NNP'),
#   ('#', '#'),
#   (':', ':'),
#   ('319-231-7015', 'JJ'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/B2ev1MRa', 'NN')],
#  [],
#  [('No', 'DT'),
#   ('my', 'PRP$'),
#   ('roommate', 'NN'),
#   ('play', 'NN'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('tune', 'NN'),
#   ('Zeppelin', 'NNP'),
#   ('songs', 'NNS'),
#   ('right', 'RB'),
#   ('outside', 'IN'),
#   ('my', 'PRP$'),
#   ('door', 'NN'),
#   ('isnt', 'NN'),
#   ('annoying', 'VBG'),
#   ('.', '.'),
#   ('Not', 'RB'),
#   ('at', 'IN'),
#   ('all', 'DT'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('sigh', 'JJ')],
#  [],
#  [('``', '``'),
#   ('Fuck', 'JJ'),
#   ('hate', 'NN'),
#   ("''", "''"),
#   ('bumper', 'NN'),
#   ('sticker', 'NN'),
#   ('on', 'IN'),
#   ('64', 'CD'),
#   ('.', '.'),
#   ('So', 'RB'),
#   ('many', 'JJ'),
#   ('small', 'JJ'),
#   ('beings', 'NNS'),
#   ('have', 'VBP'),
#   ('proudly', 'RB'),
#   ('read', 'VBN'),
#   ('that', 'IN'),
#   ('to', 'TO'),
#   ('their', 'PRP$'),
#   ('parents', 'NNS'),
#   ('.', '.'),
#   ('#', '#'),
#   ('RVA', 'NNP'),
#   ('#', '#'),
#   ('firstwords', 'NNS')],
#  [],
#  [('8th', 'CD'),
#   ('grade', 'JJ'),
#   ('orientation', 'NN'),
#   ('tonight', 'NN'),
#   ('#', '#'),
#   ('alwaysfun', 'RB'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('I', 'PRP'), ('hate', 'VBP'), ('this', 'DT'), ('class', 'NN'), ('.', '.')],
#  [],
#  [('From', 'IN'),
#   ('car', 'NN'),
#   ('fan', 'NN'),
#   ('to', 'TO'),
#   ('house', 'NN'),
#   ('fan', 'NN'),
#   ('-', ':'),
#   ('Richard', 'NNP'),
#   ('Turere', 'NNP'),
#   ("'s", 'POS'),
#   ('laters', 'NNS'),
#   ('home', 'VBP'),
#   ('improvement', 'NN'),
#   ('@', 'NNP'),
#   ('afrigadget', 'NN'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/hEjY62H6', 'NN')],
#  [],
#  [('@', 'NN'),
#   ('kaywa_xo', 'NN'),
#   ('well', 'RB'),
#   ('done', 'VBN'),
#   ('for', 'IN'),
#   ('understanding', 'VBG'),
#   ('kayla', 'NN'),
#   ('!', '.'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('youradickhead', 'NN'),
#   (':', ':'),
#   (')', ')')],
#  [],
#  [('@', 'NNS'),
#   ('HennaSaeed', 'NNP'),
#   ('yup', 'NN'),
#   ('.', '.'),
#   ('They', 'PRP'),
#   ('deserve', 'VBP'),
#   ('this', 'DT'),
#   ('win..', 'NN')],
#  [],
#  [('@', 'NN'),
#   ('rahulpuri', 'NN'),
#   ('Absolutely', 'RB'),
#   ('!', '.'),
#   ('She', 'PRP'),
#   ('just', 'RB'),
#   ('keeps', 'VBZ'),
#   ('re-tweeting', 'JJ'),
#   ('anything', 'NN'),
#   ('and', 'CC'),
#   ('everything', 'NN'),
#   ('that', 'IN'),
#   ('mentions', 'VBZ'),
#   ('her', 'PRP$'),
#   ('name', 'NN'),
#   ('.', '.'),
#   ('My', 'PRP$'),
#   ('page', 'NN'),
#   ('is', 'VBZ'),
#   ('flooded', 'VBN'),
#   ('!', '.'),
#   ('Enough', 'NNP'),
#   (',', ','),
#   ('I', 'PRP'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [],
#  [('Hahaha', 'NNP'),
#   ('...', ':'),
#   ('.wenger', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('fucking', 'JJ'),
#   ('genius', 'NN'),
#   ('...', ':'),
#   ('giroud', 'NN'),
#   ('is', 'VBZ'),
#   ('d', 'VBN'),
#   ('only', 'RB'),
#   ('striker', 'NN'),
#   ('left', 'VBD'),
#   ('in', 'IN'),
#   ('arsenal', 'JJ'),
#   ('...', ':'),
#   ('lmao', 'NN'),
#   ('...', ':'),
#   ('#', '#'),
#   ('sarcasm', 'NN'),
#   ('!', '.'),
#   ('!', '.')],
#  [],
#  [('Youth', 'NN'),
#   ('Of', 'IN'),
#   ('The', 'DT'),
#   ('Nation', 'NNP'),
#   ('-', ':'),
#   ('P.O.D', 'NN'),
#   ('.', '.'),
#   ('[', 'CC'),
#   ('HQ', 'NNP'),
#   (']', 'NN'),
#   (':', ':'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/lTMD6zKl', 'JJ'),
#   ('via', 'IN'),
#   ('@', 'JJ'),
#   ('youtube', 'NN'),
#   ('thanks', 'NNS'),
#   ('for', 'IN'),
#   ('this', 'DT'),
#   ('!', '.'),
#   ('!', '.'),
#   ('@', 'JJ'),
#   ('thewhosoevers', 'NNS')],
#  [],
#  [('Agh', 'NNP'),
#   ('i', 'VBZ'),
#   ('only', 'RB'),
#   ('got', 'VBD'),
#   ('5', 'CD'),
#   ('hours', 'NNS'),
#   ('of', 'IN'),
#   ('sleep', 'NN'),
#   ('last', 'JJ'),
#   ('night.', 'JJ'),
#   ('&', 'CC'),
#   ('amp', 'NN'),
#   (';', ':'),
#   ('fee', 'NN'),
#   ('night', 'NN'),
#   ('is', 'VBZ'),
#   ('tonight', 'VBN'),
#   ('so', 'RB'),
#   ('im', 'JJ'),
#   ('gon', 'NN'),
#   ('na', 'TO'),
#   ('look', 'VB'),
#   ('a', 'DT'),
#   ('mess', 'NN'),
#   ('.', '.'),
#   ('Great', 'JJ'),
#   ('way', 'NN'),
#   ('to', 'TO'),
#   ('start', 'VB'),
#   ('off', 'RP'),
#   ('the', 'DT'),
#   ('school', 'NN'),
#   ('year', 'NN'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('QueMarlee', 'NNP'),
#   ('appreciate', 'NN'),
#   ('that', 'WDT'),
#   ('man', 'NN')],
#  [],
#  [('First', 'NNP'),
#   ('day', 'NN'),
#   ('of', 'IN'),
# ...
#   ('amazing', 'JJ'),
#   ('teacher', 'NN'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('#', '#'),
#   ('love', 'NN'),
#   ('being', 'VBG'),
#   ('up', 'RP'),
#   ('early', 'RB'),
#   ('after', 'IN'),
#   ('getting', 'VBG'),
#   ('no', 'DT'),
#   ('sleep', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('RIP', 'NNP'),
#   ('@', 'NNP'),
#   ('SKEnergyShots', 'NNP'),
#   ('Deeply', 'NNP'),
#   ('saddened', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('loss', 'NN'),
#   ('of', 'IN'),
#   ('my', 'PRP$'),
#   ('dear', 'JJ'),
#   ('friend', 'NN'),
#   ('and', 'CC'),
#   ('business', 'NN'),
#   ('partner', 'NN'),
#   ('Chris', 'NNP'),
#   ('Lighty', 'NNP'),
#   ('.', '.'),
#   ('He', 'PRP'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('greatly', 'RB'),
#   ('missed', 'VBN'),
#   ('.', '.'),
#   ('-', ':'),
#   ('50', 'CD')],
#  [],
#  [('yep', 'NN'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('gives', 'VBZ'),
#   ('me', 'PRP'),
#   ('advice', 'IN'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('time', 'NN'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('RT', 'NNP'),
#   ('@', 'NNP'),
#   ('WorstOfLibra', 'NNP'),
#   (':', ':'),
#   ('#', '#'),
#   ('Libra', 'NNP'),
#   (':', ':'),
#   ('I', 'PRP'),
#   ('have', 'VBP'),
#   ('a', 'DT'),
#   ('scale', 'NN'),
#   ('in', 'IN'),
#   ('my', 'PRP$'),
#   ('bathroom', 'NN'),
#   ('.', '.')],
#  [],
#  [('I', 'PRP'),
#   ('love', 'VBP'),
#   ('how', 'WRB'),
#   ('all', 'DT'),
#   ('your', 'PRP$'),
#   ('tweets', 'NNS'),
#   ('and', 'CC'),
#   ('instas', 'NNS'),
#   ('are', 'VBP'),
#   ('so', 'RB'),
#   ('original', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('peoplepleasers', 'NNS'),
#   ('👎', 'VBP')],
#  [],
#  [('I', 'PRP'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('what', 'WP'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('with', 'IN'),
#   ('my', 'PRP$'),
#   ('life', 'NN'),
#   ('besides', 'IN'),
#   ('get', 'NN'),
#   ('high', 'JJ'),
#   ('and', 'CC'),
#   ('make', 'VB'),
#   ('music', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('chur_ay', 'NN'),
#   ('pengguna', 'NN'),
#   ('baru', 'NN'),
#   ('twett', 'NN'),
#   (',', ','),
#   ('mhon', 'FW'),
#   ('bantuanx', 'NN'),
#   ('ya', 'NN'),
#   ('.', '.'),
#   ('.', '.')],
#  [(':', ':'), ('D', 'NN')],
#  [],
#  [('How', 'WRB'),
#   ('u', 'JJ'),
#   ('brag', 'NN'),
#   ('about', 'IN'),
#   ('Tru', 'NNP'),
#   ('jeans', 'NNS'),
#   ('and', 'CC'),
#   ('big', 'JJ'),
#   ('screen', 'NN'),
#   ('tv', 'NN'),
#   ('and', 'CC'),
#   ('yo', 'VB'),
#   ('rent', 'NN'),
#   ('only', 'RB'),
#   ('1.87', 'CD'),
#   ('I', 'PRP'),
#   ('be', 'VB'),
#   ('balling', 'VBG'),
#   ('too', 'RB')],
#  [],
#  [('This', 'DT'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('so', 'RB'),
#   ('good', 'JJ'),
#   ('.', '.'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/nZsxb3pu', 'NN')],
#  [],
#  [('Can', 'MD'),
#   ('already', 'RB'),
#   ('tell', 'VB'),
#   ('3', 'CD'),
#   ('hour', 'NN'),
#   ('Bio', 'NNP'),
#   ('labs', 'NN'),
#   ('are', 'VBP'),
#   ('gon', 'VBN'),
#   ('na', 'RB'),
#   ('be', 'VB'),
#   ('loads', 'NNS'),
#   ('fun', 'VB'),
#   ('...', ':'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ('want', 'VBP'),
#   ('us', 'PRP'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('caught', 'JJ'),
#   ('!', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Do', 'VBP'),
#   ('you', 'PRP'),
#   ('want', 'VB'),
#   ('a', 'DT'),
#   ('cookie', 'NN'),
#   ('for', 'IN'),
#   ('that', 'DT'),
#   ('?', '.'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('notagreatachievement', 'NN')],
#  [],
#  [('Can', 'MD'),
#   ('someone', 'NN'),
#   ('please', 'VB'),
#   ('tell', 'VB'),
#   ('me', 'PRP'),
#   ('why', 'WRB'),
#   ('it', 'PRP'),
#   ('smells', 'VBZ'),
#   ('like', 'IN'),
#   ('poop', 'NN'),
#   ('in', 'IN'),
#   ('Lebanon', 'NNP'),
#   ('right', 'NN'),
#   ('now', 'RB'),
#   ('?', '.'),
#   ('!', '.'),
#   ('Like', 'IN'),
#   ('seriously', 'RB'),
#   ('though..', 'JJ'),
#   ('#', '#'),
#   ('sogross', 'NN'),
#   ('\ue40c\ue40c\ue40c', 'NN')],
#  [],
#  [('Thank', 'NNP'),
#   ('you', 'PRP'),
#   ('alarm', 'VBP'),
#   ('clock', 'NN'),
#   ('for', 'IN'),
#   ('never', 'RB'),
#   ('going', 'VBG'),
#   ('off', 'RP'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('hatebeinglate', 'NN')],
#  [],
#  [(':', ':'),
#   ('D', 'NN'),
#   ('Does', 'VBZ'),
#   ('this', 'DT'),
#   ('make', 'VB'),
#   ('me', 'PRP'),
#   ('cool', 'JJ'),
#   ('!', '.'),
#   ('?', '.'),
#   ('!', '.'),
#   ('?', '.'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/ySW26a6I', 'NN')],
#  [],
#  [('Thanks', 'NNS'),
#   ('for', 'IN'),
#   ('showing', 'VBG'),
#   ('me', 'PRP'),
#   ('how', 'WRB'),
#   ('real', 'JJ'),
#   ('Christians', 'NNPS'),
#   ('act..', 'VBP'),
#   ('ur', 'JJ'),
#   ('such', 'JJ'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('example', 'NN'),
#   ('...', ':'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('“', 'JJ'),
#   ('@', 'NNP'),
#   ('Kayneee_K', 'NNP'),
#   (':', ':'),
#   ('I', 'PRP'),
#   ('LOVE', 'VBP'),
#   ('it', 'PRP'),
#   ('when', 'WRB'),
#   ('the', 'DT'),
#   ('nail', 'NN'),
#   ('salon', 'NN'),
#   ('says', 'VBZ'),
#   ('they', 'PRP'),
#   ("'ll", 'MD'),
#   ('be', 'VB'),
#   ('15', 'CD'),
#   ('minutes', 'NNS'),
#   ('when', 'WRB'),
#   ('you', 'PRP'),
#   ("'ve", 'VBP'),
#   ('been', 'VBN'),
#   ('waiting', 'VBG'),
#   ('30”', 'CD'),
#   ('#', '#'),
#   ('sarcasm', 'NN'),
#   ('?', '.'),
#   ('😏', 'NN')],
#  [],
#  [('It', 'PRP'),
#   ('seems', 'VBZ'),
#   ('too', 'RB'),
#   ('early', 'JJ'),
#   ('for', 'IN'),
#   ('this', 'DT'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('called', 'VBN'),
#   ('an', 'DT'),
#   ('instant', 'JJ'),
#   ('classic', 'NN'),
#   ('but', 'CC'),
#   ('Gophs/UNLV', 'NNP'),
#   ('is', 'VBZ'),
#   ('all', 'DT'),
#   ('that', 'DT'),
#   ('.', '.'),
#   ('#', '#'),
#   ('Sarcasm', 'NNP')],
#  [],
#  [('@', 'NN'),
#   ('Vamp', 'NNP'),
#   ('So', 'NNP'),
#   ('do', 'VB'),
#   ('you', 'PRP'),
#   ('sparkle', 'VB'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('sunlight', 'NN'),
#   ('being', 'VBG'),
#   ('a', 'DT'),
#   ('``', '``'),
#   ('vampire', 'NN'),
#   ("''", "''"),
#   ('and', 'CC'),
#   ('all', 'DT'),
#   ('?', '.'),
#   ('&', 'CC'),
#   ('gt', 'NN'),
#   (';', ':'),
#   ('_', 'NNP'),
#   ('&', 'CC'),
#   ('gt', 'NN'),
#   (';', ':'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Just', 'RB'),
#   ('love', 'VB'),
#   ('getting', 'VBG'),
#   ('lied', 'VBN'),
#   ('to', 'TO'),
#   ('!', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Somewhere', 'RB'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('desert', 'NN'),
#   ('of', 'IN'),
#   ('Nevada', 'NNP'),
#   (',', ','),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('touch', 'NN'),
#   ('of', 'IN'),
#   ('green', 'JJ'),
#   ('.', '.'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//t.co/nN8MOuIy', 'NN')],
#  [],
#  [('Imma', 'NNP'),
#   ('stop', 'VBD'),
#   ('snapping', 'VBG'),
#   ('tho', 'NN'),
#   ('.', '.')],
#  [],
#  [('I', 'PRP'),
#   ('wan', 'VBP'),
#   ('na', 'RB'),
#   ('be', 'VB'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('fantasy', 'NN'),
#   ('football', 'NN'),
#   ('league', 'NN')],
#  [],
#  [('Off', 'IN'),
#   ('to', 'TO'),
#   ('Jamaica', 'NNP'),
#   ('manana', 'NN'),
#   ('!', '.'),
#   ('Even', 'RB'),
#   ('though', 'IN'),
#   ('this', 'DT'),
#   ('trip', 'NN'),
#   ('is', 'VBZ'),
#   ("n't", 'RB'),
#   ('precipitated', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('circumstances', 'NNS'),
#   (',', ','),
#   ('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('looking', 'VBG'),
#   ('forward', 'RB'),
#   ('to', 'TO'),
#   ('being', 'VBG'),
#   ('home', 'VBN'),
#   ('with', 'IN'),
#   ('fam', 'NN'),
#   (':', ':'),
#   ('-', ':'),
#   (')', ')')],
#  [],
#  [('Of', 'IN'),
#   ('course', 'NN'),
#   ('I', 'PRP'),
#   ('have', 'VBP'),
#   ('the', 'DT'),
#   ('earliest', 'JJS'),
#   ('appointment', 'NN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('dmv', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('computers', 'NNS'),
#   ('crashed', 'VBD'),
#   ('last', 'JJ'),
#   ('night', 'NN'),
#   ('#', '#'),
#   ('greatmorning', 'VBG'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('The', 'DT'),
#   ('United', 'NNP'),
#   ('States', 'NNPS'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('signatory', 'NN'),
#   ('to', 'TO'),
#   ('this', 'DT'),
#   ('international', 'JJ'),
#   ('convention', 'NN'),
#   ('.', '.')],
#  [],
#  [('@', 'JJ'),
#   ('elfordminis', 'NN'),
#   ('looks', 'VBZ'),
#   ('awesome', 'JJ'),
#   ('.', '.'),
#   ('How', 'WRB'),
#   ('long', 'RB'),
#   ('did', 'VBD'),
#   ('it', 'PRP'),
#   ('take', 'VB'),
#   ('to', 'TO'),
#   ('paint', 'VB'),
#   ('?', '.')],
#  [],
#  [('I', 'PRP'),
#   ('love', 'VBP'),
#   ('that', 'IN'),
#   ('im', 'JJ'),
#   ('wide', 'JJ'),
#   ('awake', 'NN'),
#   ('with', 'IN'),
#   ('him', 'PRP'),
#   ('sound', 'JJ'),
#   ('asleep', 'RB'),
#   ('next', 'JJ'),
#   ('to', 'TO'),
#   ('me', 'PRP'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('wishicouldsleep', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('BenWiseMelb', 'NNP'),
#   ('no', 'DT'),
#   ('kidding', 'NN'),
#   ('.', '.'),
#   ('It', 'PRP'),
#   ('was', 'VBD'),
#   ('brutal', 'JJ'),
#   ('!', '.'),
#   ('P.S', 'NNP'),
#   ('what', 'WP'),
#   ("'s", 'VBZ'),
#   ('your', 'PRP$'),
#   ('beef', 'NN'),
#   ('with', 'IN'),
#   ('Warnie', 'NNP'),
#   ('?', '.'),
#   ('Just', 'RB'),
#   ('because', 'IN'),
#   ('he', 'PRP'),
#   ('bleaches', 'VBZ'),
#   ('his', 'PRP$'),
#   ('teeth', 'NN'),
#   ('&', 'CC'),
#   ('amp', 'NN'),
#   (';', ':'),
#   ('uses', 'NNS'),
#   ('fake', 'VBP'),
#   ('tan', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('.', '.'),
#   ('not', 'RB'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('along', 'IN'),
#   ('with', 'IN'),
#   ('my', 'PRP$'),
#   ('chemistry', 'NN'),
#   ('teacher', 'NN'),
#   ('I', 'PRP'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('like', 'VB'),
#   ('his', 'PRP$'),
#   ('ass', 'NN'),
#   ('already', 'RB')],
#  [],
#  [('Sooo', 'NNP'),
#   ('happy', 'JJ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('at', 'IN'),
#   ('work', 'NN'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Absolutely', 'RB'),
#   ('love', 'VB'),
#   ('when', 'WRB'),
#   ('water', 'NN'),
#   ('is', 'VBZ'),
#   ('spilt', 'VBN'),
#   ('on', 'IN'),
#   ('my', 'PRP$'),
#   ('phone..', 'NN'),
#   ('Just', 'NNP'),
#   ('love', 'VB'),
#   ('it..', 'RB'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('timeforanewphone', 'NN'),
#   ('...', ':')],
#  [],
#  [('No', 'DT'), ('shame', 'NN'), ('in', 'IN'), ('that', 'DT'), ('.', '.')],
#  [],
#  [('taking', 'VBG'),
#   ('my', 'PRP$'),
#   ('boys', 'NNS'),
#   ('into', 'IN'),
#   ('town', 'NN'),
#   ('today-', 'JJ'),
#   ('awww', 'NN'),
#   ('yay', 'NN'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Every', 'DT'),
#   ('dark', 'NN'),
#   ('light', 'NN'),
#   ('is', 'VBZ'),
#   ('followed', 'VBN'),
#   ('by', 'IN'),
#   ('a', 'DT'),
#   ('light', 'JJ'),
#   ('morning', 'NN'),
#   ('.', '.'),
#   ('Good', 'JJ'),
#   ('Morning', 'NN'),
#   ('and', 'CC'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('forget', 'VB'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('AWESOME', 'NNP'),
#   ('!', '.')],
#  [],
#  [('Just', 'RB'),
#   ('got', 'VBD'),
#   ('off', 'RP'),
#   ('the', 'DT'),
#   ('horn', 'NN'),
#   ('with', 'IN'),
#   ('Clint', 'NNP'),
#   ('.', '.'),
#   ('Told', 'VBD'),
#   ('me', 'PRP'),
#   ('he', 'PRP'),
#   ('really', 'RB'),
#   ('gives', 'VBZ'),
#   ('a', 'DT'),
#   ('shit', 'JJ'),
#   ('what', 'WDT'),
#   ('people', 'NNS'),
#   ('think', 'VBP'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('NoteToTwitter', 'NN')],
#  [],
#  [('Actually', 'RB'),
#   ('goin', 'VB'),
#   ('to', 'TO'),
#   ('school', 'NN'),
#   ('tomorrow', 'NN'),
#   ('(', '('),
#   ('x', 'JJ')],
#  [],
#  [('@', 'JJ'),
#   ('sscorbett', 'NN'),
#   ('u', 'JJ'),
#   ('mean', 'NN'),
#   ('like', 'IN'),
#   ('real', 'JJ'),
#   ('Madrid', 'NNP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('team', 'NN'),
#   ('ever', 'RB'),
#   ('#', '#'),
#   ('biggestlie', 'NN')],
#  [],
#  [('Nothing', 'NN'),
#   ('like', 'IN'),
#   ('being', 'VBG'),
#   ('in', 'IN'),
#   ('class', 'NN'),
#   ('two', 'CD'),
#   ('hours', 'NNS'),
#   ('and', 'CC'),
#   ('having', 'VBG'),
#   ('two', 'CD'),
#   ('hours', 'NNS'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('!', '.'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('TDE220', 'NNP')],
#  [],
#  [('@', 'JJ'),
#   ('NiallOfficial', 'NNP'),
#   ('@', 'NNP'),
#   ('AryaDwiCosta', 'NNP'),
#   ('Hopefully', 'NNP'),
#   ('not', 'RB'),
#   ('a', 'DT'),
#   ('strangers', 'NNS'),
#   ('car', 'NN'),
#   ('...', ':'),
#   ('(', '('),
#   (':', ':'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('my', 'PRP$'),
#   ('prayers', 'NNS'),
#   ('go', 'VBP'),
#   ('out', 'RP'),
#   ('to', 'TO'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('people', 'NNS'),
#   ('in', 'IN'),
#   ('new', 'JJ'),
#   ('orleans', 'NNS'),
#   ('about', 'IN'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('hit', 'VBN'),
#   ('by', 'IN'),
#   ('isaac', 'NN'),
#   ('\ue41d', 'NN')],
#  [],
#  [('in', 'IN'),
#   ('such', 'PDT'),
#   ('a', 'DT'),
#   ('happy', 'JJ'),
#   ('mood', 'NN'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Leicester', 'NNP'),
#   ('later', 'RB'),
#   ('with', 'IN'),
#   ('jessssss', 'NN'),
#   (':', ':'),
#   ('D', 'NN')],
#  [],
#  [('Wow', 'NNP'),
#   (',', ','),
#   ('kids', 'NNS'),
#   ('drinking', 'VBG'),
#   ('vodka', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('back', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('room', 'NN'),
#   ('during', 'IN'),
#   ('a', 'DT'),
#   ('lecture', 'NN'),
#   ('.', '.'),
#   ('You', 'PRP'),
#   ('guys', 'NNS'),
#   ('are', 'VBP'),
#   ('classy', 'JJ'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('So', 'RB'),
#   ('I', 'PRP'),
#   ('accidentally', 'RB'),
#   ('took', 'VBD'),
#   ('over', 'RP'),
#   ('the', 'DT'),
#   ('whole', 'JJ'),
#   ('room', 'NN'),
#   ('and', 'CC'),
#   ('now', 'RB'),
#   ('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('room', 'NN'),
#   ('for', 'IN'),
#   ('my', 'PRP$'),
#   ('roommate', 'NN'),
#   ('...', ':'),
#   ('WHO', 'WP'),
#   ('IS', 'VBZ'),
#   ('COMING', 'NNP'),
#   ('TOMORROW', 'NNP'),
#   ('BTW', 'NNP'),
#   ('...', ':'),
#   ('#', '#'),
#   ('rushed', 'VBD')],
#  [],
#  [('I', 'PRP'),
#   ('was', 'VBD'),
#   ('gone', 'VBN'),
#   ('for', 'IN'),
#   ('3', 'CD'),
#   ('days', 'NNS'),
#   ('and', 'CC'),
#   ('my', 'PRP$'),
#   ('cat', 'NN'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('even', 'RB'),
#   ('notice', 'VB'),
#   ('...', ':')],
#  [],
#  [('fuck', 'VB'),
#   ('the', 'DT'),
#   ('police', 'NN'),
#   ('from', 'IN'),
#   ('every', 'DT'),
#   ('possible', 'JJ'),
#   ('direction', 'NN')],
#  [],
#  [('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('immortal', 'JJ'),
#   ('.', '.'),
#   ('You', 'PRP'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('kill', 'VB'),
#   ('what', 'WP'),
#   ('has', 'VBZ'),
#   ('no', 'DT'),
#   ('life', 'NN'),
#   ('lol', 'RB'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'JJ'),
#   ('#', '#'),
#   ('BandGeekFTW', 'NNP')],
#  [],
#  [('@', 'JJ'),
#   ('PeteTheTemp', 'NNP'),
#   ('@', 'NNP'),
#   ('adamkammerling', 'VBG'),
#   ('Great', 'NNP'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('you', 'PRP'),
#   ('there', 'RB'),
#   (',', ','),
#   ('chaps', 'NNS'),
#   ('.', '.'),
#   ('Loving', 'VBG'),
#   ('your', 'PRP$'),
#   ('work', 'NN'),
#   ('.', '.'),
#   ('Hope', 'VBP'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('you', 'PRP'),
#   ('again', 'RB'),
#   ('soon', 'RB'),
#   ('.', '.'),
#   ('#', '#'),
#   ('PoetryPower', 'NNP')],
#  [],
#  [('Ill', 'NNP'),
#   ('probably', 'RB'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('while', 'NN'),
#   ('u', 'JJ'),
#   ('diks', 'NN')],
#  [],
#  [('@', 'RB'),
#   ('4ever_PlumNelly', 'CD'),
#   ('aww', 'NN'),
#   ('.', '.'),
#   ('Subway', 'NNP'),
#   ('popping', 'VBG'),
#   ('though', 'IN')],
#  [],
#  [('Some', 'DT'),
#   ('of', 'IN'),
#   ('these', 'DT'),
#   ('speakers', 'NNS'),
#   ('@', 'VBP'),
#   ('the', 'DT'),
#   ('RNC', 'NNP'),
#   ('are', 'VBP'),
#   ('just', 'RB'),
#   ('toooo', 'RB'),
#   ('riveting', 'VBG'),
#   ('to', 'TO'),
#   ('watch', 'VB'),
#   ('.', '.'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('Bianca', 'NNP'),
#   ('told', 'VBD'),
#   ('me', 'PRP'),
#   ('that', 'IN'),
#   ('my', 'PRP$'),
#   ('hair', 'NN'),
#   ('growin', 'VBP'),
#   ('wild', 'JJ'),
#   ('son', 'NN'),
#   ('!', '.'),
#   ('We', 'PRP'),
#   ('need', 'VBP'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('get', 'VB'),
#   ('that', 'DT'),
#   ('cut', 'NN'),
#   (',', ','),
#   ('I', 'PRP'),
#   ('said', 'VBD'),
#   ('I', 'PRP'),
#   ('know', 'VBP'),
#   ('mama', 'RB'),
#   ('.', '.')],
#  [],
#  [('Straightened', 'VBN'),
#   ('my', 'PRP$'),
#   ('hair', 'NN'),
#   ('and', 'CC'),
#   ('its', 'PRP$'),
#   ('already', 'RB'),
#   ('curling', 'NN'),
#   ('and', 'CC'),
#   ('I', 'PRP'),
#   ('have', 'VBP'),
#   ("n't", 'RB'),
#   ('even', 'RB'),
#   ('went', 'VBD'),
#   ('outside', 'JJ'),
#   ('yet', 'RB'),
#   ('...', ':'),
#   ('.', '.'),
#   ('#', '#'),
#   ('greaaat', 'JJ'),
#   ('#', '#'),
#   ('sarcasm', 'NN')],
#  [],
#  [('@', 'JJ'),
#   ('LaurenCarey4', 'NNP'),
#   ('oooh', 'NN'),
#   ('lucky', 'NN'),
#   ('!', '.'),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ('2', 'CD'),
#   ('classes', 'NNS'),
#   ('and', 'CC'),
#   ('1', 'CD'),
#   ('lab', 'NN'),
#   ('but', 'CC'),
#   ('textttt', 'IN'),
#   ('me', 'PRP'),
#   (':', ':'),
#   (')', ')')],
#  ...]

# %%
# Iterate through all tweets, extracting only the POS tags

list2 = []

iter = 0
for i in tagged_list:
    length = len(i)
    for j in range(0,length):
        list2.append(tagged_list[iter][j][1])
    iter+=1
    list2.append("\n") # Note: this adds two newline characters for some reason
list2
# Out:
# ['RB',
#  'JJ',
#  'NNS',
#  'IN',
#  'DT',
#  'NN',
#  '.',
#  'NNP',
#  'IN',
#  'CC',
#  'VB',
#  'PRP',
#  'RP',
#  '.',
#  'NN',
#  ':',
#  'NN',
#  '\n',
#  '\n',
#  'DT',
#  'RB',
#  'VBD',
#  'RP',
#  'PRP$',
#  'NN',
#  ':',
#  'POS',
#  ')',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'NNS',
#  'IN',
#  'CC',
#  'PRP',
#  'VBD',
#  'VBN',
#  '.',
#  'RB',
#  'JJ',
#  'NN',
#  'VBD',
#  'DT',
#  'NN',
#  'IN',
#  'JJ',
#  'NN',
#  'IN',
#  'NNP',
#  'NNP',
#  'CC',
#  'NNP',
#  'NNP',
#  'NN',
#  '#',
#  'JJ',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'NNP',
#  'PRP',
#  'VBP',
#  'IN',
#  'CD',
#  'IN',
#  'NNP',
#  'NNP',
#  'NNS',
#  'VBD',
#  'VBN',
#  'IN',
#  'NNP',
#  '.',
#  'NNP',
#  'NNP',
#  'VBZ',
#  'NN',
#  'IN',
#  'DT',
#  'NNP',
#  'NN',
#  '.',
#  'NN',
#  ':',
#  'NN',
#  '\n',
#  '\n',
#  'PRP',
#  'RB',
#  'VB',
#  'VBG',
#  'DT',
#  'NN',
#  '.',
#  'JJ',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'IN',
#  'PRP',
#  'VBP',
#  'VBG',
#  'IN',
#  'NN',
#  'CC',
#  'NN',
#  'VBP',
#  'IN',
#  'JJS',
#  'CD',
#  'NNS',
#  'PRP',
#  'RB',
#  'VBP',
#  'TO',
#  'DT',
#  'JJ',
#  'NN',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'JJ',
#  'NN',
#  'NN',
#  'NN',
#  'PRP',
#  'VBP',
#  'VBG',
#  '.',
#  ':',
#  ')',
#  'WP',
#  'PRP',
#  'VBP',
#  'IN',
#  'NN',
#  '.',
#  '\n',
#  '\n',
#  '$',
#  'CD',
#  'NNP',
#  'NN',
#  'VBZ',
#  'VBG',
#  'RB',
#  'VB',
#  'NN',
#  '.',
#  '.',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'NNP',
#  'VBD',
#  'WP',
#  'DT',
#  'JJ',
#  'NN',
#  'RB',
#  'RB',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'DT',
#  'NN',
#  'IN',
#  'DT',
#  'NN',
#  'CC',
#  'PRP',
#  'VBP',
#  'JJ',
#  'VBG',
#  '#',
#  'JJ',
#  '.',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'DT',
#  'NN',
#  'NN',
#  'NN',
#  'NN',
#  '\n',
#  '\n',
#  'NNP',
#  'IN',
#  'NN',
#  ',',
#  'NN',
#  'MD',
#  'VB',
#  'JJ',
#  '.',
#  '#',
#  'JJ',
#  '#',
#  'NNS',
#  '#',
#  'NNS',
#  '\n',
#  '\n',
#  'IN',
#  'PRP',
#  'MD',
#  'VB',
#  'IN',
#  'NNS',
#  'WRB',
#  'JJ',
#  'PRP',
#  'VBP',
#  'VBG',
#  'RP',
#  'IN',
#  'CD',
#  'VBP',
#  'IN',
#  'NNP',
#  'POS',
#  'PRP',
#  'MD',
#  ':',
#  '.',
#  'JJ',
#  '#',
#  'NN',
#  '.',
#  '\n',
#  '\n',
#  'PRP',
#  'RB',
#  'VBD',
#  'NN',
#  'IN',
#  'PRP$',
#  'NN',
#  'NN',
#  '#',
#  'JJ',
#  '#',
#  'JJ',
#  'NN',
#  '\n',
#  '\n',
#  'NNS',
#  'VBP',
#  'NNP',
#  'PRP$',
#  'NNS',
#  'VBP',
#  'JJ',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'PRP',
#  'RB',
#  'VB',
#  'PRP$',
#  'NN',
#  '.',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'NN',
#  'NN',
#  'PRP',
#  'VBD',
#  'PRP',
#  'MD',
#  'VB',
#  'DT',
#  'NN',
#  'RB',
#  '.',
#  '\n',
#  '\n',
#  'PRP',
#  'RB',
#  'VB',
#  'VBG',
#  'DT',
#  'JJ',
#  'NN',
#  'NN',
#  'CC',
#  'RB',
#  'RB',
#  'VBG',
#  'IN',
#  'PRP',
#  '.',
#  ':',
#  ')',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'NNP',
#  'NN',
#  ',',
#  'NNP',
#  'NN',
#  'RB',
#  'JJR',
#  'IN',
#  'CD',
#  'NN',
#  'IN',
#  'JJ',
#  'NN',
#  'VBG',
#  'TO',
#  'NNP',
#  '.',
#  'NNP',
#  'VBZ',
#  'CD',
#  'IN',
#  'CD',
#  'NN',
#  '.',
#  'NN',
#  ':',
#  'NN',
#  '\n',
#  '\n',
#  'PRP',
#  'VBP',
#  'VBN',
#  'TO',
#  'VB',
#  'PRP$',
#  'NN',
#  'RB',
#  'DT',
#  'NN',
#  'NN',
#  '\n',
#  '\n',
#  'JJ',
#  'NNP',
#  'MD',
#  'VB',
#  'RB',
#  'RP',
#  'NN',
#  '.',
#  'PRP',
#  'VBP',
#  'RB',
#  'RB',
#  ':',
#  'IN',
#  'PRP$',
#  'JJ',
#  ':',
#  'VBG',
#  'NNS',
#  'IN',
#  'NN',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'TO',
#  'NN',
#  'RB',
#  'VBG',
#  'DT',
#  'VBG',
#  'IN',
#  'DT',
#  'NN',
#  'IN',
#  'NNP',
#  'NNP',
#  ':',
#  'NNP',
#  'NNP',
#  'NNP',
#  ',',
#  'NNP',
#  'VBZ',
#  'NNP',
#  'NNP',
#  'POS',
#  'NN',
#  ':',
#  'NN',
#  '.',
#  '\n',
#  '\n',
#  'JJ',
#  'NNP',
#  'NN',
#  ',',
#  'JJ',
#  'NN',
#  'NN',
#  'CD',
#  'NN',
#  '.',
#  ':',
#  'NNP',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'PRP$',
#  'PRP$',
#  'NN',
#  'NNS',
#  ':',
#  'WP',
#  'VBZ',
#  'NN',
#  'TO',
#  'VB',
#  'VBG',
#  'PRP$',
#  'NN',
#  'CC',
#  'WP',
#  'VBZ',
#  'NN',
#  'TO',
#  'VB',
#  'VBG',
#  'PRP$',
#  'NNS',
#  '.',
#  '\n',
#  '\n',
#  'NNP',
#  'NN',
#  '.',
#  'NNP',
#  'VBD',
#  'RP',
#  'DT',
#  'NN',
#  '\n',
#  '\n',
#  'PRP',
#  'DT',
#  'VBP',
#  'DT',
#  'CD',
#  'NN',
#  'WP',
#  'PRP',
#  'VBD',
#  'PRP',
#  'RB',
#  'VBD',
#  'PRP$',
#  'NN',
#  'NN',
#  'TO',
#  ':',
#  '#',
#  'NNP',
#  '\n',
#  '\n',
#  'UH',
#  ',',
#  'VB',
#  'DT',
#  '.',
#  'JJ',
#  'NN',
#  ':',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  ',',
#  'IN',
#  'NN',
#  ',',
#  'CC',
#  'PRP',
#  'RB',
#  'VB',
#  'DT',
#  'NNP',
#  'NN',
#  'NN',
#  ':',
#  'NN',
#  '\n',
#  '\n',
#  'VBG',
#  'DT',
#  'NN',
#  '#',
#  'NNP',
#  'NN',
#  'JJ',
#  'JJ',
#  'NNS',
#  'VBP',
#  '\n',
#  '\n',
#  'JJ',
#  'NNP',
#  'IN',
#  'PRP$',
#  'NNP',
#  'MD',
#  'VB',
#  'PRP',
#  'VB',
#  'RB',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'NN',
#  'TO',
#  'VB',
#  'NN',
#  ':',
#  '.',
#  '\n',
#  '\n',
#  '#',
#  'NNP',
#  'NNP',
#  'JJ',
#  'NN',
#  'VBD',
#  'JJ',
#  'NN',
#  'DT',
#  'CD',
#  'NN',
#  '.',
#  'NNP',
#  ',',
#  'RB',
#  'WP',
#  'DT',
#  'NN',
#  'VBZ',
#  '.',
#  'JJ',
#  'JJ',
#  'VBP',
#  'NN',
#  'RBR',
#  'IN',
#  'NNS',
#  '.',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'JJ',
#  'NNP',
#  'NNP',
#  'NNP',
#  ':',
#  'PRP',
#  'VBP',
#  'JJ',
#  'NN',
#  'NNP',
#  'NN',
#  'MD',
#  'VB',
#  'DT',
#  'JJ',
#  'JJ',
#  'NN',
#  'IN',
#  'NN',
#  '#',
#  'NNP',
#  '\n',
#  '\n',
#  'PRP',
#  'VBP',
#  'TO',
#  'VB',
#  'RB',
#  ':',
#  'NN',
#  ':',
#  'NN',
#  '\n',
#  '\n',
#  'NNP',
#  'JJS',
#  'JJ',
#  'NNS',
#  ',',
#  'PRP',
#  'RB',
#  'VBD',
#  'NN',
#  'IN',
#  '$',
#  'CD',
#  'NN',
#  'NNP',
#  'NNP',
#  ',',
#  'NNP',
#  'NNP',
#  ',',
#  'NNP',
#  'NNP',
#  ',',
#  'NNP',
#  'NNP',
#  ',',
#  '#',
#  'NNP',
#  '\n',
#  '\n',
#  'JJ',
#  'NNP',
#  'FW',
#  'NN',
#  'TO',
#  'VB',
#  'RB',
#  'RB',
#  'IN',
#  'RB',
#  'IN',
#  'DT',
#  'CD',
#  'NN',
#  'RB',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'IN',
#  'PRP',
#  'VBZ',
#  'CD',
#  'NN',
#  'JJ',
#  'NN',
#  '.',
#  'PRP',
#  'VBP',
#  'RB',
#  'JJ',
#  'JJ',
#  'PRP',
#  'MD',
#  'RB',
#  'VB',
#  'PRP',
#  '.',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'PRP',
#  'VBP',
#  'PRP',
#  'WRB',
#  'PRP$',
#  'NN',
#  'VBZ',
#  'RP',
#  'CC',
#  'NNS',
#  'IN',
#  'PDT',
#  'DT',
#  'NNS',
#  ':',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  '#',
#  'CD',
#  'RB',
#  'RB',
#  'IN',
#  'PRP',
#  'VBP',
#  'PRP',
#  'IN',
#  'NN',
#  'PRP',
#  'VBP',
#  'NN',
#  '.',
#  '\n',
#  '\n',
#  'RB',
#  'VBN',
#  'PRP$',
#  'NN',
#  '.',
#  'JJ',
#  'NNS',
#  '.',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'JJ',
#  'NNS',
#  'VBP',
#  'NN',
#  'NN',
#  'VBP',
#  'PRP$',
#  'NNS',
#  'RB',
#  '.',
#  '\n',
#  '\n',
#  'NNP',
#  'NN',
#  'PRP',
#  'VBD',
#  'IN',
#  'DT',
#  'NN',
#  'DT',
#  'NN',
#  '.',
#  '\n',
#  '\n',
#  'DT',
#  'JJ',
#  'JJ',
#  'TO',
#  'VB',
#  'NN',
#  'RB',
#  'CD',
#  'NNS',
#  'IN',
#  'CD',
#  'NN',
#  'MD',
#  'VB',
#  'NN',
#  ':',
#  '\n',
#  '\n',
#  'JJ',
#  'NNP',
#  'NNP',
#  'POS',
#  '.',
#  'CD',
#  'NN',
#  '.',
#  'JJ',
#  'NNP',
#  'NNP',
#  '.',
#  'NNP',
#  'IN',
#  'NNP',
#  'VBP',
#  'CC',
#  'VBP',
#  ':',
#  'NNP',
#  'NNP',
#  '.',
#  '$',
#  'CD',
#  'NNP',
#  ':',
#  'NN',
#  ':',
#  'NN',
#  '\n',
#  '\n',
#  'PRP',
#  'VBP',
#  'WP',
#  'PRP',
#  'VBP',
#  'VBG',
#  '.',
#  'VBG',
#  'JJ',
#  'NNS',
#  '.',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  '``',
#  'JJ',
#  'NN',
#  ':',
#  'PRP',
#  'VBP',
#  'JJ',
#  'NNP',
#  'CC',
#  'NNP',
#  'NNP',
#  'JJ',
#  'TO',
#  'VB',
#  'NN',
#  'IN',
#  'NNP',
#  'NNP',
#  '.',
#  "''",
#  'NNP',
#  '.',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'WRB',
#  'PRP',
#  'RB',
#  'VBP',
#  'JJ',
#  'NN',
#  'NN',
#  'NN',
#  'NN',
#  '\n',
#  '\n',
#  'JJ',
#  'PRP',
#  'VBZ',
#  'DT',
#  'NNP',
#  'NN',
#  'VBG',
#  'RB',
#  'VBN',
#  'RB',
#  'IN',
#  'NN',
#  '.',
#  'NN',
#  'IN',
#  'VBG',
#  'PRP',
#  'MD',
#  'RB',
#  'VB',
#  'DT',
#  'NNP',
#  '.',
#  '#',
#  'NNP',
#  '\n',
#  '\n',
#  'NN',
#  'NN',
#  'RB',
#  'PRP',
#  'VBP',
#  'IN',
#  'PRP',
#  'VBD',
#  'VBG',
#  'NN',
#  'NN',
#  '.',
#  '\n',
#  '\n',
#  'PRP',
#  'RB',
#  'VB',
#  'VBG',
#  'RP',
#  'DT',
#  'JJ',
#  'TO',
#  'VB',
#  'IN',
#  'NN',
#  '#',
#  'NN',
#  '#',
#  'VBD',
#  '#',
#  'NN',
#  ':',
#  'NN',
#  '\n',
#  '\n',
#  'NNP',
#  'NNP',
#  ',',
#  'NN',
#  'PRP',
#  'IN',
#  'VBG',
#  'PRP',
#  'IN',
#  'DT',
#  'JJ',
#  'NNS',
#  'IN',
#  'VBG',
#  '.',
#  'PRP$',
#  'RB',
#  'VBG',
#  'TO',
#  'VB',
#  'JJ',
#  'NNS',
#  'VBP',
#  'NN',
#  '.',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'JJ',
#  'NNP',
#  'NNP',
#  ',',
#  'CC',
#  'NNP',
#  'VBZ',
#  'DT',
#  'NN',
#  'IN',
#  'NN',
#  'WDT',
#  'RB',
#  'VBZ',
#  'PRP',
#  'VBP',
#  'TO',
#  'VB',
#  'IN',
#  'PRP',
#  '.',
#  '#',
#  'NN',
#  '\n',
#  '\n',
#  'PRP$',
#  'JJ',
#  'JJ',
#  'NN',
#  ':',
#  'VBG',
#  'DT',
#  'VBN',
#  'NN',
#  'NN',
#  '.',
#  '#',
#  'NNP',
#  '\n',
#  '\n',
#  'JJ',
#  'NN',
#  'JJ',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'NNS',
#  'RB',
#  '\n',
#  '\n',
#  'JJ',
#  'NN',
#  'NN',
#  'PRP',
#  'MD',
#  'VB',
#  'JJR',
#  'NN',
#  'IN',
#  'NN',
#  ...]

# %%
# Organize the POS tags into individual tweets

list3 = []
list4 = []
for i in list2:
    if (i is not '\n'):
        if(i.startswith("V")):  # Replace all verb instances (e.g., VBD) with just V
            i = "V"
        if(i.startswith("N")): # Replace all noun instances (e.g., NNS) with N
            i = "N"
        if(i.startswith("PRP")): # Repalce all pronoun instances (e.g., PRP$) with PRP
            i = "PRP"
        if(i.startswith("JJ")):
            i = "JJ"
        list3.append(i)
    else:
        list4.append(list3)
        list3 = []
list4
# Out:
# [['RB',
#   'JJ',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   '.',
#   'N',
#   'IN',
#   'CC',
#   'V',
#   'PRP',
#   'RP',
#   '.',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['DT', 'RB', 'V', 'RP', 'PRP', 'N', ':', 'POS', ')', '#', 'N'],
#  [],
#  ['N',
#   'IN',
#   'CC',
#   'PRP',
#   'V',
#   'V',
#   '.',
#   'RB',
#   'JJ',
#   'N',
#   'V',
#   'DT',
#   'N',
#   'IN',
#   'JJ',
#   'N',
#   'IN',
#   'N',
#   'N',
#   'CC',
#   'N',
#   'N',
#   'N',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'PRP',
#   'V',
#   'IN',
#   'CD',
#   'IN',
#   'N',
#   'N',
#   'N',
#   'V',
#   'V',
#   'IN',
#   'N',
#   '.',
#   'N',
#   'N',
#   'V',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   'N',
#   '.',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['PRP', 'RB', 'V', 'V', 'DT', 'N', '.', 'JJ', '#', 'N'],
#  [],
#  ['IN',
#   'PRP',
#   'V',
#   'V',
#   'IN',
#   'N',
#   'CC',
#   'N',
#   'V',
#   'IN',
#   'JJ',
#   'CD',
#   'N',
#   'PRP',
#   'RB',
#   'V',
#   'TO',
#   'DT',
#   'JJ',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'N',
#   'PRP',
#   'V',
#   'V',
#   '.',
#   ':',
#   ')',
#   'WP',
#   'PRP',
#   'V',
#   'IN',
#   'N',
#   '.'],
#  [],
#  ['$', 'CD', 'N', 'N', 'V', 'V', 'RB', 'V', 'N', '.', '.', '#', 'N'],
#  [],
#  ['N',
#   'V',
#   'WP',
#   'DT',
#   'JJ',
#   'N',
#   'RB',
#   'RB',
#   '.',
#   'PRP',
#   'MD',
#   'V',
#   'DT',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   'CC',
#   'PRP',
#   'V',
#   'JJ',
#   'V',
#   '#',
#   'JJ',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['DT', 'N', 'N', 'N', 'N'],
#  [],
#  ['N',
#   'IN',
#   'N',
#   ',',
#   'N',
#   'MD',
#   'V',
#   'JJ',
#   '.',
#   '#',
#   'JJ',
#   '#',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['IN',
#   'PRP',
#   'MD',
#   'V',
#   'IN',
#   'N',
#   'WRB',
#   'JJ',
#   'PRP',
#   'V',
#   'V',
#   'RP',
#   'IN',
#   'CD',
#   'V',
#   'IN',
#   'N',
#   'POS',
#   'PRP',
#   'MD',
#   ':',
#   '.',
#   'JJ',
#   '#',
#   'N',
#   '.'],
#  [],
#  ['PRP', 'RB', 'V', 'N', 'IN', 'PRP', 'N', 'N', '#', 'JJ', '#', 'JJ', 'N'],
#  [],
#  ['N', 'V', 'N', 'PRP', 'N', 'V', 'JJ', '#', 'N'],
#  [],
#  ['PRP', 'RB', 'V', 'PRP', 'N', '.', '#', 'N'],
#  [],
#  ['N', 'N', 'PRP', 'V', 'PRP', 'MD', 'V', 'DT', 'N', 'RB', '.'],
#  [],
#  ['PRP',
#   'RB',
#   'V',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'N',
#   'CC',
#   'RB',
#   'RB',
#   'V',
#   'IN',
#   'PRP',
#   '.',
#   ':',
#   ')',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   ',',
#   'N',
#   'N',
#   'RB',
#   'JJ',
#   'IN',
#   'CD',
#   'N',
#   'IN',
#   'JJ',
#   'N',
#   'V',
#   'TO',
#   'N',
#   '.',
#   'N',
#   'V',
#   'CD',
#   'IN',
#   'CD',
#   'N',
#   '.',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['PRP', 'V', 'V', 'TO', 'V', 'PRP', 'N', 'RB', 'DT', 'N', 'N'],
#  [],
#  ['JJ',
#   'N',
#   'MD',
#   'V',
#   'RB',
#   'RP',
#   'N',
#   '.',
#   'PRP',
#   'V',
#   'RB',
#   'RB',
#   ':',
#   'IN',
#   'PRP',
#   'JJ',
#   ':',
#   'V',
#   'N',
#   'IN',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['TO',
#   'N',
#   'RB',
#   'V',
#   'DT',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   'IN',
#   'N',
#   'N',
#   ':',
#   'N',
#   'N',
#   'N',
#   ',',
#   'N',
#   'V',
#   'N',
#   'N',
#   'POS',
#   'N',
#   ':',
#   'N',
#   '.'],
#  [],
#  ['JJ', 'N', 'N', ',', 'JJ', 'N', 'N', 'CD', 'N', '.', ':', 'N', '#', 'N'],
#  [],
#  ['PRP',
#   'PRP',
#   'N',
#   'N',
#   ':',
#   'WP',
#   'V',
#   'N',
#   'TO',
#   'V',
#   'V',
#   'PRP',
#   'N',
#   'CC',
#   'WP',
#   'V',
#   'N',
#   'TO',
#   'V',
#   'V',
#   'PRP',
#   'N',
#   '.'],
#  [],
#  ['N', 'N', '.', 'N', 'V', 'RP', 'DT', 'N'],
#  [],
#  ['PRP',
#   'DT',
#   'V',
#   'DT',
#   'CD',
#   'N',
#   'WP',
#   'PRP',
#   'V',
#   'PRP',
#   'RB',
#   'V',
#   'PRP',
#   'N',
#   'N',
#   'TO',
#   ':',
#   '#',
#   'N'],
#  [],
#  ['UH',
#   ',',
#   'V',
#   'DT',
#   '.',
#   'JJ',
#   'N',
#   ':',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   ',',
#   'IN',
#   'N',
#   ',',
#   'CC',
#   'PRP',
#   'RB',
#   'V',
#   'DT',
#   'N',
#   'N',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['V', 'DT', 'N', '#', 'N', 'N', 'JJ', 'JJ', 'N', 'V'],
#  [],
#  ['JJ', 'N', 'IN', 'PRP', 'N', 'MD', 'V', 'PRP', 'V', 'RB', '#', 'N'],
#  [],
#  ['N', 'TO', 'V', 'N', ':', '.'],
#  [],
#  ['#',
#   'N',
#   'N',
#   'JJ',
#   'N',
#   'V',
#   'JJ',
#   'N',
#   'DT',
#   'CD',
#   'N',
#   '.',
#   'N',
#   ',',
#   'RB',
#   'WP',
#   'DT',
#   'N',
#   'V',
#   '.',
#   'JJ',
#   'JJ',
#   'V',
#   'N',
#   'RBR',
#   'IN',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'N',
#   ':',
#   'PRP',
#   'V',
#   'JJ',
#   'N',
#   'N',
#   'N',
#   'MD',
#   'V',
#   'DT',
#   'JJ',
#   'JJ',
#   'N',
#   'IN',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['PRP', 'V', 'TO', 'V', 'RB', ':', 'N', ':', 'N'],
#  [],
#  ['N',
#   'JJ',
#   'JJ',
#   'N',
#   ',',
#   'PRP',
#   'RB',
#   'V',
#   'N',
#   'IN',
#   '$',
#   'CD',
#   'N',
#   'N',
#   'N',
#   ',',
#   'N',
#   'N',
#   ',',
#   'N',
#   'N',
#   ',',
#   'N',
#   'N',
#   ',',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'FW',
#   'N',
#   'TO',
#   'V',
#   'RB',
#   'RB',
#   'IN',
#   'RB',
#   'IN',
#   'DT',
#   'CD',
#   'N',
#   'RB',
#   '#',
#   'N'],
#  [],
#  ['IN',
#   'PRP',
#   'V',
#   'CD',
#   'N',
#   'JJ',
#   'N',
#   '.',
#   'PRP',
#   'V',
#   'RB',
#   'JJ',
#   'JJ',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'PRP',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   'PRP',
#   'WRB',
#   'PRP',
#   'N',
#   'V',
#   'RP',
#   'CC',
#   'N',
#   'IN',
#   'PDT',
#   'DT',
#   'N',
#   ':',
#   '#',
#   'N'],
#  [],
#  ['#',
#   'CD',
#   'RB',
#   'RB',
#   'IN',
#   'PRP',
#   'V',
#   'PRP',
#   'IN',
#   'N',
#   'PRP',
#   'V',
#   'N',
#   '.'],
#  [],
#  ['RB', 'V', 'PRP', 'N', '.', 'JJ', 'N', '.', '#', 'N'],
#  [],
#  ['JJ', 'N', 'V', 'N', 'N', 'V', 'PRP', 'N', 'RB', '.'],
#  [],
#  ['N', 'N', 'PRP', 'V', 'IN', 'DT', 'N', 'DT', 'N', '.'],
#  [],
#  ['DT',
#   'JJ',
#   'JJ',
#   'TO',
#   'V',
#   'N',
#   'RB',
#   'CD',
#   'N',
#   'IN',
#   'CD',
#   'N',
#   'MD',
#   'V',
#   'N',
#   ':'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'POS',
#   '.',
#   'CD',
#   'N',
#   '.',
#   'JJ',
#   'N',
#   'N',
#   '.',
#   'N',
#   'IN',
#   'N',
#   'V',
#   'CC',
#   'V',
#   ':',
#   'N',
#   'N',
#   '.',
#   '$',
#   'CD',
#   'N',
#   ':',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['PRP', 'V', 'WP', 'PRP', 'V', 'V', '.', 'V', 'JJ', 'N', '.', '#', 'N'],
#  [],
#  ['``',
#   'JJ',
#   'N',
#   ':',
#   'PRP',
#   'V',
#   'JJ',
#   'N',
#   'CC',
#   'N',
#   'N',
#   'JJ',
#   'TO',
#   'V',
#   'N',
#   'IN',
#   'N',
#   'N',
#   '.',
#   "''",
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['WRB', 'PRP', 'RB', 'V', 'JJ', 'N', 'N', 'N', 'N'],
#  [],
#  ['JJ',
#   'PRP',
#   'V',
#   'DT',
#   'N',
#   'N',
#   'V',
#   'RB',
#   'V',
#   'RB',
#   'IN',
#   'N',
#   '.',
#   'N',
#   'IN',
#   'V',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'DT',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N', 'N', 'RB', 'PRP', 'V', 'IN', 'PRP', 'V', 'V', 'N', 'N', '.'],
#  [],
#  ['PRP',
#   'RB',
#   'V',
#   'V',
#   'RP',
#   'DT',
#   'JJ',
#   'TO',
#   'V',
#   'IN',
#   'N',
#   '#',
#   'N',
#   '#',
#   'V',
#   '#',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['N',
#   'N',
#   ',',
#   'N',
#   'PRP',
#   'IN',
#   'V',
#   'PRP',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'V',
#   '.',
#   'PRP',
#   'RB',
#   'V',
#   'TO',
#   'V',
#   'JJ',
#   'N',
#   'V',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   ',',
#   'CC',
#   'N',
#   'V',
#   'DT',
#   'N',
#   'IN',
#   'N',
#   'WDT',
#   'RB',
#   'V',
#   'PRP',
#   'V',
#   'TO',
#   'V',
#   'IN',
#   'PRP',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['PRP', 'JJ', 'JJ', 'N', ':', 'V', 'DT', 'V', 'N', 'N', '.', '#', 'N'],
#  [],
#  ['JJ', 'N', 'JJ', '.', 'PRP', 'MD', 'V', 'N', 'RB'],
#  [],
#  ['JJ', 'N', 'N', 'PRP', 'MD', 'V', 'JJ', 'N', 'IN', 'N', '#', 'N'],
#  [],
#  ['N', 'N', 'V', 'DT', 'JJ', 'JJ', 'N', 'N', 'V', 'DT', 'CD'],
#  [],
#  ['RB', ',', 'N', 'V', 'V', 'IN', 'TO', 'DT', 'N', 'N', '.', '#', 'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   '.',
#   'PRP',
#   'N',
#   'V',
#   'RB',
#   'V',
#   'WRB',
#   'PRP',
#   'V',
#   'RB',
#   'JJ',
#   'IN',
#   'DT',
#   'N',
#   '.',
#   'N',
#   'N'],
#  [],
#  ['#', 'N', ':', 'V', 'PRP'],
#  [],
#  ['WP', 'TO', 'V', '.', 'V', 'V', 'N', 'N', 'N', 'N', 'N', ':', 'N'],
#  [],
#  ['``',
#   'N',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   "''",
#   'N',
#   'N',
#   'PRP',
#   'V',
#   'DT',
#   'RP',
#   'DT',
#   'N',
#   'N',
#   'N',
#   'PRP',
#   'V',
#   'TO',
#   'N',
#   'IN',
#   'N',
#   '.',
#   '#',
#   'N',
#   '.'],
#  [],
#  ['N',
#   'N',
#   'N',
#   '#',
#   'N',
#   'IN',
#   'N',
#   'N',
#   'CC',
#   'N',
#   ':',
#   'CC',
#   'N',
#   '.',
#   '.',
#   '.',
#   'IN',
#   'PRP',
#   'V',
#   'DT',
#   'N',
#   'POS',
#   '#',
#   'CD',
#   'N',
#   ':',
#   ')',
#   'CC',
#   'N',
#   ':',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['V', 'DT', 'N', 'N', 'RB', '#', 'JJ', '#', 'N', '.'],
#  [],
#  ['N',
#   'N',
#   '#',
#   'N',
#   ',',
#   'N',
#   'N',
#   'N',
#   'CC',
#   'N',
#   ':',
#   'N',
#   'IN',
#   'N',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   'N',
#   '.',
#   'N',
#   'PRP',
#   'IN',
#   ',',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   'V',
#   'JJ',
#   ',',
#   'CC',
#   'JJ',
#   'V',
#   'RP',
#   'DT',
#   'N',
#   'V',
#   'PRP',
#   'N',
#   'DT',
#   'N',
#   'RB',
#   'V',
#   'PRP',
#   'V',
#   'RB',
#   'IN',
#   'PRP',
#   'V',
#   'DT',
#   'N',
#   'V',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   '#',
#   'N',
#   'V',
#   'DT',
#   'JJ',
#   'JJ',
#   'IN',
#   'N',
#   'N',
#   'V',
#   'JJ',
#   'N',
#   ':',
#   'JJ',
#   'V',
#   'N',
#   'POS',
#   'JJ',
#   'N'],
#  [],
#  ['N',
#   '(',
#   'N',
#   ')',
#   ':',
#   'JJ',
#   'N',
#   'V',
#   'TO',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'N',
#   'IN',
#   'JJ',
#   'N',
#   'N',
#   ',',
#   'N',
#   ':',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['PRP', 'V', 'V', '.', 'DT', 'N', 'V', 'V', 'V', 'JJ', '#', 'N'],
#  [],
#  ['N', 'V', 'JJ', 'PRP', 'JJ', 'JJ', 'N', '.'],
#  [],
#  ['PRP',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'N',
#   'N',
#   ':',
#   'N',
#   'N',
#   'N',
#   ':',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N'],
#  [],
#  ['CC', 'PRP', 'V', 'JJ', 'RB', 'RB'],
#  [],
#  ['IN',
#   'N',
#   'IN',
#   'N',
#   'N',
#   '.',
#   'N',
#   'JJ',
#   'N',
#   ':',
#   ')',
#   'N',
#   'IN',
#   'N',
#   ':',
#   'CD',
#   'WP',
#   'CD',
#   'N',
#   ':',
#   'N',
#   '#',
#   'JJ'],
#  [],
#  ['PRP',
#   'V',
#   'V',
#   'RP',
#   'IN',
#   'DT',
#   'RB',
#   'N',
#   'WP',
#   'V',
#   'PRP',
#   'V',
#   'V',
#   'TO',
#   'V',
#   '.'],
#  [],
#  ['IN',
#   'PRP',
#   'V',
#   'V',
#   'IN',
#   'DT',
#   ':',
#   'N',
#   '.',
#   'JJ',
#   'JJ',
#   'N',
#   ':',
#   'N',
#   'N',
#   ':',
#   '``',
#   'PRP',
#   'N',
#   'RB',
#   'V',
#   'V',
#   'RP',
#   'N',
#   "''",
#   'N'],
#  [],
#  ['V', 'DT', 'JJ', 'N', 'IN', 'N', '.', '#', 'JJ', '#', 'V'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   ',',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'TO',
#   'V',
#   'N',
#   'CC',
#   ':',
#   'N',
#   '.'],
#  [],
#  ['RB',
#   'V',
#   'IN',
#   'CD',
#   'IN',
#   'DT',
#   'N',
#   'N',
#   'CC',
#   'N',
#   ':',
#   'PRP',
#   'V',
#   'RP',
#   'IN',
#   'IN',
#   'N',
#   'N',
#   '.',
#   '#',
#   'N',
#   '.'],
#  [],
#  ['N',
#   ',',
#   'N',
#   '.',
#   'PRP',
#   'V',
#   'RB',
#   'TO',
#   'V',
#   'RB',
#   'CC',
#   'V',
#   'PRP',
#   'N',
#   '.',
#   'CC',
#   'JJ',
#   'N',
#   'V',
#   'TO',
#   'PRP',
#   'N',
#   'CC',
#   'N',
#   'RB',
#   'RB',
#   '#',
#   'N'],
#  [],
#  ['PRP', 'MD', 'RB', 'V', 'TO', 'V', 'TO', 'DT', 'N', 'JJ', 'JJ', '#', 'N'],
#  [],
#  ['DT', 'N', 'V', 'IN', 'JJ', 'IN', 'JJ', 'N', '.', '#', 'N', '#', 'N', 'N'],
#  [],
#  ['N',
#   'IN',
#   'PRP',
#   'N',
#   'N',
#   'V',
#   'TO',
#   'V',
#   'DT',
#   'RBS',
#   'JJ',
#   'V',
#   'N',
#   'RB'],
#  [],
#  ['V', 'DT', 'N', 'IN', 'N', ':', '#', 'JJ', '#', 'N'],
#  [],
#  ['PRP', 'V', 'RB', 'V', 'TO', 'DT', 'JJ', 'N', 'N', ':', '('],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'V',
#   'RB',
#   'PRP',
#   'JJ',
#   'N',
#   ',',
#   'PRP',
#   'MD',
#   'V',
#   'DT',
#   'JJ',
#   'JJ',
#   'JJ',
#   ':',
#   '#',
#   'N',
#   'WRB',
#   'V',
#   'PRP',
#   'V',
#   'TO',
#   'V'],
#  [],
#  ['N', 'N', 'V', 'RB', 'V', 'V', 'JJ', 'N', 'N', 'N'],
#  [],
#  ['N',
#   'TO',
#   'V',
#   'TO',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'RB',
#   'N',
#   ',',
#   'UH',
#   ',',
#   'DT',
#   'V',
#   'RB',
#   'RB',
#   '.',
#   '#',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   'V',
#   'RP',
#   'WP',
#   'PRP',
#   'JJ',
#   'N',
#   'V',
#   '.',
#   'PRP',
#   'V',
#   'RB',
#   'RB',
#   'DT',
#   'JJ',
#   '.',
#   '(',
#   ':'],
#  ['#', 'N'],
#  [],
#  ['DT',
#   'N',
#   'N',
#   'POS',
#   'JJ',
#   'N',
#   'N',
#   'V',
#   'TO',
#   'V',
#   'DT',
#   'N',
#   'WDT',
#   'V',
#   'JJ',
#   'N',
#   'POS',
#   'IN',
#   'N',
#   'N',
#   ':',
#   '#',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'N',
#   '.',
#   'V',
#   'PRP',
#   'V',
#   'WP',
#   'PRP',
#   'V',
#   '.',
#   'RB',
#   'V',
#   '.'],
#  [],
#  ['N', ':', 'N'],
#  [],
#  ['N', 'V', 'N', 'CD', ',', 'IN', 'N', '.'],
#  [],
#  ['N', 'N', 'PRP', 'V', 'JJ', '#', 'N'],
#  [],
#  ['JJ', 'N', 'N', 'IN', 'N', 'N', 'N', 'N'],
#  [],
#  ['``',
#   'N',
#   'MD',
#   'V',
#   'PRP',
#   'IN',
#   'DT',
#   'N',
#   ',',
#   'CC',
#   'PRP',
#   'V',
#   'RP',
#   'TO',
#   'PRP',
#   'TO',
#   'V',
#   'N',
#   'IN',
#   'PRP',
#   '.',
#   "''"],
#  [],
#  ['N',
#   'V',
#   'IN',
#   'N',
#   'IN',
#   '``',
#   'N',
#   'POS',
#   'N',
#   "''",
#   'IN',
#   'N',
#   'IN',
#   'N',
#   ':',
#   'UH',
#   ',',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   'JJ',
#   'N',
#   ':',
#   '#',
#   'N'],
#  [],
#  ['IN', 'PRP', 'V', 'PRP', 'JJ', 'N', '#', 'N'],
#  [],
#  ['V',
#   'JJ',
#   'N',
#   'IN',
#   'N',
#   '.',
#   'V',
#   'PRP',
#   'IN',
#   'DT',
#   'N',
#   '.',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['PRP', 'V', 'V', 'RP', 'CC', 'V', 'RB', 'TO', 'V'],
#  [],
#  ['JJ', 'N', 'V', 'DT', 'N', 'WP', 'V', 'IN', 'N', ':', '#', 'N'],
#  [],
#  ['JJ',
#   'N',
#   ':',
#   'RB',
#   'V',
#   'PRP',
#   'CD',
#   'N',
#   'TO',
#   'V',
#   '.',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'PRP',
#   'V',
#   'DT',
#   'N',
#   'JJ',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N', '#', 'N'],
#  [],
#  ['IN',
#   'DT',
#   'N',
#   'IN',
#   'RB',
#   'JJ',
#   'N',
#   ',',
#   'N',
#   'N',
#   'V',
#   'RP',
#   'DT',
#   'JJ',
#   'N',
#   'N',
#   'POS',
#   'JJ',
#   'N',
#   'N',
#   'N',
#   ':',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   'WRB',
#   'PRP',
#   'V',
#   'V',
#   'N',
#   'IN',
#   'N',
#   'CC',
#   'N',
#   ':',
#   'DT',
#   'N',
#   'V',
#   'DT',
#   'IN',
#   'PRP',
#   ',',
#   'PRP',
#   'DT',
#   'JJ',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['V',
#   'V',
#   'DT',
#   'JJ',
#   'TO',
#   'V',
#   'RP',
#   'PRP',
#   'N',
#   'CC',
#   'N',
#   'N',
#   'N',
#   '.',
#   'CC',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   ',',
#   'N',
#   'N',
#   '.',
#   'N',
#   '#',
#   'V',
#   '#',
#   'JJ',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['PRP', 'V', 'DT', 'N', 'PRP', 'V', 'N', ',', 'V', 'PRP', 'RB', 'V'],
#  [],
#  ['V', 'PRP', 'JJ', 'IN', 'DT', '#', 'V', 'N', 'N', 'N', ':', 'N', 'N'],
#  [],
#  ['IN',
#   'JJ',
#   'DT',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   'N',
#   'V',
#   'RB',
#   'N',
#   '.',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   'N',
#   'RB',
#   'WP',
#   'V',
#   'V',
#   ':',
#   'N',
#   'N',
#   'V',
#   'N',
#   'IN',
#   'N',
#   'IN',
#   'N'],
#  [],
#  ['JJ', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', ':', 'N'],
#  [],
#  ['N',
#   ',',
#   'N',
#   'N',
#   'V',
#   'RB',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   ':',
#   'N',
#   'N',
#   'N',
#   'N',
#   '(',
#   'N',
#   ')',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['PRP',
#   'MD',
#   'RB',
#   'RB',
#   'V',
#   'WRB',
#   'JJ',
#   'PRP',
#   'V',
#   'TO',
#   'V',
#   'N',
#   'N',
#   'IN',
#   'CD',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['IN',
#   'PRP',
#   'N',
#   'V',
#   'V',
#   'PRP',
#   'N',
#   'RB',
#   'V',
#   'JJ',
#   'N',
#   'N',
#   'V',
#   'N',
#   'N',
#   'N',
#   'N',
#   'V',
#   'JJ',
#   'IN',
#   'PRP',
#   'JJ',
#   'V',
#   'CD',
#   'N'],
#  [],
#  ['JJ', 'N', '#', 'JJ', '#', 'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'N',
#   'N',
#   ',',
#   'N',
#   'CC',
#   'N',
#   'V',
#   'RB',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'MD',
#   'DT',
#   'N',
#   '.',
#   'PRP',
#   'V',
#   'RB',
#   'V',
#   'DT',
#   'V',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   '.',
#   '#',
#   'N',
#   '.'],
#  [],
#  ['N',
#   'N',
#   'N',
#   ':',
#   ')',
#   ')',
#   'N',
#   'N',
#   'N',
#   'JJ',
#   'V',
#   'V',
#   'JJ',
#   'JJ',
#   'N',
#   'N',
#   'N'],
#  [],
#  ['PRP',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   'N',
#   'IN',
#   'N',
#   'V',
#   'N',
#   'RB',
#   'RB',
#   'PRP',
#   'MD',
#   'V',
#   'V',
#   'PRP',
#   'TO',
#   'PRP',
#   'JJ',
#   'N',
#   '.',
#   'V',
#   'RP',
#   'PRP',
#   'N',
#   'TO',
#   'V',
#   'JJ',
#   '.'],
#  [],
#  ['N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   ':',
#   'N',
#   '.',
#   'N',
#   ':',
#   'JJ',
#   'IN',
#   'JJ',
#   'N'],
#  [],
#  ['PRP',
#   'RB',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'JJ',
#   'N',
#   'V',
#   'PRP',
#   'DT',
#   'CC',
#   'N',
#   ':',
#   'CC',
#   ':',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'TO',
#   'V',
#   'N',
#   'IN',
#   'PRP',
#   'JJ',
#   'N',
#   'N',
#   '.',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   'N',
#   'N',
#   'N',
#   'IN',
#   'N',
#   ':',
#   'N',
#   ':',
#   '.',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['DT', 'JJ', 'N', 'MD', 'RB', 'V', 'PRP', 'N'],
#  [],
#  ['JJ',
#   'N',
#   'V',
#   'DT',
#   'RBS',
#   'JJ',
#   'N',
#   'PRP',
#   'V',
#   'RB',
#   'V',
#   '.',
#   'JJ',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['PRP',
#   'N',
#   'JJ',
#   'N',
#   'V',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   '#',
#   'N',
#   'V',
#   'PRP',
#   'MD',
#   'V',
#   'N',
#   'N'],
#  [],
#  ['DT',
#   'PRP',
#   'V',
#   'IN',
#   'N',
#   'N',
#   'V',
#   ':',
#   'CD',
#   'N',
#   'N',
#   '.',
#   'N',
#   'N',
#   ':',
#   'N',
#   'N',
#   ':',
#   ':',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['RB', 'V', 'V', 'V', 'TO', 'V', '#', 'N'],
#  [],
#  ['N', 'JJ', 'N', 'V', 'DT', 'JJ', 'N', '#', 'N'],
#  [],
#  ['PRP',
#   'V',
#   'V',
#   'RB',
#   'TO',
#   'N',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'N',
#   'N',
#   ':',
#   '#',
#   'N',
#   '.',
#   '#',
#   'N',
#   '.'],
#  [],
#  ['JJ', 'N', 'N', 'N', 'N', '.', '.'],
#  [],
#  ['DT',
#   'N',
#   'N',
#   'V',
#   'RP',
#   '.',
#   'N',
#   ':',
#   'JJ',
#   'N',
#   'N',
#   'N',
#   'N',
#   'IN',
#   'N',
#   'FW',
#   'N',
#   'N'],
#  [],
#  ['V',
#   'V',
#   'V',
#   'RB',
#   'IN',
#   'DT',
#   'N',
#   'IN',
#   'N',
#   'V',
#   'CC',
#   'V',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['JJ', 'N', 'V', 'PRP', 'IN', 'DT', 'N', 'N', 'N', 'CC', 'N', ':', 'CD'],
#  [],
#  ['CC',
#   'IN',
#   'N',
#   'IN',
#   'PRP',
#   'DT',
#   'PRP',
#   'N',
#   'V',
#   'RP',
#   '#',
#   'RB',
#   '#',
#   'N'],
#  [],
#  ['PRP', 'V', 'RB', 'JJ', 'PRP', 'RB', 'V', 'IN', 'DT', 'N', '.', '#', 'N'],
#  [],
#  ['N',
#   'RB',
#   ',',
#   'RB',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'RB',
#   'V',
#   'N',
#   'N',
#   'POS',
#   '``',
#   'N',
#   'N',
#   'IN',
#   'V',
#   "''",
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   'V',
#   'TO',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'JJ',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   ':',
#   'JJ',
#   'IN',
#   'N',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['N',
#   'PRP',
#   'N',
#   'V',
#   'RB',
#   'JJ',
#   '.',
#   '.',
#   '.',
#   'UH',
#   'RB',
#   'N',
#   'IN',
#   'JJ',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'V',
#   'N',
#   'POS',
#   'N',
#   'IN',
#   '#',
#   'N',
#   'N',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   '.',
#   'RB',
#   'RB',
#   'IN',
#   'PRP',
#   'V',
#   'RB',
#   'DT',
#   'N',
#   '.',
#   '#',
#   'JJ',
#   '#',
#   'N',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['RB',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'IN',
#   'JJ',
#   'N',
#   'V',
#   'JJ',
#   'CC',
#   'RB',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   'RB',
#   'RB',
#   'RB',
#   'IN',
#   'DT',
#   'IN',
#   'PRP',
#   'IN',
#   'N',
#   'CC',
#   'N',
#   'V',
#   'TO',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'N',
#   'IN',
#   'N',
#   ':',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['N', 'N', 'N', 'IN', 'DT', 'CD', '#', 'N', 'JJ', 'N', ':', 'N'],
#  [],
#  ['JJ', 'N', 'N', 'N', 'PRP', 'V', 'V', 'JJ', 'N', '.', '.', '#', 'N'],
#  [],
#  ['RB', 'DT', 'N', 'WDT', 'V', 'PRP', 'N', 'V', 'DT', 'N', 'N', '.', '#', 'N'],
#  ['N', '#', ':', 'JJ', 'N', ':', 'N'],
#  [],
#  ['DT',
#   'PRP',
#   'N',
#   'N',
#   'IN',
#   'IN',
#   'N',
#   'N',
#   'N',
#   'RB',
#   'IN',
#   'PRP',
#   'N',
#   'N',
#   'V',
#   '.',
#   'RB',
#   'IN',
#   'DT',
#   '#',
#   'JJ',
#   '#',
#   'JJ'],
#  [],
#  ['``',
#   'JJ',
#   'N',
#   "''",
#   'N',
#   'N',
#   'IN',
#   'CD',
#   '.',
#   'RB',
#   'JJ',
#   'JJ',
#   'N',
#   'V',
#   'RB',
#   'V',
#   'IN',
#   'TO',
#   'PRP',
#   'N',
#   '.',
#   '#',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['CD', 'JJ', 'N', 'N', '#', 'RB', '#', 'N'],
#  [],
#  ['PRP', 'V', 'DT', 'N', '.'],
#  [],
#  ['IN',
#   'N',
#   'N',
#   'TO',
#   'N',
#   'N',
#   ':',
#   'N',
#   'N',
#   'POS',
#   'N',
#   'V',
#   'N',
#   'N',
#   'N',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['N', 'N', 'RB', 'V', 'IN', 'V', 'N', '.', '#', 'JJ', '#', 'N', ':', ')'],
#  [],
#  ['N', 'N', 'N', '.', 'PRP', 'V', 'DT', 'N'],
#  [],
#  ['N',
#   'N',
#   'RB',
#   '.',
#   'PRP',
#   'RB',
#   'V',
#   'JJ',
#   'N',
#   'CC',
#   'N',
#   'IN',
#   'V',
#   'PRP',
#   'N',
#   '.',
#   'PRP',
#   'N',
#   'V',
#   'V',
#   '.',
#   'N',
#   ',',
#   'PRP',
#   'V',
#   '.'],
#  [],
#  ['N',
#   ':',
#   'N',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   ':',
#   'N',
#   'V',
#   'V',
#   'RB',
#   'N',
#   'V',
#   'IN',
#   'JJ',
#   ':',
#   'N',
#   ':',
#   '#',
#   'N',
#   '.',
#   '.'],
#  [],
#  ['N',
#   'IN',
#   'DT',
#   'N',
#   ':',
#   'N',
#   '.',
#   'CC',
#   'N',
#   'N',
#   ':',
#   'N',
#   ':',
#   'JJ',
#   'IN',
#   'JJ',
#   'N',
#   'N',
#   'IN',
#   'DT',
#   '.',
#   '.',
#   'JJ',
#   'N'],
#  [],
#  ['N',
#   'V',
#   'RB',
#   'V',
#   'CD',
#   'N',
#   'IN',
#   'N',
#   'JJ',
#   'JJ',
#   'CC',
#   'N',
#   ':',
#   'N',
#   'N',
#   'V',
#   'V',
#   'RB',
#   'JJ',
#   'N',
#   'TO',
#   'V',
#   'DT',
#   'N',
#   '.',
#   'JJ',
#   'N',
#   'TO',
#   'V',
#   'RP',
#   'DT',
#   'N',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['JJ', 'N', 'N', 'WDT', 'N'],
#  [],
#  ['N', 'N', 'IN', 'JJ', 'N', '#', 'JJ', '#', 'N'],
#  [],
#  ['IN', 'N', 'PRP', 'V', 'IN', 'JJ', 'V', 'DT', 'N', 'RB'],
#  [],
#  ['N',
#   'V',
#   'V',
#   'IN',
#   'PRP',
#   'V',
#   'V',
#   'DT',
#   '#',
#   'N',
#   'N',
#   'N',
#   '.',
#   'PRP',
#   'V',
#   'JJ',
#   'N',
#   'IN',
#   'DT',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'POS',
#   'IN',
#   'DT',
#   'N',
#   'IN',
#   'N',
#   'N',
#   'CD',
#   '.',
#   'N',
#   'N',
#   'TO',
#   'V',
#   'V',
#   '.',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['PRP',
#   'RB',
#   'V',
#   'TO',
#   'V',
#   'N',
#   'V',
#   'N',
#   'CC',
#   'RB',
#   'PRP',
#   'V',
#   'RB',
#   'JJ',
#   'CC',
#   'MD',
#   'RB',
#   'V',
#   'RP'],
#  [],
#  ['N', 'TO', 'V', 'PRP', 'V', 'RB', 'RB', 'TO', 'PRP', '.', '#', 'N'],
#  [],
#  ['N', 'V', 'DT', 'V', 'RB', 'N', '.', 'N', 'MD', 'V', 'JJ', '.'],
#  [],
#  ['PRP',
#   'MD',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   'IN',
#   'PRP',
#   'TO',
#   'V',
#   'IN',
#   'N',
#   'DT',
#   'N',
#   'N',
#   ',',
#   'RB',
#   'IN',
#   'CD',
#   'N',
#   'N',
#   'TO',
#   'V',
#   'N',
#   '.',
#   'N',
#   'V',
#   'PRP',
#   'N',
#   'IN',
#   'CC',
#   'V',
#   'PRP',
#   'V'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'N',
#   'V',
#   'IN',
#   'N',
#   'IN',
#   'N',
#   'IN',
#   'IN',
#   '#',
#   'N',
#   '#',
#   'RB',
#   '#',
#   'JJ'],
#  [],
#  ['N', 'V', 'JJ', 'N', 'N', 'N'],
#  [],
#  ['DT',
#   'N',
#   'TO',
#   'V',
#   'TO',
#   'V',
#   'RBR',
#   'IN',
#   'N',
#   'IN',
#   'N',
#   'V',
#   'RB',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   '.',
#   'N',
#   'N',
#   '.',
#   'RB',
#   'IN',
#   'V',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   'IN',
#   'PRP',
#   'N',
#   'IN',
#   'CD',
#   'CC',
#   'CD',
#   'N',
#   '.',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   'IN',
#   'PRP',
#   'N',
#   'IN',
#   'DT',
#   '#',
#   'N',
#   'IN',
#   'CD',
#   'N',
#   '.',
#   'V',
#   'RP',
#   'IN',
#   'DT',
#   'N',
#   'RB',
#   '.',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['N', 'N', 'TO', 'V', 'N'],
#  [],
#  ['N',
#   'CC',
#   'N',
#   ':',
#   'N',
#   'N',
#   'IN',
#   'N',
#   ',',
#   'DT',
#   'N',
#   'V',
#   'RB',
#   'IN',
#   'N',
#   ',',
#   ',',
#   'V',
#   'RP',
#   'N',
#   ':',
#   'N',
#   'PRP',
#   'V',
#   'PRP',
#   'N',
#   'N',
#   'N',
#   'N'],
#  [],
#  ['N', 'RB', 'V', 'TO', 'V', 'JJ', '#', 'N'],
#  [],
#  ['N',
#   'V',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'V',
#   'JJ',
#   'N',
#   ':',
#   '(',
#   '#',
#   'V',
#   '#',
#   'N'],
#  [],
#  ['JJ', 'N', ':', 'N'],
#  [],
#  ['PRP',
#   'N',
#   'V',
#   'RB',
#   'RB',
#   '.',
#   'CC',
#   'PRP',
#   'V',
#   'V',
#   'IN',
#   'PRP',
#   'N',
#   '.',
#   'N',
#   'N',
#   'V',
#   'V',
#   'RB',
#   'TO',
#   'DT',
#   'JJ',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   ',',
#   'V',
#   'RB',
#   'V',
#   'RB',
#   'JJ',
#   'N',
#   'N',
#   '.',
#   'V',
#   'N',
#   'V',
#   'N',
#   'IN',
#   'RB',
#   '#',
#   'N'],
#  [],
#  ['DT',
#   'V',
#   'CD',
#   'PRP',
#   'CC',
#   'V',
#   ':',
#   'CD',
#   'N',
#   'CC',
#   'N',
#   ':',
#   'CD',
#   'CC',
#   'N',
#   ':',
#   'CD',
#   'CC',
#   'N',
#   ':',
#   'CD',
#   'N',
#   'N',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['RB',
#   'N',
#   'N',
#   'IN',
#   'PRP',
#   'V',
#   '.',
#   'PRP',
#   'V',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   '.',
#   'N',
#   'MD',
#   'V',
#   'V',
#   '``',
#   'N',
#   '.',
#   'V',
#   'IN',
#   'JJ',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   '.',
#   "''"],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'V',
#   'N',
#   'N',
#   'N',
#   'PRP',
#   'IN',
#   'V',
#   'N',
#   ':',
#   ')'],
#  [],
#  ['RB', 'TO', 'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   ':',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'PRP',
#   'DT',
#   'N',
#   'TO',
#   'N',
#   ',',
#   'CC',
#   'DT',
#   'N',
#   'TO',
#   'N',
#   'V',
#   'V',
#   'TO',
#   'V',
#   'V'],
#  [],
#  ['JJ', 'N', '#', 'JJ', 'N', '.'],
#  [],
#  ['PRP',
#   'V',
#   'WRB',
#   'PRP',
#   'N',
#   'V',
#   'JJ',
#   'JJ',
#   'CC',
#   'V',
#   'PRP',
#   'V',
#   'RB',
#   'RB',
#   '.',
#   '#',
#   'N',
#   '#',
#   'RB',
#   '#',
#   'N'],
#  [],
#  ['N', 'V', 'PRP', 'V', '.', '#', 'N', '#', 'N'],
#  [],
#  ['PRP',
#   'V',
#   'RB',
#   'IN',
#   'IN',
#   'PRP',
#   'V',
#   'V',
#   'TO',
#   'V',
#   'TO',
#   'V',
#   'IN',
#   'N',
#   'IN',
#   'CD',
#   'CC',
#   'CD',
#   'DT',
#   'N',
#   '.',
#   'PRP',
#   'MD',
#   'RB',
#   'RB',
#   'V',
#   'IN',
#   'N',
#   'CC',
#   'V',
#   'DT',
#   'N'],
#  [],
#  ['PRP', 'N', 'N', '.'],
#  [],
#  ['N', 'DT', 'V', 'N', 'N', 'PRP', 'V', 'V', 'IN', 'PRP', 'JJ', 'N'],
#  [],
#  ['N',
#   'N',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   '.',
#   'PRP',
#   'V',
#   'WRB',
#   'PRP',
#   'V',
#   'RB',
#   'V',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['V',
#   'N',
#   'N',
#   'V',
#   'CD',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'V',
#   'DT',
#   'N',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['N', 'N', 'PRP', 'V', '#', 'N', '.'],
#  [],
#  ['PRP',
#   'MD',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'PRP',
#   'JJ',
#   'JJ',
#   'N',
#   'N',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   '.',
#   'V',
#   'PRP',
#   'JJ',
#   'IN',
#   'JJ',
#   'V',
#   'PRP',
#   '.',
#   'N',
#   'V',
#   'DT',
#   'N',
#   ':'],
#  [],
#  ['N', 'V', 'IN', 'PRP', 'JJ', 'N', 'IN', 'N', ':', '.', '#', 'N'],
#  [],
#  ['N', 'IN', 'JJ', '.', '#', 'N', '#', 'N'],
#  [],
#  ['V',
#   'PRP',
#   'IN',
#   'N',
#   ',',
#   'V',
#   'JJ',
#   'N',
#   'N',
#   'V',
#   'PRP',
#   'CC',
#   'N',
#   ':',
#   'CC',
#   'N',
#   ':',
#   'CC',
#   'N',
#   ':',
#   'CC',
#   'N',
#   'IN',
#   'PDT',
#   'DT',
#   'N',
#   '.',
#   '.'],
#  [],
#  ['JJ',
#   'N',
#   'IN',
#   'N',
#   ',',
#   'N',
#   'V',
#   'RB',
#   'RB',
#   'JJ',
#   'RB',
#   '.',
#   '#',
#   'JJ',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'IN',
#   'CD',
#   'PRP',
#   'V',
#   'TO',
#   'V',
#   'DT',
#   'N',
#   'IN',
#   'JJ',
#   'CC',
#   'MD',
#   'RB',
#   'V',
#   'JJ',
#   ',',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   '.',
#   '.',
#   ':',
#   'CD',
#   'IN',
#   'PRP',
#   'RB',
#   'V',
#   'PRP',
#   'RB',
#   'RB',
#   'IN',
#   'V',
#   'DT',
#   'IN',
#   'N',
#   'N',
#   '#',
#   'N',
#   ':',
#   ')'],
#  [],
#  ['PRP', 'V', 'V', 'IN', 'DT', 'JJ', 'N', '#', 'N'],
#  [],
#  ['N', ',', 'PRP', 'V', 'RB', 'JJ', 'PRP', 'V', 'JJ', 'N', '#', 'N'],
#  [],
#  ['N', 'TO', 'V', 'N', 'N', 'N', 'V', 'N', ':', 'N'],
#  [],
#  ['PRP', 'V'],
#  [],
#  ['#', 'N'],
#  [],
#  ['N',
#   '``',
#   'JJ',
#   'N',
#   ':',
#   'EX',
#   'V',
#   'RB',
#   'CD',
#   'N',
#   'V',
#   'V',
#   'IN',
#   'N',
#   '.',
#   "''"],
#  [],
#  ['JJ', 'N', 'CC', 'N', 'V', 'V', 'N', '.', '#', 'JJ', 'N', ':', 'N'],
#  [],
#  ['N',
#   'N',
#   'N',
#   'N',
#   ':',
#   'JJ',
#   'N',
#   'PRP',
#   'V',
#   'RB',
#   'V',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   'N'],
#  [],
#  ['JJ', 'IN', 'N', 'CD', '.', 'N', 'IN', 'N', 'N', '.', '#', 'N'],
#  [],
#  ['PRP',
#   'N',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   '.',
#   'WP',
#   'DT',
#   'JJ',
#   'N',
#   'TO',
#   'PRP',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N', 'N', 'N', 'IN', 'JJ', 'N', ':', 'N'],
#  [],
#  ['RB', 'N', 'N', 'CC', 'N', 'IN', 'N', ':', 'N'],
#  [],
#  ['DT', 'JJ', 'N', ':', 'N'],
#  [],
#  ['N',
#   '.',
#   'PRP',
#   'V',
#   'DT',
#   '.',
#   'PRP',
#   'JJ',
#   'JJ',
#   'N',
#   '.',
#   'JJ',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   ':',
#   'JJ',
#   'N',
#   'CC',
#   'N',
#   'V',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['JJ', 'N', 'RB', 'V', 'IN', 'PRP', 'N', 'N'],
#  [],
#  ['PRP',
#   'RB',
#   'V',
#   'WRB',
#   'N',
#   'V',
#   'PRP',
#   'V',
#   'JJ',
#   'IN',
#   'CD',
#   '#',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'RB',
#   'JJ',
#   'CD',
#   '#',
#   'N',
#   'IN',
#   'PRP',
#   '#',
#   'JJ',
#   'RB',
#   '.',
#   'JJ',
#   '#',
#   'V',
#   'RB',
#   '.'],
#  [],
#  ['JJ', 'N', 'N', 'N', 'IN', 'PRP', 'N', 'RB'],
#  [],
#  ['JJ', 'N', 'JJ', 'N', '#', 'N'],
#  [],
#  ['JJ', 'N', 'CC', 'PRP', 'V', 'DT', 'JJ', 'JJ', 'N', '.', '#', 'N'],
#  [],
#  ['V', 'WP', '.', 'PRP', 'V', 'DT', 'N', 'RB', '.', 'WP', 'V', 'V', '.'],
#  [],
#  ['JJ',
#   'N',
#   'PRP',
#   'V',
#   'RB',
#   'V',
#   'WRB',
#   'TO',
#   'V',
#   'DT',
#   'N',
#   'IN',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'WRB',
#   'N',
#   'V',
#   'PRP',
#   'N',
#   'TO',
#   'V',
#   'PRP',
#   'N',
#   'RP',
#   'IN',
#   'N',
#   'N',
#   'N',
#   'V',
#   'PRP',
#   'RP',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'N',
#   'N',
#   'CC',
#   'N',
#   'WDT',
#   'V',
#   ':',
#   'JJ',
#   'IN',
#   'N',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   'V',
#   'RB',
#   'N',
#   'TO',
#   'V',
#   'RP',
#   'DT',
#   'N',
#   'IN',
#   'N',
#   '.',
#   'PRP',
#   'V',
#   'V',
#   'PRP',
#   'V',
#   'PRP',
#   'TO',
#   'PRP',
#   'JJ',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'V',
#   'N',
#   'JJ',
#   'N',
#   ',',
#   'JJ',
#   'N',
#   'PRP',
#   'N',
#   'V',
#   'RB',
#   'CC',
#   'JJ',
#   'N',
#   'TO',
#   'V',
#   'N',
#   'IN',
#   'N',
#   '.',
#   '#',
#   'JJ',
#   '#',
#   'V'],
#  [],
#  ['V', 'WRB', 'DT', 'N', 'V', 'RB', 'IN', 'N', '.', '#', 'RB', '#', 'N'],
#  [],
#  ['WP', 'DT', 'N', '.', '.', '.', '#', 'N'],
#  [],
#  ['DT', 'N', 'RP', 'IN', 'DT', 'N', ',', 'PRP', 'V', '.'],
#  [],
#  ['PRP', 'V', 'V', 'N', 'N', 'CC', 'RB', 'V', 'DT', 'N', '#', 'N'],
#  [],
#  ['IN',
#   'PRP',
#   'N',
#   'N',
#   'PRP',
#   'N',
#   'N',
#   'V',
#   'N',
#   'MD',
#   'V',
#   'DT',
#   'N',
#   'V',
#   'PRP',
#   '.',
#   'N'],
#  [],
#  ['N',
#   'V',
#   'DT',
#   'N',
#   'IN',
#   'N',
#   '.',
#   'PDT',
#   'DT',
#   'N',
#   'V',
#   'V',
#   'IN',
#   'N',
#   'N',
#   'RB',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   'N',
#   'N',
#   ':',
#   'PRP',
#   'V',
#   'RB',
#   'JJ',
#   'IN',
#   'PRP',
#   'V',
#   'N',
#   ':',
#   '#',
#   'N'],
#  [],
#  ['JJ', 'N'],
#  [],
#  ['PRP',
#   'V',
#   'TO',
#   'V',
#   'PRP',
#   'N',
#   'N',
#   'IN',
#   'PRP',
#   'WRB',
#   'PRP',
#   'V',
#   'TO',
#   'DT',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   ':',
#   'N',
#   'CC',
#   'N',
#   ':',
#   ':',
#   ':',
#   'V',
#   'PRP',
#   '.',
#   '.',
#   'N'],
#  [],
#  ['RB',
#   'JJ',
#   'PRP',
#   'V',
#   'RB',
#   'N',
#   'V',
#   'IN',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'PRP',
#   'N',
#   '.',
#   '#',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'RB',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   'N',
#   'IN',
#   'N',
#   'N',
#   '#',
#   'N',
#   '#',
#   'N',
#   '#',
#   'N',
#   'N'],
#  [],
#  ['N',
#   'N',
#   'N',
#   'N',
#   'N',
#   ':',
#   'WRB',
#   'PRP',
#   'V',
#   'JJ',
#   ',',
#   'PRP',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   'N'],
#  [],
#  ['PRP', 'V', 'RB', 'V', 'PRP', 'JJ', 'N', '.'],
#  [],
#  ['N', 'IN', 'N', 'N', '.', 'DT', 'N', 'IN', 'DT', 'N', '#', 'N', '.'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   ':',
#   '``',
#   'DT',
#   'N',
#   'N',
#   'V',
#   'V',
#   'V',
#   'TO',
#   'V',
#   'PRP',
#   '.',
#   '``',
#   'JJ',
#   'N',
#   'N'],
#  [],
#  ['N', 'N', 'N', 'CC', 'N', 'N', ':', 'JJ', 'N', ':', 'N'],
#  [],
#  ['DT',
#   'N',
#   'V',
#   'JJ',
#   'N',
#   'V',
#   'IN',
#   'PRP',
#   'CC',
#   'PRP',
#   'V',
#   'V',
#   '.',
#   '.',
#   '.'],
#  [],
#  ['N', 'N', 'V', 'N'],
#  [],
#  ['N',
#   'V',
#   'IN',
#   'N',
#   'WP',
#   'V',
#   'PRP',
#   'N',
#   '.',
#   'PRP',
#   'V',
#   'JJ',
#   ',',
#   'PRP',
#   'V',
#   'RB',
#   'V',
#   'JJ',
#   'N',
#   'IN',
#   'PRP',
#   'N',
#   'V',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   '.',
#   'JJ',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'V',
#   'CD',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   'V',
#   '.',
#   '.',
#   'IN',
#   '#',
#   'N',
#   '.',
#   '.',
#   'WP',
#   'DT',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['PRP', 'RB', 'V', 'PDT', 'DT', 'N', '#', 'N'],
#  [],
#  ['N', 'TO', 'V', 'V', 'IN', 'N', '.', 'N', 'N', '.', '#', 'N'],
#  [],
#  ['RB', 'V', 'PRP', 'JJ', 'N', 'DT', 'N', '#', 'N', 'FW', 'N', ':', 'N', 'N'],
#  [],
#  ['N',
#   'V',
#   'PRP',
#   'V',
#   'N',
#   'WRB',
#   'PRP',
#   'RB',
#   'V',
#   'CD',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   'IN',
#   'PRP',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   'JJ',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'CC',
#   'N',
#   ':',
#   'CD',
#   'N',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'IN',
#   'PRP',
#   'TO',
#   'V',
#   'JJ',
#   '.',
#   '.',
#   'N',
#   'V',
#   '.',
#   '.',
#   'V',
#   'RP',
#   '.',
#   '.',
#   'V',
#   'RB',
#   '.',
#   '.',
#   'N',
#   '.',
#   '.',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N', 'WP', 'PRP', 'N', 'N', ':', 'N', 'N'],
#  [],
#  ['N', 'N', 'IN', 'N', ':', 'V', 'JJ', '.', '#', 'JJ', '#', 'V'],
#  [],
#  ['N',
#   'POS',
#   'N',
#   'N',
#   ':',
#   'V',
#   'PRP',
#   'DT',
#   'JJ',
#   'TO',
#   'V',
#   'IN',
#   'N',
#   ':',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['N', 'N', 'IN', 'DT', 'N', 'JJ', 'N', 'IN', 'N', ':', 'N', 'IN', 'PRP', ':'],
#  [],
#  ['V', 'JJ', 'DT', 'N', ':', ')', ')'],
#  [],
#  ['RB',
#   'RB',
#   'IN',
#   'PRP',
#   'V',
#   'N',
#   ',',
#   'N',
#   'V',
#   '.',
#   'RB',
#   'RB',
#   'IN',
#   'PRP',
#   'V',
#   'N',
#   ',',
#   'N',
#   'N',
#   '.',
#   'RB',
#   'RB',
#   'IN',
#   'PRP',
#   'V',
#   'V',
#   ',',
#   'PRP',
#   'V',
#   'RB',
#   'DT',
#   'N',
#   "''"],
#  [],
#  ['PRP', 'V', 'JJ', 'N', '.', 'N', 'TO', 'V', 'N', 'CC', 'N', ':', 'CD'],
#  [],
#  ['N',
#   'DT',
#   'IN',
#   'N',
#   'N',
#   'IN',
#   'N',
#   'N',
#   '#',
#   'N',
#   '#',
#   'RB',
#   '#',
#   'JJ',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   'RB',
#   'JJ',
#   'N',
#   'V',
#   'RB',
#   'V',
#   'IN',
#   'PRP',
#   'V',
#   'PRP',
#   'DT',
#   'N',
#   'IN',
#   'PRP',
#   'N',
#   'N',
#   'N',
#   '.',
#   'PRP',
#   'V',
#   'V',
#   '#',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'RB',
#   'V',
#   'WRB',
#   'PRP',
#   'V',
#   'PRP',
#   'N',
#   '.',
#   '.',
#   '.',
#   'IN',
#   'WRB',
#   'DT',
#   'N',
#   'V',
#   'RP',
#   'IN',
#   'PRP',
#   'PRP',
#   'V',
#   'PRP',
#   'V',
#   '.',
#   'N',
#   'PRP',
#   'JJ',
#   '#',
#   'N',
#   'N',
#   'V',
#   'RB',
#   'RB',
#   'N'],
#  [],
#  ['WRB', 'IN', 'N', 'V', 'JJ', 'V', '.'],
#  [],
#  ['V', 'DT', 'N', 'N', 'WDT', 'MD', 'V', 'DT', 'JJ', 'N', 'IN', 'N', '.'],
#  [],
#  ['``',
#   'JJ',
#   'N',
#   ':',
#   'DT',
#   'V',
#   '``',
#   'N',
#   "''",
#   'WDT',
#   'V',
#   'V',
#   'PRP',
#   'TO',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'V',
#   'DT',
#   'N',
#   '.',
#   '#',
#   'N',
#   "''",
#   'N',
#   '.',
#   '.'],
#  [],
#  ['N',
#   'TO',
#   'N',
#   'PRP',
#   'V',
#   'N',
#   'IN',
#   ',',
#   'PRP',
#   'V',
#   'JJ',
#   ',',
#   'PRP',
#   'V',
#   'JJ',
#   'JJ',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  [],
#  ['IN',
#   'DT',
#   'IN',
#   'N',
#   '.',
#   'V',
#   'PRP',
#   'IN',
#   '.',
#   '.',
#   'JJ',
#   'N',
#   '#',
#   'JJ',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['RB',
#   'DT',
#   'N',
#   "''",
#   'V',
#   'RB',
#   'V',
#   'N',
#   'TO',
#   'V',
#   'TO',
#   'PRP',
#   ',',
#   'CC',
#   'V',
#   'N',
#   'TO',
#   'V',
#   'TO',
#   'JJ',
#   'N',
#   '.',
#   'RB',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N', 'N', 'N', '.', 'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'N',
#   'IN',
#   'N',
#   'PRP',
#   'V',
#   'RB',
#   'RB',
#   'JJ',
#   '.',
#   'N',
#   'MD',
#   'RB',
#   'RB',
#   'V',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['RB',
#   'V',
#   'N',
#   'IN',
#   'PRP',
#   'V',
#   'DT',
#   'N',
#   'RB',
#   ':',
#   'PRP',
#   'RB',
#   'V',
#   'CD',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   ':',
#   'N',
#   'CC',
#   'N',
#   'V',
#   'V',
#   'IN',
#   'N',
#   '.',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['N', 'IN', 'PRP', 'TO', 'V', 'V'],
#  [],
#  ['PRP',
#   'RB',
#   'V',
#   'JJ',
#   'V',
#   'V',
#   'DT',
#   'POS',
#   'DT',
#   'N',
#   'TO',
#   'V',
#   'TO',
#   'DT',
#   'N',
#   'N',
#   'V',
#   'TO',
#   'V',
#   'TO',
#   '.',
#   'PRP',
#   'V',
#   'PRP',
#   'RP',
#   'JJ',
#   'N',
#   '#',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['N', 'N', 'RB', 'IN', 'JJ', 'PRP', 'V', 'RB', 'JJ', '#', 'JJ', '#', 'N'],
#  [],
#  ['JJ', 'JJ', 'N', ':', ')'],
#  [],
#  ['DT', 'JJ', 'N', 'N', ':', 'N', 'PRP', 'N', 'N', ':', 'JJ', 'IN', 'N', 'N'],
#  [],
#  ['PRP', 'V', 'RBS', 'JJ', ':', 'N', ':', 'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   ':',
#   'DT',
#   '#',
#   'N',
#   'N',
#   'MD',
#   'V',
#   '#',
#   'N',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'PRP',
#   'V',
#   '#',
#   'JJ',
#   '#',
#   'N',
#   'N',
#   'N'],
#  [],
#  ['N', 'N', 'RB', 'V', 'IN', 'N', 'V', 'RB', 'JJ', 'IN', 'JJ', 'IN', 'N'],
#  [],
#  ['#',
#   'N',
#   'N',
#   'N',
#   'N',
#   'V',
#   'N',
#   'N',
#   ',',
#   'N',
#   'N',
#   'V',
#   'RB',
#   'V',
#   'IN',
#   'CD',
#   'DT',
#   'IN',
#   'DT',
#   'N',
#   '.',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['N', 'IN', 'V', 'PRP', 'V', 'JJ', '.', 'IN', 'RB', 'PRP', 'V', '.'],
#  ['#', 'N'],
#  [],
#  ['RB', 'CD', 'N', 'JJ', 'N', 'V', '.'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'N',
#   'N',
#   '.',
#   '.',
#   ':',
#   'N',
#   'V',
#   'N',
#   'IN',
#   'N',
#   'N',
#   'N',
#   'JJ',
#   'N',
#   'N',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['N',
#   'V',
#   'V',
#   'PRP',
#   'V',
#   'RB',
#   'JJ',
#   '.',
#   'PRP',
#   'V',
#   '``',
#   'V',
#   'PRP',
#   'V',
#   'PRP',
#   'TO',
#   'V',
#   'N',
#   'RP',
#   '.',
#   'UH',
#   'DT',
#   'PRP',
#   'V',
#   'PRP',
#   'RP',
#   'DT',
#   'N',
#   'RB',
#   '.',
#   "''",
#   '#',
#   'N'],
#  [],
#  ['PRP', 'V', 'TO', 'V', 'RP', 'DT', 'N', '.', 'N'],
#  [],
#  ['N',
#   ',',
#   'RB',
#   'V',
#   'DT',
#   'JJ',
#   ',',
#   'JJ',
#   'N',
#   'N',
#   'IN',
#   'PRP',
#   'N',
#   'CC',
#   'V',
#   'N',
#   'PRP',
#   ':',
#   'RB',
#   'V',
#   'DT',
#   'JJ'],
#  [],
#  ['JJ', 'N', 'N', 'N', 'N', 'N', 'V', 'N', '.'],
#  [],
#  ['RB', 'V', 'RP', ',', 'PRP', 'N', 'POS', '.', '#', 'N'],
#  [],
#  ['N',
#   'V',
#   'TO',
#   'V',
#   'N',
#   'IN',
#   'TO',
#   'DT',
#   'N',
#   'V',
#   'DT',
#   'N',
#   'N',
#   'IN',
#   'N',
#   '.'],
#  [],
#  ['PRP',
#   'V',
#   '#',
#   'N',
#   'V',
#   'JJ',
#   'N',
#   '.',
#   'N',
#   ':',
#   'JJ',
#   '.',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['JJ', 'N', 'N', 'V', 'DT', 'JJ', 'N', 'V'],
#  [],
#  ['CD', 'V', 'JJ', 'N', 'N', '#', 'N', '#', 'N'],
#  [],
#  ['V',
#   'IN',
#   'N',
#   ':',
#   'V',
#   'RB',
#   'JJ',
#   'N',
#   'CC',
#   'RB',
#   'RB',
#   'V',
#   'IN',
#   'DT',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['JJ', 'N', 'PRP', 'V', 'JJ', 'V', 'IN', 'N', 'N', '.', '#', 'N'],
#  [],
#  ['JJ', 'N', 'N', 'MD', 'RB', 'V', 'N', 'V', 'CC', 'JJ', 'IN', '#', 'N'],
#  [],
#  ['JJ', 'N', 'CC', 'CD', 'N', 'IN', 'N'],
#  [],
#  ['N', 'N', '.', '#', 'N', 'N', 'N', 'N', ':', 'N'],
#  [],
#  ['N',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'RB',
#   ',',
#   'IN',
#   'EX',
#   'V',
#   'DT',
#   'N',
#   '.',
#   '#',
#   'JJ',
#   '#'],
#  [],
#  ['N',
#   'N',
#   ',',
#   'JJ',
#   'N',
#   'RB',
#   'RB',
#   'V',
#   '.',
#   'V',
#   'N',
#   'V',
#   'DT',
#   'N',
#   'N',
#   'PRP',
#   'JJ',
#   'N',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['RB', 'JJ', 'IN', 'N', '.', '#', 'JJ', '#', 'JJ', '#', 'N'],
#  [],
#  ['V', 'PRP', 'IN', 'N', '.', '.', '.', '#', 'IN', ':', ')', 'N'],
#  [],
#  ['PRP', 'V', 'JJ', 'N', 'TO', 'RB'],
#  [],
#  ['V',
#   'PRP',
#   'V',
#   'IN',
#   '``',
#   'IN',
#   'N',
#   'N',
#   'N',
#   "''",
#   'V',
#   'TO',
#   'V',
#   'PRP',
#   'V',
#   '.',
#   'N',
#   'DT',
#   'N',
#   'N',
#   'N'],
#  [],
#  ['UH',
#   '.',
#   'PRP',
#   'V',
#   'V',
#   'RP',
#   'TO',
#   'V',
#   'N',
#   'CC',
#   'PRP',
#   'JJ',
#   'N',
#   'V',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'V',
#   'JJ',
#   '.',
#   'PRP',
#   'V',
#   'PRP',
#   'N',
#   'N',
#   'V',
#   'IN',
#   'CD',
#   '.',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'N',
#   'V',
#   'JJ',
#   'IN',
#   'N',
#   ',',
#   'V',
#   'DT',
#   'N',
#   '.',
#   'CC',
#   'RB',
#   'N',
#   'N',
#   ',',
#   'N',
#   '.'],
#  [],
#  ['PRP',
#   'V',
#   'V',
#   'RB',
#   'DT',
#   'N',
#   'JJ',
#   'N',
#   'MD',
#   'V',
#   'DT',
#   'N',
#   'DT',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['V',
#   'IN',
#   'TO',
#   'V',
#   'IN',
#   'CD',
#   'N',
#   'V',
#   'RB',
#   'JJ',
#   'DT',
#   'CD',
#   'N',
#   'V',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   'PRP',
#   'V',
#   'V',
#   'IN',
#   'CD',
#   'N',
#   'IN',
#   'PRP',
#   'IN',
#   'PRP',
#   'V',
#   'JJ',
#   'IN',
#   'DT',
#   '.',
#   '.'],
#  [],
#  ['N', 'WDT', 'N', ':', '#', 'JJ', '#', 'N'],
#  [],
#  ['V',
#   'RB',
#   'V',
#   'JJ',
#   'TO',
#   'V',
#   ',',
#   'IN',
#   'PRP',
#   'V',
#   'V',
#   'V',
#   'N',
#   'IN',
#   'N',
#   'CC',
#   'JJ',
#   'N',
#   'DT',
#   'N',
#   '.',
#   'WP',
#   'DT',
#   'V',
#   'N',
#   'PRP',
#   'V',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['PRP',
#   'N',
#   'N',
#   'V',
#   'CD',
#   'N',
#   'IN',
#   'PRP',
#   ':',
#   '.',
#   'CD',
#   'IN',
#   'PRP',
#   'V',
#   'JJ',
#   '.',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'PRP',
#   'PRP',
#   'V',
#   'RB',
#   'JJ',
#   '.',
#   'PRP',
#   'V',
#   'PRP',
#   'V',
#   'PRP',
#   '.',
#   '#',
#   'N',
#   'N'],
#  [],
#  ['N',
#   'JJ',
#   'N',
#   'V',
#   'V',
#   'TO',
#   'V',
#   'PRP',
#   'JJ',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   ',',
#   'PRP',
#   'V',
#   'N',
#   'DT',
#   'IN',
#   'PRP',
#   'N',
#   '(',
#   'N',
#   ')',
#   '#',
#   'N'],
#  [],
#  ['#',
#   'N',
#   'WRB',
#   'N',
#   'CC',
#   'JJ',
#   'N',
#   'IN',
#   'DT',
#   'JJ',
#   ',',
#   'CC',
#   'PRP',
#   'V',
#   'RB',
#   'JJ',
#   'CC',
#   'JJ',
#   '.'],
#  [],
#  ['N',
#   'N',
#   'N',
#   '(',
#   'N',
#   ')',
#   'V',
#   'N',
#   'N',
#   'N',
#   ':',
#   'N',
#   'N',
#   'N',
#   'N',
#   ':',
#   'N',
#   '(',
#   'CD',
#   'N',
#   ')',
#   '(',
#   'N',
#   'POS',
#   'N',
#   "''",
#   ')',
#   'V',
#   'N',
#   'N',
#   'N',
#   ':',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   '.',
#   '.',
#   '.',
#   '.'],
#  [],
#  ['N', 'V', 'RB', 'JJ', '.', '.', '#', 'RB', '#', 'N'],
#  [],
#  ['N',
#   'IN',
#   'JJ',
#   'CD',
#   'N',
#   'N',
#   'N',
#   ',',
#   'RB',
#   'V',
#   'DT',
#   'N',
#   'N',
#   'IN',
#   'PRP',
#   'MD',
#   'V',
#   'N',
#   'RB',
#   'RB',
#   'IN',
#   'PRP',
#   'V',
#   '#',
#   'N',
#   'CC',
#   'N',
#   ':',
#   'CD'],
#  [],
#  ['V',
#   'IN',
#   'DT',
#   'N',
#   'IN',
#   'PRP',
#   'N',
#   'N',
#   'V',
#   'V',
#   'FW',
#   'RP',
#   ':',
#   '#',
#   'JJ',
#   '#',
#   'N',
#   '#',
#   'N',
#   '#',
#   'JJ',
#   '#',
#   'V'],
#  [],
#  ['PRP', 'V', 'RB', 'JJ', 'JJ', 'CC', 'PRP', 'N', 'V', 'JJ', '.'],
#  [],
#  ['N', 'N', 'IN', 'V', 'PRP', 'IN', 'N', '.'],
#  [],
#  ['V',
#   'POS',
#   'V',
#   'N',
#   'RB',
#   'WRB',
#   'JJ',
#   'PRP',
#   'V',
#   'JJ',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N'],
#  [],
#  ['V', 'V', 'RP', 'V', 'DT', 'JJ', 'N', 'TO', 'V', 'PRP', 'N', '.', '#', 'N'],
#  [],
#  ['N', 'N', 'V', 'PRP', 'PRP', '#', 'N', 'N'],
#  [],
#  ['MD', 'IN', 'DT', 'N', 'V', 'JJ', 'N', 'IN', 'N', 'JJ', 'N', 'N', 'N'],
#  [],
#  ['N',
#   '.',
#   'N',
#   '.',
#   'N',
#   'CC',
#   'N',
#   'V',
#   'V',
#   'JJ',
#   '.',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['N', 'V', 'V', 'IN', 'JJ', 'IN', 'DT', 'PRP', 'V', 'JJ', 'V', 'RB', '.'],
#  [],
#  ['V',
#   'RP',
#   'DT',
#   'JJ',
#   'N',
#   ':',
#   'CD',
#   'N',
#   'CD',
#   'N',
#   'N',
#   'N',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['N', '.', 'RB', 'JJ', '.', 'JJ', 'N', 'IN', 'N', '.', '#', 'N'],
#  [],
#  ['JJ',
#   'N',
#   'TO',
#   'PRP',
#   'JJ',
#   'N',
#   ',',
#   'PRP',
#   'JJ',
#   'JJ',
#   'JJ',
#   'TO',
#   'JJ',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['JJ', 'N', 'JJ', 'N', 'RB', 'PRP', 'CC', 'PRP', 'V', 'WP', 'IN', 'V', 'N'],
#  [],
#  ['PRP',
#   'RB',
#   'V',
#   'N',
#   'IN',
#   'N',
#   'IN',
#   'N',
#   '.',
#   'N',
#   'IN',
#   'V',
#   'DT',
#   'N',
#   'V',
#   'N',
#   'N',
#   'CC',
#   'N',
#   ':',
#   'CC',
#   'V',
#   '.',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['V', 'CC', 'N', 'N', 'RB', 'V', '#', 'JJ', '#', 'N'],
#  [],
#  ['PRP',
#   'V',
#   'IN',
#   'TO',
#   'V',
#   'JJ',
#   'CC',
#   'PRP',
#   'RB',
#   'V',
#   'TO',
#   'V',
#   'IN',
#   'CD',
#   'JJ',
#   'N'],
#  [],
#  ['JJ', 'N', 'JJ', 'N', 'TO', 'V', 'DT', 'JJ', 'N', '#', 'N'],
#  [],
#  ['PRP',
#   'V',
#   'JJ',
#   'N',
#   'DT',
#   'N',
#   'CC',
#   'PRP',
#   'N',
#   'V',
#   'JJ',
#   'PRP',
#   'V',
#   'JJ',
#   'FW',
#   'JJ',
#   '$',
#   'N'],
#  [],
#  ['#',
#   'N',
#   'POS',
#   'N',
#   'V',
#   'V',
#   'DT',
#   'N',
#   ',',
#   'IN',
#   'V',
#   'N',
#   'CC',
#   'N',
#   ':',
#   'N',
#   'JJ',
#   '.',
#   'N',
#   'N'],
#  [],
#  ['N',
#   'IN',
#   'CD',
#   'CC',
#   'DT',
#   'JJ',
#   'N',
#   'N',
#   '.',
#   '#',
#   'JJ',
#   '#',
#   'JJ',
#   '#',
#   'JJ'],
#  [],
#  ['PRP', 'V', 'V', 'IN', 'N', 'IN', 'CD', 'IN', 'DT', 'N', '#', 'N', '#', 'N'],
#  [],
#  ['CC',
#   'RB',
#   'DT',
#   'N',
#   'V',
#   'JJ',
#   'IN',
#   'CD',
#   'IN',
#   'N',
#   'MD',
#   'V',
#   'JJ',
#   ':',
#   'N',
#   ':',
#   '.'],
#  [],
#  ['N',
#   'WRB',
#   'N',
#   '.',
#   'DT',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   'N',
#   'V',
#   'PRP',
#   'N',
#   'N',
#   '.',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['UH', ',', 'JJ', 'JJ', 'V', 'V', 'PRP', 'JJ', '#', 'JJ', '#', 'V'],
#  [],
#  ['UH',
#   'PRP',
#   'N',
#   '.',
#   'MD',
#   'PRP',
#   'V',
#   "''",
#   'N',
#   'V',
#   'N',
#   'IN',
#   'PRP',
#   'N',
#   'IN',
#   'V',
#   'DT',
#   'N',
#   '.',
#   'PRP',
#   'MD',
#   'V',
#   'CC',
#   'V',
#   'TO',
#   'RB',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N', 'IN', 'DT', 'N', 'JJ', 'N', '.', '.'],
#  [],
#  ['JJ',
#   'N',
#   'IN',
#   'JJ',
#   'IN',
#   'N',
#   'TO',
#   'V',
#   'TO',
#   'PRP',
#   'N',
#   'N',
#   'CC',
#   'V',
#   'PRP',
#   'JJ',
#   'N',
#   'DT',
#   'IN',
#   'PRP',
#   ',',
#   'RB',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N', 'V', 'IN', '.', 'N', ':', 'N'],
#  [],
#  ['JJ',
#   'N',
#   'IN',
#   'N',
#   ':',
#   'JJ',
#   '.',
#   '.',
#   '.',
#   'N',
#   'RB',
#   'RB',
#   '#',
#   'N',
#   'TO',
#   'PRP',
#   'N',
#   '.',
#   '.',
#   '(',
#   'N',
#   'RB',
#   'V',
#   'N',
#   'PRP',
#   'IN',
#   ':',
#   'PRP',
#   'V',
#   'N',
#   'JJ',
#   'N',
#   '.',
#   ')',
#   ':',
#   '('],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'V',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'V',
#   'N',
#   'RB',
#   'V',
#   'TO',
#   'V',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'V'],
#  [],
#  ['``',
#   'JJ',
#   'N',
#   ':',
#   'N',
#   'N',
#   ',',
#   'JJ',
#   'N',
#   'CC',
#   'N',
#   'MD',
#   'V',
#   'PRP',
#   'JJ',
#   'N',
#   'IN',
#   'CD',
#   'N',
#   'N',
#   'N',
#   ':',
#   'N',
#   "''",
#   'N'],
#  [],
#  ['PRP', 'N', 'V', 'V', 'RB', 'V', 'N', 'N', 'CC', 'N'],
#  [],
#  ['N', ':', 'N', 'N', 'N', '(', 'CD', 'N', ')', 'N', ':', 'N'],
#  [],
#  ['PRP', 'V', 'DT', 'N', 'IN', 'N', 'WRB', 'PRP', 'RB', 'V', 'N', '.'],
#  ['UH', ',', 'PRP', 'DT', '.'],
#  [],
#  ['PRP', 'JJ', 'N', 'IN', 'N', 'V', 'V', 'N', 'RP', '#', 'N'],
#  [],
#  ['V', 'DT', ':', 'WRB', 'TO', 'V', 'N', 'N', ':', 'N', '.'],
#  ['N', ':', 'JJ', '#', 'JJ', '#', 'JJ', '#', 'JJ', '#', 'N'],
#  [],
#  ['V',
#   'V',
#   'N',
#   'CD',
#   'N',
#   'RB',
#   ',',
#   'N',
#   'TO',
#   'V',
#   'PRP',
#   'V',
#   'V',
#   'JJ',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'PRP',
#   'V',
#   'V',
#   'RB',
#   'V',
#   'DT',
#   '#',
#   'N',
#   'CC',
#   'WRB',
#   'V',
#   'PRP',
#   '#',
#   'V'],
#  [],
#  ['JJ', 'N', 'WP', 'V', 'N', '.', 'WRB', 'V', 'PRP', 'V', 'V', '.', '#', 'N'],
#  [],
#  ['PRP',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'PRP',
#   'MD',
#   'V',
#   'RB',
#   'RB',
#   'PRP',
#   'V',
#   'IN',
#   'CD',
#   'IN',
#   'DT',
#   'N',
#   '.',
#   'UH',
#   'N',
#   'TO',
#   'V',
#   'RB',
#   '.',
#   'V',
#   'RB',
#   'V',
#   '.',
#   'PRP',
#   'V',
#   'JJ',
#   '.',
#   '#',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   'IN',
#   'PRP',
#   'V',
#   'IN',
#   'PRP',
#   'N',
#   ',',
#   'IN',
#   'PRP',
#   'V',
#   'IN',
#   'N',
#   '.',
#   ':',
#   "''",
#   ')'],
#  [],
#  ['DT', 'N', 'N', 'N', 'IN', 'N', '.', 'N', '.', 'V', 'RB'],
#  [],
#  ['V',
#   'PRP',
#   'N',
#   'RB',
#   'RB',
#   'IN',
#   'N',
#   'N',
#   'N',
#   'N',
#   ':',
#   'JJ',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   '.',
#   'DT',
#   'V',
#   'RB',
#   'WP',
#   'PRP',
#   'V',
#   '#',
#   'N'],
#  [],
#  ['N', 'V', 'DT', 'JJ', '#', 'N'],
#  [],
#  ['N',
#   'V',
#   'JJ',
#   'N',
#   'IN',
#   'JJ',
#   'N',
#   'N',
#   ':',
#   'N',
#   ':',
#   'N',
#   'UH',
#   ',',
#   'WDT',
#   'MD',
#   'V',
#   'PRP',
#   'N',
#   'JJ',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['RB',
#   'V',
#   'IN',
#   'N',
#   'PRP',
#   'IN',
#   ',',
#   'RB',
#   'PRP',
#   'V',
#   'RB',
#   'V',
#   'TO',
#   'V',
#   'N',
#   'N',
#   'WRB',
#   'PRP',
#   'V',
#   'PRP',
#   'IN',
#   'DT',
#   'PRP',
#   'V',
#   'PRP',
#   'N',
#   'V',
#   '#',
#   'N'],
#  [],
#  ['PRP',
#   'MD',
#   'RB',
#   'RB',
#   'V',
#   'TO',
#   'V',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['V',
#   'PRP',
#   'N',
#   'RP',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'PRP',
#   'N',
#   'RB',
#   '#',
#   'JJ',
#   '#',
#   'V'],
#  [],
#  ['N',
#   'N',
#   'N',
#   'N',
#   'V',
#   'V',
#   'IN',
#   'WRB',
#   'JJ',
#   'PRP',
#   'V',
#   'V',
#   'IN',
#   'IN',
#   'N',
#   '.',
#   'N',
#   'IN',
#   'N',
#   'MD',
#   'V',
#   'PRP',
#   'N',
#   'N',
#   'TO',
#   '$',
#   'CD',
#   '.'],
#  [],
#  ['N', '.', 'PRP', 'V', 'V', 'WRB', 'TO', 'V', 'IN', 'DT', 'N', '#', 'N'],
#  [],
#  ['N', 'V', 'DT', 'N', 'RB', '#', 'N'],
#  [],
#  ['N',
#   'EX',
#   'DT',
#   '#',
#   'N',
#   'RB',
#   '#',
#   'N',
#   'CC',
#   '#',
#   'N',
#   '.',
#   '#',
#   'V',
#   '#',
#   'N'],
#  [],
#  ['JJ', 'N', 'RB', 'DT', 'N', 'MD', 'V', 'PRP', 'RP', '.'],
#  [],
#  ['V',
#   'TO',
#   'V',
#   ':',
#   'RB',
#   '.',
#   'UH',
#   'WRB',
#   'PRP',
#   'V',
#   'JJ',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['PRP', 'V', 'JJ', 'N', '.', '#', 'N'],
#  [],
#  ['N', '#', 'N', 'N', '.', '.', '.', '.'],
#  [],
#  ['``',
#   'RB',
#   'PRP',
#   'V',
#   'RB',
#   '.',
#   'N',
#   'N',
#   'IN',
#   'N',
#   '.',
#   "''",
#   '#',
#   'N',
#   'N',
#   'N',
#   'N',
#   'V',
#   'CD',
#   'N'],
#  [],
#  ['DT', 'N', 'IN', 'DT', '.', '#', 'JJ', '#', 'N'],
#  [],
#  ['DT',
#   'JJ',
#   'N',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   ',',
#   'PRP',
#   'V',
#   'PRP',
#   'RB',
#   'CC',
#   'V',
#   'PRP',
#   'IN',
#   'JJ',
#   ':',
#   'DT',
#   'N',
#   'PRP',
#   'V',
#   'PRP',
#   'V',
#   'N'],
#  [],
#  ['V', 'IN', 'JJ', 'N', ':', 'JJ', '.', '.', '#', 'JJ', '#', 'V', '#', 'V'],
#  [],
#  ['V',
#   'PRP',
#   'V',
#   'V',
#   'IN',
#   'EX',
#   'V',
#   'RB',
#   'N',
#   'IN',
#   'PRP',
#   'N',
#   'IN',
#   'N',
#   'RB',
#   '.',
#   'IN',
#   'JJ',
#   ',',
#   'PRP',
#   'V',
#   'TO',
#   'DT',
#   'N',
#   'IN',
#   ':',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['PRP', 'V', 'IN', 'DT', 'N', 'N', ':', 'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'PRP',
#   'IN',
#   'TO',
#   'DT',
#   'N',
#   'N',
#   'CD',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'N',
#   'POS'],
#  [],
#  ['N',
#   ':',
#   'N',
#   'N',
#   'V',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   'N',
#   '#',
#   'N',
#   '#',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'V',
#   'WP',
#   'N',
#   'V',
#   'TO',
#   'V',
#   'CC',
#   'IN',
#   'N',
#   'POS',
#   'N',
#   'CC',
#   'N',
#   ':',
#   ':',
#   'EX',
#   'V',
#   'V',
#   'PRP',
#   'RB',
#   ':',
#   'V',
#   'JJ'],
#  [],
#  ['N', '``', 'WP', 'DT', 'N', "''", 'MD', 'V', 'DT', 'JJ', 'N', 'RB'],
#  [],
#  ['N', 'N', 'EX', 'V', 'DT', 'N', 'N', '#', 'RB', '#', 'N'],
#  [],
#  ['PRP', 'V', 'V', 'DT', 'N', 'IN', 'DT', 'V', 'N', 'DT', 'N', 'N', '#', 'N'],
#  [],
#  ['DT', 'N', 'N', 'N', 'V', 'PRP', 'V', 'TO', 'V', 'N'],
#  [],
#  ['#',
#   'N',
#   'N',
#   'POS',
#   'JJ',
#   'N',
#   'N',
#   'RB',
#   ',',
#   'V',
#   'CD',
#   'N',
#   ',',
#   'IN',
#   'JJ',
#   'JJ',
#   ':',
#   ':',
#   'N',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   'V',
#   'CD',
#   'JJ',
#   ',',
#   'V',
#   'V',
#   'V',
#   'JJ',
#   'N',
#   'N',
#   'N',
#   "''",
#   'V',
#   'CD',
#   'N',
#   'N',
#   'CC',
#   'N',
#   ':',
#   'PRP',
#   'N',
#   'TO',
#   'V',
#   'TO',
#   'N',
#   '.',
#   'RB',
#   'V',
#   'PRP',
#   'V',
#   'CD',
#   'JJ',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   "''"],
#  [],
#  ['N',
#   'N',
#   'V',
#   'JJ',
#   'IN',
#   'V',
#   'FW',
#   'N',
#   '.',
#   'RB',
#   'JJ',
#   'IN',
#   'DT',
#   'N',
#   'PRP',
#   'V',
#   ',',
#   'PRP',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'N',
#   'CC',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'V',
#   'IN',
#   'N',
#   '.',
#   '.',
#   'CC',
#   'WP',
#   'DT',
#   'N',
#   'V',
#   'V',
#   '.',
#   '.'],
#  [],
#  ['N', 'RB', 'V', 'V', 'N', 'CD', 'V', 'IN', 'DT', 'CD', 'N', 'N', '#', 'N'],
#  [],
#  ['PRP', 'JJ', 'CC', 'PRP', 'RB', 'RB', 'JJ', 'N', '.'],
#  [],
#  ['DT',
#   'V',
#   'PRP',
#   'RB',
#   'V',
#   'PRP',
#   'V',
#   'PRP',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   ':',
#   'PRP',
#   'V',
#   'V',
#   'V'],
#  [],
#  ['N', 'IN', 'DT', 'PRP', 'V', 'WRB', 'N', 'V', 'N', 'N'],
#  [],
#  ['JJ',
#   'N',
#   'PRP',
#   'V',
#   'V',
#   'V',
#   'N',
#   'CC',
#   'PRP',
#   'V',
#   'PRP',
#   '.',
#   ':',
#   ')',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['JJ', 'N', 'JJ', 'UH', '.', '.', 'N', 'PRP', 'V', '.', 'DT', 'V', 'DT', 'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   ',',
#   'V',
#   'N',
#   '.',
#   'N',
#   'JJ',
#   'V',
#   'JJ',
#   'TO',
#   'V',
#   'PRP',
#   '.',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'N',
#   '.',
#   'PRP',
#   'V',
#   'PRP',
#   'V',
#   ',',
#   'PRP',
#   'V',
#   'PRP',
#   'N',
#   '.'],
#  [],
#  ['V', 'IN', 'DT', 'N', 'N'],
#  [],
#  ['RB', 'DT', 'V', 'DT', 'JJ', 'N', '#', 'N'],
#  [],
#  ['N', 'PRP', 'V', 'N', 'JJ', 'JJ', 'N', ':', 'N', 'N', ':', 'N'],
#  [],
#  ['#',
#   'N',
#   ':',
#   'WRB',
#   'N',
#   'N',
#   'MD',
#   'RB',
#   'V',
#   'V',
#   'RB',
#   'RB',
#   'TO',
#   'V',
#   '.',
#   '#',
#   'N',
#   '.',
#   'V',
#   'PRP',
#   'N',
#   'RB',
#   '.',
#   '.'],
#  [],
#  ['N', 'V', 'V', 'N', '#', 'N'],
#  [],
#  ['JJ',
#   'N',
#   'PRP',
#   'V',
#   'RB',
#   'V',
#   'N',
#   'IN',
#   'PRP',
#   'V',
#   'V',
#   'PRP',
#   'N',
#   ',',
#   'PRP',
#   'MD',
#   'V',
#   'PRP',
#   'V',
#   'RB',
#   'V'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   ':',
#   'PRP',
#   'V',
#   'PRP',
#   'IN',
#   'CD',
#   ':',
#   ')',
#   ',',
#   'N',
#   'RB',
#   'N',
#   'N',
#   'V',
#   'PRP',
#   'DT',
#   'N',
#   'RB',
#   'IN',
#   'JJ',
#   'N'],
#  [],
#  ['CC',
#   'DT',
#   'N',
#   'MD',
#   'V',
#   'IN',
#   'CC',
#   'IN',
#   'IN',
#   'PRP',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   'RP',
#   'PRP',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N', 'N', 'V', 'DT', 'JJ', ',', 'V', 'RP', '#', 'N'],
#  [],
#  ['DT', 'V', 'JJ', '#', 'N', 'N'],
#  [],
#  ['V', 'V', 'RP', 'IN', 'DT', 'N', 'IN', 'DT', 'N', '.', '#', 'JJ', '#', 'N'],
#  [],
#  ['N', 'IN', 'N', 'V', 'RB', 'JJ', '.', '#', 'N', 'N'],
#  [],
#  ['N', 'N', 'N', 'V', 'RB', 'JJ', '#', 'N'],
#  [],
#  ['DT', 'N', 'TO', 'N', 'N', ',', 'V', '#', 'N'],
#  [],
#  ['PRP',
#   'N',
#   ',',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'DT',
#   'JJ',
#   'CC',
#   'N',
#   ':',
#   'JJ',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'V',
#   'WP',
#   'V',
#   'JJ',
#   'N',
#   'V',
#   'N'],
#  [],
#  ['JJ', 'N', 'WP', 'RP', 'N', '.'],
#  [],
#  ['JJ', 'N', 'IN', 'DT', 'JJ', '.', '#', 'JJ', 'N', ':', 'N'],
#  [],
#  ['WP', 'JJ', 'N', 'N', 'PRP', 'RB', 'V', '#', 'JJ', '#', 'N'],
#  [],
#  ['PRP',
#   'V',
#   'JJ',
#   'WRB',
#   'PRP',
#   'V',
#   'JJ',
#   'N',
#   'PRP',
#   'RB',
#   'RB',
#   'TO',
#   'V',
#   'IN',
#   'PRP',
#   'RB',
#   'PRP',
#   'V',
#   'IN',
#   'PRP',
#   'DT',
#   'JJ',
#   'N',
#   '#',
#   'JJ',
#   '#',
#   'JJ',
#   '#',
#   'V'],
#  [],
#  ['DT', 'N', 'V', 'V', 'TO', 'V', 'JJ', '#', 'N', '#', 'N'],
#  [],
#  ['JJ', 'N', 'N', 'N', 'PRP', 'N', '#', 'N'],
#  [],
#  ['N',
#   'V',
#   'PRP',
#   'V',
#   'JJ',
#   'WRB',
#   'DT',
#   'N',
#   'MD',
#   'V',
#   'IN',
#   'JJ',
#   'N',
#   '#',
#   'JJ',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   'WP',
#   'PRP',
#   'MD',
#   'V',
#   'RB',
#   'IN',
#   'N',
#   'CC',
#   'PRP',
#   'V',
#   'PRP',
#   'JJ',
#   'JJ',
#   'CC',
#   'PRP',
#   'V',
#   'RB',
#   ',',
#   '#',
#   'V',
#   '#',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'V',
#   ':',
#   'PRP',
#   'V',
#   'PRP',
#   ',',
#   'CC',
#   'PRP',
#   'V',
#   'RB',
#   'RB',
#   'V',
#   'TO',
#   'V',
#   'TO',
#   'PRP',
#   '.',
#   'N',
#   '.',
#   'CC',
#   'N',
#   ':',
#   'CC'],
#  [],
#  ['RB', 'RB', 'JJ', 'N', 'IN', 'N', '.', 'JJ', 'N', 'TO', 'DT', 'JJ', 'N'],
#  ['#', 'N', '#', 'N', '#', 'JJ', '#', 'N'],
#  [],
#  ['CD',
#   'V',
#   'CC',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'N',
#   'MD',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'N',
#   'IN',
#   'PRP',
#   'V',
#   'RB',
#   'DT',
#   'N',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'IN',
#   'DT',
#   'CD',
#   'N'],
#  [],
#  ['RB', 'N', 'WRB', 'MD', 'PRP', 'V', 'DT', '.', 'N'],
#  [],
#  ['V', 'WP', 'DT', 'JJ', 'V', '.', '#', 'N'],
#  [],
#  ['JJ', 'N', 'V', 'RP', 'IN', 'PRP', ',', 'CD', 'N', 'RB'],
#  [],
#  ['PRP', 'RB', 'V', 'V', 'PRP', 'N', 'N', 'WRB', 'PRP', 'V', ':', '#', 'N'],
#  [],
#  ['N',
#   'N',
#   'IN',
#   'N',
#   'N',
#   'V',
#   'CD',
#   'N',
#   ':',
#   'JJ',
#   '#',
#   'N',
#   '#',
#   'N',
#   '#',
#   'N',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'V',
#   'N',
#   'IN',
#   'N',
#   'V',
#   'IN',
#   'IN',
#   'JJ',
#   'IN',
#   'CD',
#   'PRP',
#   'V',
#   'V',
#   'RP',
#   'TO',
#   'V',
#   'RB',
#   'RB',
#   'RB',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   'JJ',
#   'N',
#   'IN',
#   'JJ',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'IN',
#   'IN',
#   'N',
#   'WDT',
#   'N',
#   'JJ',
#   'N',
#   'IN',
#   'N',
#   '.',
#   'N',
#   'N',
#   'CC',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N', 'V', 'TO', 'V', 'V', '.'],
#  [],
#  ['N',
#   '.',
#   'WRB',
#   'PRP',
#   'V',
#   'RB',
#   'TO',
#   'CD',
#   'N',
#   'PRP',
#   'V',
#   'JJ',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   ',',
#   'N',
#   'N',
#   ',',
#   'JJ',
#   'CC',
#   'JJ',
#   ':',
#   '.',
#   'PRP',
#   'N',
#   'V',
#   'RB',
#   'V',
#   'RB',
#   'JJ',
#   'N',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   ',',
#   'PRP',
#   'V',
#   'JJ',
#   'JJ',
#   'PRP',
#   'V',
#   'N',
#   'IN',
#   'N',
#   'N',
#   'N',
#   'V',
#   ',',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   'IN',
#   'PRP',
#   'V',
#   'RB',
#   'RB',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N', 'N', 'V', 'IN', 'PRP', 'N', 'N', ',', 'N', '.', '#', 'N'],
#  [],
#  ['JJ', 'N', 'N', 'N', 'N', 'N', 'IN', 'N', 'N', 'N', 'N', 'N', '.'],
#  [],
#  ['N', 'N', 'N', 'V', 'V', 'JJ', '#', 'N'],
#  [],
#  ['N', 'N', 'CC', 'N', 'N', 'N', ':', 'N'],
#  [],
#  ['N',
#   ',',
#   'PRP',
#   'MD',
#   'V',
#   'RB',
#   'JJ',
#   'RB',
#   '#',
#   'N',
#   'RB',
#   ',',
#   'PRP',
#   'V',
#   'TO',
#   'V',
#   'PRP',
#   'RB',
#   'N',
#   'RP',
#   'IN',
#   'N',
#   'IN',
#   'DT',
#   'V',
#   'N',
#   '.'],
#  [],
#  ['PRP',
#   'MD',
#   'RB',
#   'V',
#   'TO',
#   'CD',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   'PRP',
#   'V',
#   'IN',
#   'PRP',
#   'N',
#   '.',
#   'JJ',
#   '#',
#   'JJ',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['PRP', 'RB', 'V', 'CD', 'N', 'N', '#', 'N', 'N'],
#  [],
#  ['UH',
#   'CD',
#   'N',
#   'N',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   ',',
#   'WDT',
#   'V',
#   'N',
#   'RB',
#   ':',
#   ')',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'RP',
#   'TO',
#   'CD',
#   'N',
#   ':',
#   'N',
#   'JJ',
#   'N',
#   ':',
#   'N',
#   'POS',
#   'JJ',
#   'N',
#   'N',
#   'N',
#   'WRB',
#   'N',
#   'CC',
#   'N',
#   ':',
#   'N',
#   'V',
#   ':',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['JJ', 'N', 'N', 'N', 'PRP', 'V', 'PRP', 'V', 'PRP', 'JJ', 'N', '#', 'N'],
#  [],
#  ['#', 'N', 'V', 'RP', 'RB', 'IN', 'V', 'DT', 'JJ', '#', 'N'],
#  [],
#  ['N',
#   'N',
#   'N',
#   'N',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   'IN',
#   'PRP',
#   'JJ',
#   'N',
#   'CC',
#   'N',
#   'N',
#   'N',
#   'N',
#   '.',
#   'PRP',
#   'MD',
#   'V',
#   'RB',
#   'V',
#   '.',
#   ':',
#   'CD'],
#  [],
#  ['N',
#   ',',
#   'PRP',
#   'V',
#   'PRP',
#   'IN',
#   'PDT',
#   'DT',
#   'N',
#   '.',
#   '#',
#   'JJ',
#   'N',
#   'N',
#   'N',
#   ':',
#   '#',
#   'N',
#   ':',
#   'PRP',
#   'V',
#   'DT',
#   'N',
#   'IN',
#   'PRP',
#   'N',
#   '.'],
#  [],
#  ['PRP',
#   'V',
#   'WRB',
#   'DT',
#   'PRP',
#   'N',
#   'CC',
#   'N',
#   'V',
#   'RB',
#   'JJ',
#   '#',
#   'JJ',
#   '#',
#   'N',
#   'V'],
#  [],
#  ['PRP',
#   'V',
#   'RB',
#   'V',
#   'WP',
#   'TO',
#   'V',
#   'IN',
#   'PRP',
#   'N',
#   'IN',
#   'N',
#   'JJ',
#   'CC',
#   'V',
#   'N'],
#  [],
#  ['JJ', 'N', 'N', 'N', 'N', ',', 'FW', 'N', 'N', '.', '.'],
#  [':', 'N'],
#  [],
#  ['WRB',
#   'JJ',
#   'N',
#   'IN',
#   'N',
#   'N',
#   'CC',
#   'JJ',
#   'N',
#   'N',
#   'CC',
#   'V',
#   'N',
#   'RB',
#   'CD',
#   'PRP',
#   'V',
#   'V',
#   'RB'],
#  [],
#  ['DT', 'V', 'RB', 'RB', 'JJ', '.', 'N', ':', 'N'],
#  [],
#  ['MD',
#   'RB',
#   'V',
#   'CD',
#   'N',
#   'N',
#   'N',
#   'V',
#   'V',
#   'RB',
#   'V',
#   'N',
#   'V',
#   ':',
#   '#',
#   'N'],
#  [],
#  ['PRP', 'V', 'PRP', 'TO', 'V', 'JJ', '.', '#', 'N'],
#  [],
#  ['V', 'PRP', 'V', 'DT', 'N', 'IN', 'DT', '.', '#', 'JJ', '#', 'N'],
#  [],
#  ['MD',
#   'N',
#   'V',
#   'V',
#   'PRP',
#   'WRB',
#   'PRP',
#   'V',
#   'IN',
#   'N',
#   'IN',
#   'N',
#   'N',
#   'RB',
#   '.',
#   '.',
#   'IN',
#   'RB',
#   'JJ',
#   '#',
#   'N',
#   'N'],
#  [],
#  ['N', 'PRP', 'V', 'N', 'IN', 'RB', 'V', 'RP', '.', '#', 'JJ', '#', 'N'],
#  [],
#  [':',
#   'N',
#   'V',
#   'DT',
#   'V',
#   'PRP',
#   'JJ',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   'JJ',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['N',
#   'IN',
#   'V',
#   'PRP',
#   'WRB',
#   'JJ',
#   'N',
#   'V',
#   'JJ',
#   'JJ',
#   'DT',
#   'JJ',
#   'N',
#   ':',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   ':',
#   'PRP',
#   'V',
#   'PRP',
#   'WRB',
#   'DT',
#   'N',
#   'N',
#   'V',
#   'PRP',
#   'MD',
#   'V',
#   'CD',
#   'N',
#   'WRB',
#   'PRP',
#   'V',
#   'V',
#   'V',
#   'CD',
#   '#',
#   'N',
#   '.',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   'RB',
#   'JJ',
#   'IN',
#   'DT',
#   'TO',
#   'V',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'CC',
#   'N',
#   'V',
#   'DT',
#   'DT',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'N',
#   'N',
#   'V',
#   'PRP',
#   'V',
#   'IN',
#   'DT',
#   'N',
#   'V',
#   'DT',
#   '``',
#   'N',
#   "''",
#   'CC',
#   'DT',
#   '.',
#   'CC',
#   'N',
#   ':',
#   'N',
#   'CC',
#   'N',
#   ':',
#   '#',
#   'N'],
#  [],
#  ['RB', 'V', 'V', 'V', 'TO', '.', '#', 'N'],
#  [],
#  ['RB',
#   'IN',
#   'DT',
#   'N',
#   'IN',
#   'N',
#   ',',
#   'EX',
#   'V',
#   'DT',
#   'N',
#   'IN',
#   'JJ',
#   '.',
#   'N',
#   ':',
#   'N'],
#  [],
#  ['N', 'V', 'V', 'N', '.'],
#  [],
#  ['PRP', 'V', 'RB', 'V', 'IN', 'DT', 'N', 'N', 'N'],
#  [],
#  ['IN',
#   'TO',
#   'N',
#   'N',
#   '.',
#   'RB',
#   'IN',
#   'DT',
#   'N',
#   'V',
#   'RB',
#   'V',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   ',',
#   'PRP',
#   'V',
#   'V',
#   'RB',
#   'TO',
#   'V',
#   'V',
#   'IN',
#   'N',
#   ':',
#   ':',
#   ')'],
#  [],
#  ['IN',
#   'N',
#   'PRP',
#   'V',
#   'DT',
#   'JJ',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   'CC',
#   'DT',
#   'N',
#   'V',
#   'JJ',
#   'N',
#   '#',
#   'V',
#   '#',
#   'N'],
#  [],
#  ['DT', 'N', 'N', 'V', 'DT', 'N', 'TO', 'DT', 'JJ', 'N', '.'],
#  [],
#  ['JJ', 'N', 'V', 'JJ', '.', 'WRB', 'RB', 'V', 'PRP', 'V', 'TO', 'V', '.'],
#  [],
#  ['PRP',
#   'V',
#   'IN',
#   'JJ',
#   'JJ',
#   'N',
#   'IN',
#   'PRP',
#   'JJ',
#   'RB',
#   'JJ',
#   'TO',
#   'PRP',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'DT',
#   'N',
#   '.',
#   'PRP',
#   'V',
#   'JJ',
#   '.',
#   'N',
#   'WP',
#   'V',
#   'PRP',
#   'N',
#   'IN',
#   'N',
#   '.',
#   'RB',
#   'IN',
#   'PRP',
#   'V',
#   'PRP',
#   'N',
#   'CC',
#   'N',
#   ':',
#   'N',
#   'V',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['PRP',
#   'V',
#   '.',
#   'RB',
#   'V',
#   'TO',
#   'V',
#   'IN',
#   'IN',
#   'PRP',
#   'N',
#   'N',
#   'PRP',
#   'V',
#   'RB',
#   'V',
#   'PRP',
#   'N',
#   'RB'],
#  [],
#  ['N', 'JJ', 'TO', 'V', 'IN', 'N', '#', 'N'],
#  [],
#  ['RB',
#   'V',
#   'WRB',
#   'N',
#   'V',
#   'V',
#   'IN',
#   'PRP',
#   'N',
#   'N',
#   'V',
#   'RB',
#   '#',
#   'JJ',
#   '#',
#   'N',
#   ':'],
#  [],
#  ['DT', 'N', 'IN', 'DT', '.'],
#  [],
#  ['V', 'PRP', 'N', 'IN', 'N', 'JJ', 'N', 'N', '#', 'N'],
#  [],
#  ['DT',
#   'N',
#   'N',
#   'V',
#   'V',
#   'IN',
#   'DT',
#   'JJ',
#   'N',
#   '.',
#   'JJ',
#   'N',
#   'CC',
#   'V',
#   'RB',
#   'V',
#   'TO',
#   'V',
#   'N',
#   '.'],
#  [],
#  ['RB',
#   'V',
#   'RP',
#   'DT',
#   'N',
#   'IN',
#   'N',
#   '.',
#   'V',
#   'PRP',
#   'PRP',
#   'RB',
#   'V',
#   'DT',
#   'JJ',
#   'WDT',
#   'N',
#   'V',
#   '.',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['RB', 'V', 'TO', 'N', 'N', '(', 'JJ'],
#  [],
#  ['JJ', 'N', 'JJ', 'N', 'IN', 'JJ', 'N', 'V', 'DT', 'JJ', 'N', 'RB', '#', 'N'],
#  [],
#  ['N',
#   'IN',
#   'V',
#   'IN',
#   'N',
#   'CD',
#   'N',
#   'CC',
#   'V',
#   'CD',
#   'N',
#   'TO',
#   'V',
#   '.',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['JJ', 'N', 'N', 'N', 'N', 'RB', 'DT', 'N', 'N', ':', '(', ':', '#', 'N'],
#  [],
#  ['PRP',
#   'N',
#   'V',
#   'RP',
#   'TO',
#   'PDT',
#   'DT',
#   'N',
#   'IN',
#   'JJ',
#   'N',
#   'IN',
#   'TO',
#   'V',
#   'V',
#   'IN',
#   'N',
#   'N'],
#  [],
#  ['IN', 'PDT', 'DT', 'JJ', 'N', '#', 'N'],
#  [],
#  ['N', 'RB', 'IN', 'N', ':', 'N'],
#  [],
#  ['N',
#   ',',
#   'N',
#   'V',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   'IN',
#   'DT',
#   'N',
#   '.',
#   'PRP',
#   'N',
#   'V',
#   'JJ',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['RB',
#   'PRP',
#   'RB',
#   'V',
#   'RP',
#   'DT',
#   'JJ',
#   'N',
#   'CC',
#   'RB',
#   'PRP',
#   'V',
#   'V',
#   'TO',
#   'V',
#   'N',
#   'IN',
#   'PRP',
#   'N',
#   ':',
#   'WP',
#   'V',
#   'N',
#   'N',
#   'N',
#   ':',
#   '#',
#   'V'],
#  [],
#  ['PRP',
#   'V',
#   'V',
#   'IN',
#   'CD',
#   'N',
#   'CC',
#   'PRP',
#   'N',
#   'V',
#   'RB',
#   'RB',
#   'V',
#   ':'],
#  [],
#  ['V', 'DT', 'N', 'IN', 'DT', 'JJ', 'N'],
#  [],
#  ['PRP',
#   'V',
#   'JJ',
#   '.',
#   'PRP',
#   'MD',
#   'RB',
#   'V',
#   'WP',
#   'V',
#   'DT',
#   'N',
#   'RB',
#   '.',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'V',
#   'N',
#   'TO',
#   'V',
#   'PRP',
#   'RB',
#   ',',
#   'N',
#   '.',
#   'V',
#   'PRP',
#   'N',
#   '.',
#   'V',
#   'TO',
#   'V',
#   'PRP',
#   'RB',
#   'RB',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N', 'RB', 'V', 'DT', 'N', 'JJ', 'N'],
#  [],
#  ['RB', 'CD', 'N', '.', 'N', 'V', 'IN'],
#  [],
#  ['DT',
#   'IN',
#   'DT',
#   'N',
#   'V',
#   'DT',
#   'N',
#   'V',
#   'RB',
#   'RB',
#   'V',
#   'TO',
#   'V',
#   '.',
#   '#',
#   'N'],
#  [],
#  ['N',
#   'V',
#   'PRP',
#   'IN',
#   'PRP',
#   'N',
#   'V',
#   'JJ',
#   'N',
#   '.',
#   'PRP',
#   'V',
#   'TO',
#   'V',
#   'V',
#   'DT',
#   'N',
#   ',',
#   'PRP',
#   'V',
#   'PRP',
#   'V',
#   'RB',
#   '.'],
#  [],
#  ['V',
#   'PRP',
#   'N',
#   'CC',
#   'PRP',
#   'RB',
#   'N',
#   'CC',
#   'PRP',
#   'V',
#   'RB',
#   'RB',
#   'V',
#   'JJ',
#   'RB',
#   ':',
#   '.',
#   '#',
#   'JJ',
#   '#',
#   'N'],
#  [],
#  ['JJ',
#   'N',
#   'N',
#   'N',
#   '.',
#   'N',
#   'V',
#   'CD',
#   'N',
#   'CC',
#   'CD',
#   'N',
#   'CC',
#   'IN',
#   'PRP',
#   ':',
#   ')'],
#  ...]

# %%
print(list4[8])
# Out:
# ['PRP', 'RB', 'V', 'V', 'DT', 'N', '.', 'JJ', '#', 'N']

# %%
i =0 

# list5 is the list containing all tweets with possible bigrams
list5 = []

for j in list4:
    for x in range(len(list4[i]) -1):
        if( list4[i][x]=="V" and list4[i][x+1]=="V" or 
            list4[i][x]=="V" and list4[i][x+1]=="ADV" or
            list4[i][x]=="ADV" and list4[i][x+1]=="V" or 
            list4[i][x]=="TO" and list4[i][x+1]=="V" or
            list4[i][x]=="V" and list4[i][x+1]=="N" or
            list4[i][x]=="V" and list4[i][x+1]=="PRP" or
            list4[i][x]=="V" and list4[i][x+1]=="JJ"): 
                list5.append(list[i])
                break
    i+=1
print(list5)
# Out:
# ['Very low entries in this giveaway! Hop over and check it out! http://t.co/OrUSN9ne\n', 'Summers over and it was shit. Only sunny day was a bbq in north west with @Kade_96 and @Jess_birch95 hahhahaaa #amazing #sarcasm\n', 'Did you know that one of Bolshoi Ballet members was born in Maranhão? Bruna Gaglianone is part of the Moscow group! http://t.co/LG3SME1l\n', 'I just love missing the bus! ☺ #sarcasm\n', "If you're going into highschool and cant do at least 4 pirouettes you obviously go to a fantastic studio #sarcasm\n", '@babee_kayyy lol itold you iwasnt coming . :) what we do in class ?\n', 'TThis 8:20 Friday class is gonna be grrreat!! #sarcasm\n', 'Gee wiz what a great day so far. You can cut the tension with a knife and they think im faking #great. #sarcasm\n', 'Feel like crap, tomorrow should be great. #sarcasm #throathurts #allergies\n', "If I could put into words how much I love waking up at 5 am on Tuesday's I would.... 😒 #sarcasm.\n", 'I actually did something with my hair today #firsttimeinmonths #weird d\n', 'Thanks @PippaCarlson1 your tweets are great #sarcasm\n', 'I really admire your maturity. #sarcasm\n', "@lilylovehermore I knew I'd heard that name somewhere!\n", 'I just love getting a random schedule change and not even knowing about it!:) #sarcasm\n', "I've got to get my money back this time 💰🍁👌\n", "@Will_Piper should move back up fella. I'm already here... On my own... Having loads of fun #sarcasm\n", "To anyone still making the 'Something about a picture of Andy Carroll...OH NO WAIT, IT'S A HORSE' joke; stop.\n", "Its my birthday bitches... who's gonna start sucking my dick and who's gonna start sucking my balls?\n", 'We all have that one person who we wished we never gave our phone number to... #Ted\n', '@Students4Obama If your Dad will let you sit there #fadedposter\n', 'Need to play football....\n', '#PROJECTRUNWAY Ven ur dress gave ur  model a 3RD BREAST! Nice, just what every gal wants! u sure know design better than women! #sarcasm\n', "@RumaisaMohani @ShaiziCheema - I'm sure mr Raja rental would have a nice profitable scheme in mind #Sarcasm\n", 'I want to be here... http://t.co/Q9bFkxsE\n', 'Omg most insane matriculants, we rather play soccer than study 4 prelims=D @SadieRazak , @Cocoz_25,@xFatima_s , @TasneemKarolia,#Soccer4lyf♥\n', '@BertLcfc lookin forward to satday as well nothin quite like a 5.20 kick off #sarcasm\n', "Yay it's 3 hour clinical day. I'm so freaking excited I can't stand it. #sarcasm\n", 'I love it whenever my brother gets up and turns on all the lights... #sarcasm\n', "#10TurnOns Yet again if you list them on twitter you're garbage.\n", 'Just sprained my foot. happy days. #sarcasm\n', '@_jackpeters hahaha mannn gota have his slices yooo!\n', 'A little nervous to start school 😝 5 classes in one day should be fun...\n', 'You know what I love doing? Rehashing old arguments. #sarcasm\n', '"@skysports_bryan: We\'re told Swansea and Manchester City unable to reach agreement on Scott Sinclair." What.a.shame.  #sarcasm\n', 'When I really wana sleep n ppl wana chat✗\n', "Cynical me sees the Trinity-Spadina riding being mostly left alone despite pop. growth because splitting it wouldn't help the CPC. #CDNPoli\n", '@iAM_MissJackson well I guess because they were missing pleasure p.\n', 'I just love getting up this early to go into school #sarcasm #sotired #killme :/\n', 'Dear Teva, thank you for waking me up every few hours by howling. Your just trying to be mother natures alarm clock. #sarcasm\n', '@MarkPacker Yeah, but Beckett is the kind of guy that just makes you want to root for him.  #sarcasm\n', 'My favourite pre-work job: fixing a punctured bike tyre. #Sarcasm\n', '@haileytanley Good! I will give details later\n', "@justkramer good you'll save more money that way #sarcasm\n", 'Well, today has started of to a WONDERFUL start. #Sarcasm\n', '#sarcasm....learn it\n', 'What to do? Help please @BlackBerryHelp @BlackBerryPH http://t.co/8uX92LQU\n', "@JonnyBones stay humble, but u turn ...
